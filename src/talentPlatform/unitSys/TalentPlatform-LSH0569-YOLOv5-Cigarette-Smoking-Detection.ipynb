# %% [markdown]
# # [요청] LSH0569. Python을 이용한 2024년 AI&무인이동체 퓨처 해커톤 (AI CCTV 흡연 모니터링 및 경고 알림)

# %% [markdown]
# ## 환경 변수 설정

# %%
# ! rm -rf '/content/drive/MyDrive/COLAB/testSys-LSH0569'

# %%
import os
from google.colab import drive
import glob
from IPython.display import HTML
from base64 import b64encode
import os

# 구글 드라이브 연결
drive.mount('/content/drive')

# 주요 설정
serviceName = 'LSH0569'
contextPath = f"/content/drive/MyDrive/COLAB/testSys-{serviceName}"

globalVar = {
    'ctxPath':  f"{contextPath}"
    , 'inpPath': f"{contextPath}/INPUT"
    , 'outPath': f"{contextPath}/OUTPUT"
    , 'figPath': f"{contextPath}/FIG"
}

for key, val in globalVar.items():
    if key.__contains__('Path'):
        os.makedirs(val, exist_ok=True)
        print(f"[CHECK] {key} : {val}")

# 작업 경로 설정
os.chdir(f"{globalVar['ctxPath']}")
print(f"[CHECK] getcwd : {os.getcwd()}")

# 옵션 설정
sysOpt = {

}

# 구글 드라이브 삭제
# ! rm -rf '/content/drive/MyDrive/COLAB/testSys-LSH0568'

# 구글 코랩 세션 무한 연결
# function PreventDisconnection(){
#     document.querySelector("colab-toolbar-button#connect").click()
#     console.log("클릭이 완료되었습니다.");
# }
# setInterval(PreventDisconnection, 60 * 10000)
# Out:
# Mounted at /content/drive
# [CHECK] ctxPath : /content/drive/MyDrive/COLAB/testSys-LSH0569
# [CHECK] inpPath : /content/drive/MyDrive/COLAB/testSys-LSH0569/INPUT
# [CHECK] outPath : /content/drive/MyDrive/COLAB/testSys-LSH0569/OUTPUT
# [CHECK] figPath : /content/drive/MyDrive/COLAB/testSys-LSH0569/FIG
# [CHECK] getcwd : /content/drive/MyDrive/COLAB/testSys-LSH0569

# %% [markdown]
# ## 시스템 환경 구축

# %%
# 작업경로 설정
# os.chdir(f"{globalVar['ctxPath']}")
# print(f"[CHECK] getcwd : {os.getcwd()}")

# 소스코드 다운로드
# ! git clone https://github.com/Maximgitman/cigarette_detection.git

# 작업경로 설정
# os.chdir(f"{globalVar['ctxPath']}/cigarette_detection")
# print(f"[CHECK] getcwd : {os.getcwd()}")

# 라이브러리 다운로드/설치
# ! pip install -r requirements.txt

# 샘플 파일 다운로드
# ! gdown https://drive.google.com/uc?id=1CPQHsINPNj4EzRZ2hAwa_1rjWkWbD88Y

# %% [markdown]
# ## 비즈니스 로직

# %%
# 작업경로 설정
os.chdir(f"{globalVar['ctxPath']}/cigarette_detection")
print(f"[CHECK] getcwd : {os.getcwd()}")

# 샘플 파일 처리
# ! python detect.py --source sddefault.jpg --weights yolov5s.pt

# 테스트 파일 처리
srcInfo = f"{globalVar['ctxPath']}/cigarette_detection/TalentPlatform-LSH0569-cigarette-detection.py"
modelInfo = f"custom_yolo5x.pt"
inpInfo = f"case_20240711.mp4"

cmd = f"python {srcInfo} --source {inpInfo} --weights {modelInfo} --save-conf --exist-ok --conf-thres 0.03"
# cmd = f"python {srcInfo} --source {inpInfo} --weights {modelInfo} --save-conf --exist-ok --conf-thres 0.05"
# cmd = f"python {srcInfo} --source {inpInfo} --weights {modelInfo} --save-conf --exist-ok --conf-thres 0.10"
# cmd = f"python {srcInfo} --source {inpInfo} --weights {modelInfo} --save-conf --exist-ok --conf-thres 0.15"
print(f"[CHECK] cmd : {cmd}")
! {cmd}
# Out:
# [CHECK] getcwd : /content/drive/MyDrive/COLAB/testSys-LSH0569/cigarette_detection
# [CHECK] cmd : python /content/drive/MyDrive/COLAB/testSys-LSH0569/cigarette_detection/TalentPlatform-LSH0569-cigarette-detection.py --source case_20240711.mp4 --weights custom_yolo5x.pt --save-conf --exist-ok --conf-thres 0.03
# .
# TalentPlatform-LSH0569-cigarette-detection: weights=['custom_yolo5x.pt'], source=case_20240711.mp4, imgsz=[640, 640], conf_thres=0.03, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=., exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 c6e3a13 torch 2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model Summary: 232 layers, 7246518 parameters, 0 gradients
# ...
