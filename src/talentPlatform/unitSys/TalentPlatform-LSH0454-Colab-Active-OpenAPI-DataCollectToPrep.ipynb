# %% [markdown]
# # [요청] LSH0568. Python을 이용한 2024년 AI&무인이동체 퓨처 해커톤 (AI 북한군 탐지 및 경고 알림)

# %% [markdown]
# ## 환경 변수 설정

# %%
import os
from google.colab import drive
import glob
from IPython.display import HTML
from base64 import b64encode
import os

# 구글 드라이브 연결
drive.mount('/content/drive')

# 주요 설정
serviceName = 'LSH0568'
contextPath = f"/content/drive/MyDrive/COLAB/testSys-{serviceName}"

globalVar = {
    'ctxPath':  f"{contextPath}"
    , 'inpPath': f"{contextPath}/INPUT"
    , 'outPath': f"{contextPath}/OUTPUT"
    , 'figPath': f"{contextPath}/FIG"
}

for key, val in globalVar.items():
    if key.__contains__('Path'):
        os.makedirs(val, exist_ok=True)
        print(f"[CHECK] {key} : {val}")

# 작업 경로 설정
os.chdir(f"{globalVar['ctxPath']}")
print(f"[CHECK] getcwd : {os.getcwd()}")

# 옵션 설정
sysOpt = {

}

# 구글 드라이브 삭제
# ! rm -rf '/content/drive/MyDrive/COLAB/testSys-LSH0568'

# 구글 코랩 세션 무한 연결
# function PreventDisconnection(){
#     document.querySelector("colab-toolbar-button#connect").click()
#     console.log("클릭이 완료되었습니다.");
# }
# setInterval(PreventDisconnection, 60 * 10000)
# Out:
# Mounted at /content/drive
# [CHECK] ctxPath : /content/drive/MyDrive/COLAB/testSys-LSH0568
# [CHECK] inpPath : /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT
# [CHECK] outPath : /content/drive/MyDrive/COLAB/testSys-LSH0568/OUTPUT
# [CHECK] figPath : /content/drive/MyDrive/COLAB/testSys-LSH0568/FIG
# [CHECK] getcwd : /content/drive/MyDrive/COLAB/testSys-LSH0568/YOLOv7-DeepSORT-Object-Tracking

# %% [markdown]
# ## 시스템 환경 구축

# %%
# # 소스코드 다운로드
# os.chdir(f"{globalVar['ctxPath']}")
# print(f"[CHECK] getcwd : {os.getcwd()}")
# ! git clone https://github.com/MuhammadMoinFaisal/YOLOv7-DeepSORT-Object-Tracking.git

# # 라이브러리 다운로드/설치
# os.chdir(f"{globalVar['ctxPath']}/YOLOv7-DeepSORT-Object-Tracking")
# print(f"[CHECK] getcwd : {os.getcwd()}")
# ! pip install -r requirements.txt
# ! pip install easydict

# # deep_sort_pytorch 다운로드/설치
# ! gdown "https://drive.google.com/uc?id=11ZSZcG-bcbueXZC3rN08CM0qqX3eiHxf&confirm=t"
# ! unzip 'deep_sort_pytorch.zip'

# # YOLO 학습모형 다운로드/설치
# cmd = f"wget -P {globalVar['ctxPath']}/YOLOv7-DeepSORT-Object-Tracking https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt"
# print(f"[CHECK] cmd : {cmd}")
# ! {cmd}

# # 샘플 파일 다운로드
# ! gdown https://drive.google.com/uc?id=1_kt1alzcLRVxet-Drx0mt_KFSd3vrtHU

# # 비즈니스 로직 다운로드
# ! gdown https://drive.google.com/uc?id=1O577NwrOWhQ8T7Ihtn-X_eD_dO-RcChk

# # 샘플 파일 다운로드
# os.chdir(f"{globalVar['inpPath']}")
# print(f"[CHECK] getcwd : {os.getcwd()}")
# ! gdown https://drive.google.com/uc?id=1O7476xFKfxcjRJK3QJpy-nljtrrW4xAr
# ! gdown https://drive.google.com/uc?id=1O811iqDcPgYC0-cjRzs62dwLscuaSTqG
# ! gdown https://drive.google.com/uc?id=1O7xeTPGBV5ySolOVKsM_iNJIdKqxZJOQ
# ! gdown https://drive.google.com/uc?id=1ONkT0qGznrw1GfWr2ZuaGFUrgGJMLYzv
# Out:
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 4)) (3.7.1)
# Collecting numpy<1.24.0,>=1.18.5 (from -r requirements.txt (line 5))
#   Downloading numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 50.2 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 6)) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 7)) (9.4.0)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 8)) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 9)) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 10)) (1.11.4)
# Requirement already satisfied: torch!=1.12.0,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 11)) (2.3.0+cu121)
# Requirement already satisfied: torchvision!=0.13.0,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 12)) (0.18.0+cu121)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 13)) (4.66.4)
# Requirement already satisfied: protobuf<4.21.3 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 14)) (3.20.3)
# Requirement already satisfied: tensorboard>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 17)) (2.15.2)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 21)) (2.0.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 22)) (0.13.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 34)) (7.34.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 35)) (5.9.5)
# Collecting thop (from -r requirements.txt (line 36))
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (2024.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.7.0->-r requirements.txt (line 11)) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.7.0->-r requirements.txt (line 11)) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.7.0->-r requirements.txt (line 11)) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.7.0->-r requirements.txt (line 11)) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.7.0->-r requirements.txt (line 11)) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.7.0->-r requirements.txt (line 11)) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch!=1.12.0,>=1.7.0->-r requirements.txt (line 11))
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch!=1.12.0,>=1.7.0->-r requirements.txt (line 11))
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch!=1.12.0,>=1.7.0->-r requirements.txt (line 11))
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch!=1.12.0,>=1.7.0->-r requirements.txt (line 11))
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch!=1.12.0,>=1.7.0->-r requirements.txt (line 11))
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch!=1.12.0,>=1.7.0->-r requirements.txt (line 11))
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch!=1.12.0,>=1.7.0->-r requirements.txt (line 11))
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch!=1.12.0,>=1.7.0->-r requirements.txt (line 11))
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch!=1.12.0,>=1.7.0->-r requirements.txt (line 11))
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch!=1.12.0,>=1.7.0->-r requirements.txt (line 11))
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch!=1.12.0,>=1.7.0->-r requirements.txt (line 11))
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.7.0->-r requirements.txt (line 11)) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch!=1.12.0,>=1.7.0->-r requirements.txt (line 11))
#   Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 65.6 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->-r requirements.txt (line 17)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->-r requirements.txt (line 17)) (1.64.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->-r requirements.txt (line 17)) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->-r requirements.txt (line 17)) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->-r requirements.txt (line 17)) (3.6)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->-r requirements.txt (line 17)) (67.7.2)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->-r requirements.txt (line 17)) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->-r requirements.txt (line 17)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->-r requirements.txt (line 17)) (3.0.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->-r requirements.txt (line 21)) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->-r requirements.txt (line 21)) (2024.1)
# Collecting jedi>=0.16 (from ipython->-r requirements.txt (line 34))
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 88.9 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->-r requirements.txt (line 34)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->-r requirements.txt (line 34)) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->-r requirements.txt (line 34)) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->-r requirements.txt (line 34)) (3.0.47)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->-r requirements.txt (line 34)) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->-r requirements.txt (line 34)) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->-r requirements.txt (line 34)) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->-r requirements.txt (line 34)) (4.9.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 17)) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 17)) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 17)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard>=2.4.1->-r requirements.txt (line 17)) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->-r requirements.txt (line 34)) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->-r requirements.txt (line 34)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->-r requirements.txt (line 34)) (0.2.13)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.4.1->-r requirements.txt (line 17)) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch!=1.12.0,>=1.7.0->-r requirements.txt (line 11)) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 17)) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard>=2.4.1->-r requirements.txt (line 17)) (3.2.2)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, jedi, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, thop
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.0
#     Uninstalling numpy-2.0.0:
#       Successfully uninstalled numpy-2.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chex 0.1.86 requires numpy>=1.24.1, but you have numpy 1.23.5 which is incompatible.
# pandas-stubs 2.0.3.230814 requires numpy>=1.25.0; python_version >= "3.9", but you have numpy 1.23.5 which is incompatible.
# Successfully installed jedi-0.19.1 numpy-1.23.5 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.82 nvidia-nvtx-cu12-12.1.105 thop-0.1.1.post2209072238

# %% [markdown]
# ## 비즈니스 로직

# %%
# 작업경로 설정
# os.chdir(f"{globalVar['ctxPath']}/YOLOv7-DeepSORT-Object-Tracking")
# os.getcwd()

# 샘플 파일 처리
# cmd = f"python deep_sort_tracking_id.py --weights yolov7.pt  --img 640  --source test1.mp4"
# print(f"[CHECK] cmd : {cmd}")
# ! {cmd}

# %%
# 작업경로 설정
os.chdir(f"{globalVar['ctxPath']}/YOLOv7-DeepSORT-Object-Tracking")
os.getcwd()

# 테스트 파일 처리
srcInfo = f"{globalVar['ctxPath']}/YOLOv7-DeepSORT-Object-Tracking/TalentPlatform-LSH0568-deep_sort_tracking_id.py"
modelInfo = f"yolov7.pt"
inpInfo = f"{globalVar['inpPath']}/case_eGtahtswt_E.mp4"
# inpInfo = f"{globalVar['inpPath']}/case2_GVz6RZZmTlg.mp4"
# inpInfo = f"{globalVar['inpPath']}/case3_KHYEROW8RYA.mp4"
outInfo = f"{globalVar['inpPath']}/result_20240710"

# 단위 테스트
# cmd = f"python {srcInfo} --weights {modelInfo} --source {inpInfo} --classes 0 --save-txt --save-conf --exist-ok --save_dir {os.path.basename(outInfo)}"
# cmd = f"python {srcInfo} --weights {modelInfo} --source {inpInfo} --classes 0 --exist-ok --save_dir {os.path.basename(outInfo)}"
# print(f"[CHECK] cmd : {cmd}")
# ! {cmd}

# 통합 테스트
# keyList = ["case_eGtahtswt_E.mp4"]
keyList = ["case4_Y2meta.mp4"]
# keyList = ["case_eGtahtswt_E.mp4", "case2_GVz6RZZmTlg.mp4", "case3_KHYEROW8RYA.mp4", "case4_Y2meta.mp4"]
for key in keyList:
    inpInfo = f"{globalVar['inpPath']}/{key}"
    # cmd = f"python {srcInfo} --weights {modelInfo} --source {inpInfo} --classes 0 --save-txt --save-conf --exist-ok --save_dir {os.path.basename(outInfo)}"
    cmd = f"python {srcInfo} --weights {modelInfo} --source {inpInfo} --classes 0 --exist-ok --save_dir {os.path.basename(outInfo)}"
    print(f"[CHECK] cmd : {cmd}")
    ! {cmd}
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# video 1/1 (565/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.8ms) NMS
# video 1/1 (566/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.0ms) Inference, (0.8ms) NMS
# video 1/1 (567/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.0ms) Inference, (0.9ms) NMS
# video 1/1 (568/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (12.0ms) Inference, (4.5ms) NMS
# video 1/1 (569/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.6ms) Inference, (1.0ms) NMS
# video 1/1 (570/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.9ms) NMS
# video 1/1 (571/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.9ms) NMS
# video 1/1 (572/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.9ms) Inference, (0.8ms) NMS
# video 1/1 (573/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.9ms) Inference, (1.5ms) NMS
# video 1/1 (574/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.8ms) NMS
# video 1/1 (575/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (0.8ms) NMS
# video 1/1 (576/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (0.8ms) NMS
# video 1/1 (577/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.8ms) NMS
# video 1/1 (578/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (0.8ms) NMS
# video 1/1 (579/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.8ms) NMS
# video 1/1 (580/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.0ms) Inference, (0.9ms) NMS
# video 1/1 (581/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.0ms) Inference, (1.4ms) NMS
# video 1/1 (582/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.9ms) Inference, (0.9ms) NMS
# video 1/1 (583/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.9ms) NMS
# video 1/1 (584/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (0.8ms) NMS
# video 1/1 (585/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.0ms) Inference, (0.9ms) NMS
# video 1/1 (586/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.8ms) NMS
# video 1/1 (587/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.8ms) NMS
# video 1/1 (588/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (0.9ms) NMS
# video 1/1 (589/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (0.9ms) NMS
# video 1/1 (590/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (0.8ms) NMS
# video 1/1 (591/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (0.9ms) NMS
# video 1/1 (592/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.9ms) NMS
# video 1/1 (593/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.0ms) Inference, (0.8ms) NMS
# video 1/1 (594/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.9ms) Inference, (0.9ms) NMS
# video 1/1 (595/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.9ms) NMS
# video 1/1 (596/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.8ms) NMS
# video 1/1 (597/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.9ms) NMS
# video 1/1 (598/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.9ms) NMS
# video 1/1 (599/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.9ms) NMS
# video 1/1 (600/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.8ms) NMS
# video 1/1 (601/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.2ms) NMS
# video 1/1 (602/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.2ms) NMS
# video 1/1 (603/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.9ms) NMS
# video 1/1 (604/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (1.1ms) NMS
# video 1/1 (605/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.9ms) NMS
# video 1/1 (606/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (1.0ms) NMS
# video 1/1 (607/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.9ms) NMS
# video 1/1 (608/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (0.8ms) NMS
# video 1/1 (609/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (0.8ms) NMS
# video 1/1 (610/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.9ms) NMS
# video 1/1 (611/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.8ms) NMS
# video 1/1 (612/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (9.1ms) Inference, (0.9ms) NMS
# video 1/1 (613/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (0.9ms) NMS
# video 1/1 (614/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.9ms) NMS
# video 1/1 (615/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.9ms) Inference, (0.9ms) NMS
# video 1/1 (616/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.9ms) Inference, (0.8ms) NMS
# video 1/1 (617/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (1.1ms) NMS
# video 1/1 (618/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (1.4ms) NMS
# video 1/1 (619/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (1.6ms) NMS
# video 1/1 (620/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.2ms) NMS
# video 1/1 (621/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.2ms) NMS
# video 1/1 (622/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.9ms) NMS
# video 1/1 (623/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (10.3ms) Inference, (2.0ms) NMS
# video 1/1 (624/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.9ms) Inference, (0.9ms) NMS
# video 1/1 (625/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.9ms) NMS
# video 1/1 (626/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (9.7ms) Inference, (1.1ms) NMS
# video 1/1 (627/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (9.3ms) Inference, (1.0ms) NMS
# video 1/1 (628/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.9ms) Inference, (1.0ms) NMS
# video 1/1 (629/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.9ms) Inference, (0.9ms) NMS
# video 1/1 (630/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.9ms) NMS
# video 1/1 (631/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.9ms) NMS
# video 1/1 (632/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (0.9ms) NMS
# video 1/1 (633/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.2ms) NMS
# video 1/1 (634/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (1.2ms) NMS
# video 1/1 (635/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (0.9ms) NMS
# video 1/1 (636/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (0.9ms) NMS
# video 1/1 (637/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (0.9ms) NMS
# video 1/1 (638/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (0.8ms) NMS
# video 1/1 (639/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (0.9ms) NMS
# video 1/1 (640/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (0.9ms) NMS
# video 1/1 (641/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (0.9ms) NMS
# video 1/1 (642/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (0.9ms) NMS
# video 1/1 (643/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.2ms) Inference, (1.2ms) NMS
# video 1/1 (644/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.9ms) Inference, (0.9ms) NMS
# video 1/1 (645/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.6ms) Inference, (0.8ms) NMS
# video 1/1 (646/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.8ms) NMS
# video 1/1 (647/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (0.2ms) NMS
# video 1/1 (648/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (0.2ms) NMS
# video 1/1 (649/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (0.2ms) NMS
# video 1/1 (650/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 1 persons, Done. (7.8ms) Inference, (1.3ms) NMS
# video 1/1 (651/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (0.2ms) NMS
# video 1/1 (652/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (0.2ms) NMS
# video 1/1 (653/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (1.0ms) NMS
# video 1/1 (654/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (1.1ms) NMS
# video 1/1 (655/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (1.1ms) NMS
# video 1/1 (656/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (1.0ms) NMS
# video 1/1 (657/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (0.9ms) NMS
# video 1/1 (658/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.9ms) Inference, (0.9ms) NMS
# video 1/1 (659/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.9ms) Inference, (0.8ms) NMS
# video 1/1 (660/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.9ms) Inference, (0.8ms) NMS
# video 1/1 (661/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.9ms) Inference, (0.2ms) NMS
# video 1/1 (662/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.9ms) Inference, (0.2ms) NMS
# video 1/1 (663/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.3ms) NMS
# video 1/1 (664/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.3ms) NMS
# video 1/1 (665/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (0.9ms) NMS
# video 1/1 (666/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.9ms) NMS
# video 1/1 (667/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (0.8ms) NMS
# video 1/1 (668/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (0.8ms) NMS
# video 1/1 (669/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (0.8ms) NMS
# video 1/1 (670/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.9ms) Inference, (0.8ms) NMS
# video 1/1 (671/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.9ms) Inference, (0.9ms) NMS
# video 1/1 (672/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.9ms) Inference, (0.9ms) NMS
# video 1/1 (673/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.8ms) NMS
# video 1/1 (674/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.9ms) NMS
# video 1/1 (675/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.8ms) Inference, (1.2ms) NMS
# video 1/1 (676/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.9ms) Inference, (0.8ms) NMS
# video 1/1 (677/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (14.6ms) Inference, (1.3ms) NMS
# video 1/1 (678/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.9ms) Inference, (0.8ms) NMS
# video 1/1 (679/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (1.1ms) NMS
# video 1/1 (680/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (0.9ms) NMS
# video 1/1 (681/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (1.1ms) NMS
# video 1/1 (682/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (11.3ms) Inference, (2.3ms) NMS
# video 1/1 (683/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (14.2ms) Inference, (1.3ms) NMS
# video 1/1 (684/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (58.5ms) Inference, (1.4ms) NMS
# video 1/1 (685/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (51.5ms) Inference, (1.4ms) NMS
# video 1/1 (686/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (44.8ms) Inference, (1.4ms) NMS
# video 1/1 (687/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (9.5ms) Inference, (1.4ms) NMS
# video 1/1 (688/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (1.1ms) NMS
# video 1/1 (689/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (1.1ms) NMS
# video 1/1 (690/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.3ms) Inference, (1.1ms) NMS
# video 1/1 (691/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (1.1ms) NMS
# video 1/1 (692/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (1.0ms) NMS
# video 1/1 (693/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (1.1ms) NMS
# video 1/1 (694/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (1.0ms) NMS
# video 1/1 (695/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (12.7ms) Inference, (1.1ms) NMS
# video 1/1 (696/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (1.1ms) NMS
# video 1/1 (697/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (1.1ms) NMS
# video 1/1 (698/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.2ms) Inference, (1.0ms) NMS
# video 1/1 (699/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (1.1ms) NMS
# video 1/1 (700/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 1 persons, Done. (7.7ms) Inference, (1.5ms) NMS
# video 1/1 (701/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (11.4ms) Inference, (1.3ms) NMS
# video 1/1 (702/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (1.2ms) NMS
# video 1/1 (703/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (1.1ms) NMS
# video 1/1 (704/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (16.1ms) Inference, (1.0ms) NMS
# video 1/1 (705/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (1.0ms) NMS
# video 1/1 (706/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (11.3ms) Inference, (1.0ms) NMS
# video 1/1 (707/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (9.2ms) Inference, (1.2ms) NMS
# video 1/1 (708/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (17.0ms) Inference, (1.2ms) NMS
# video 1/1 (709/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (14.9ms) Inference, (1.2ms) NMS
# video 1/1 (710/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (1.1ms) NMS
# video 1/1 (711/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (1.0ms) NMS
# video 1/1 (712/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (1.0ms) NMS
# video 1/1 (713/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (9.3ms) Inference, (1.3ms) NMS
# video 1/1 (714/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (9.0ms) Inference, (2.0ms) NMS
# video 1/1 (715/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (1.0ms) NMS
# video 1/1 (716/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (1.1ms) NMS
# video 1/1 (717/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (9.2ms) Inference, (1.3ms) NMS
# video 1/1 (718/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.5ms) Inference, (1.0ms) NMS
# video 1/1 (719/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.3ms) Inference, (1.4ms) NMS
# video 1/1 (720/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (11.1ms) Inference, (1.4ms) NMS
# video 1/1 (721/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.9ms) Inference, (3.0ms) NMS
# video 1/1 (722/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.6ms) Inference, (1.1ms) NMS
# video 1/1 (723/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (11.1ms) Inference, (1.4ms) NMS
# video 1/1 (724/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.4ms) Inference, (1.2ms) NMS
# video 1/1 (725/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (13.3ms) Inference, (1.4ms) NMS
# video 1/1 (726/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.4ms) Inference, (1.3ms) NMS
# video 1/1 (727/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (9.5ms) Inference, (1.3ms) NMS
# video 1/1 (728/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.2ms) Inference, (1.0ms) NMS
# video 1/1 (729/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (1.1ms) NMS
# video 1/1 (730/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (10.2ms) Inference, (1.3ms) NMS
# video 1/1 (731/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.9ms) Inference, (1.2ms) NMS
# video 1/1 (732/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (1.1ms) NMS
# video 1/1 (733/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (1.0ms) NMS
# video 1/1 (734/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (1.3ms) NMS
# video 1/1 (735/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (9.2ms) Inference, (1.3ms) NMS
# video 1/1 (736/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.7ms) Inference, (1.1ms) NMS
# video 1/1 (737/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.4ms) Inference, (1.1ms) NMS
# video 1/1 (738/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.3ms) Inference, (1.2ms) NMS
# video 1/1 (739/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.4ms) Inference, (1.1ms) NMS
# video 1/1 (740/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.3ms) Inference, (1.1ms) NMS
# video 1/1 (741/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.3ms) Inference, (1.1ms) NMS
# video 1/1 (742/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.3ms) Inference, (1.1ms) NMS
# video 1/1 (743/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.3ms) Inference, (1.1ms) NMS
# video 1/1 (744/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.3ms) Inference, (1.1ms) NMS
# video 1/1 (745/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 1 persons, Done. (8.3ms) Inference, (1.6ms) NMS
# video 1/1 (746/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 1 persons, Done. (9.7ms) Inference, (1.5ms) NMS
# video 1/1 (747/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (9.4ms) Inference, (1.0ms) NMS
# video 1/1 (748/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (10.5ms) Inference, (1.1ms) NMS
# video 1/1 (749/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.3ms) Inference, (1.1ms) NMS
# video 1/1 (750/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (13.0ms) Inference, (1.1ms) NMS
# video 1/1 (751/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (11.8ms) Inference, (1.1ms) NMS
# video 1/1 (752/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.5ms) Inference, (3.9ms) NMS
# video 1/1 (753/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.5ms) Inference, (1.2ms) NMS
# video 1/1 (754/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.5ms) Inference, (1.0ms) NMS
# video 1/1 (755/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.6ms) Inference, (1.0ms) NMS
# video 1/1 (756/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.5ms) Inference, (1.0ms) NMS
# video 1/1 (757/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (9.2ms) Inference, (1.1ms) NMS
# video 1/1 (758/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.4ms) Inference, (1.0ms) NMS
# video 1/1 (759/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.4ms) Inference, (1.1ms) NMS
# video 1/1 (760/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.4ms) Inference, (1.1ms) NMS
# video 1/1 (761/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.5ms) Inference, (1.1ms) NMS
# video 1/1 (762/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.6ms) Inference, (1.1ms) NMS
# video 1/1 (763/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.6ms) Inference, (1.0ms) NMS
# video 1/1 (764/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.6ms) Inference, (1.1ms) NMS
# video 1/1 (765/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.6ms) Inference, (1.0ms) NMS
# video 1/1 (766/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (9.0ms) Inference, (1.1ms) NMS
# video 1/1 (767/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (10.6ms) Inference, (1.0ms) NMS
# video 1/1 (768/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.5ms) Inference, (1.0ms) NMS
# video 1/1 (769/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.5ms) Inference, (1.3ms) NMS
# video 1/1 (770/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.5ms) Inference, (1.0ms) NMS
# video 1/1 (771/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.5ms) Inference, (1.1ms) NMS
# video 1/1 (772/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.5ms) Inference, (1.3ms) NMS
# video 1/1 (773/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (9.2ms) Inference, (1.3ms) NMS
# video 1/1 (774/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.8ms) Inference, (1.3ms) NMS
# video 1/1 (775/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.5ms) Inference, (1.2ms) NMS
# video 1/1 (776/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (9.0ms) Inference, (1.2ms) NMS
# video 1/1 (777/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 3 persons, Done. (9.2ms) Inference, (1.8ms) NMS
# video 1/1 (778/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 3 persons, Done. (15.3ms) Inference, (7.1ms) NMS
# video 1/1 (779/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 3 persons, Done. (15.5ms) Inference, (1.5ms) NMS
# video 1/1 (780/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 3 persons, Done. (9.8ms) Inference, (1.8ms) NMS
# video 1/1 (781/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 3 persons, Done. (11.1ms) Inference, (2.1ms) NMS
# video 1/1 (782/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 3 persons, Done. (12.5ms) Inference, (1.4ms) NMS
# video 1/1 (783/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 3 persons, Done. (14.1ms) Inference, (2.9ms) NMS
# video 1/1 (784/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (15.9ms) Inference, (1.4ms) NMS
# video 1/1 (785/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (2.0ms) NMS
# video 1/1 (786/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (787/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.5ms) NMS
# video 1/1 (788/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (2.0ms) NMS
# video 1/1 (789/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.6ms) NMS
# video 1/1 (790/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (791/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (792/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.3ms) NMS
# video 1/1 (793/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.3ms) NMS
# video 1/1 (794/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (795/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (796/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (797/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.5ms) NMS
# video 1/1 (798/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.3ms) Inference, (1.6ms) NMS
# video 1/1 (799/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (800/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.3ms) Inference, (1.4ms) NMS
# video 1/1 (801/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (802/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.9ms) NMS
# video 1/1 (803/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (804/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (805/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.3ms) NMS
# video 1/1 (806/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.5ms) NMS
# video 1/1 (807/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (808/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.5ms) Inference, (1.6ms) NMS
# video 1/1 (809/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.3ms) Inference, (1.5ms) NMS
# video 1/1 (810/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.9ms) Inference, (1.9ms) NMS
# video 1/1 (811/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.7ms) NMS
# video 1/1 (812/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.7ms) NMS
# video 1/1 (813/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.3ms) Inference, (3.4ms) NMS
# video 1/1 (814/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.3ms) Inference, (4.0ms) NMS
# video 1/1 (815/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.9ms) NMS
# video 1/1 (816/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (2.0ms) NMS
# video 1/1 (817/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (818/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.3ms) Inference, (1.8ms) NMS
# video 1/1 (819/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (820/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (821/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (822/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.5ms) NMS
# video 1/1 (823/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (824/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.8ms) NMS
# video 1/1 (825/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.5ms) NMS
# video 1/1 (826/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.3ms) Inference, (1.4ms) NMS
# video 1/1 (827/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (828/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.3ms) Inference, (1.4ms) NMS
# video 1/1 (829/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (830/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.3ms) Inference, (1.4ms) NMS
# video 1/1 (831/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (832/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 3 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (833/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (834/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (835/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (836/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (837/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.5ms) NMS
# video 1/1 (838/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (23.3ms) Inference, (2.1ms) NMS
# video 1/1 (839/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (840/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.5ms) NMS
# video 1/1 (841/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (842/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.5ms) NMS
# video 1/1 (843/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (844/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.9ms) NMS
# video 1/1 (845/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (846/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.7ms) NMS
# video 1/1 (847/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (2.2ms) NMS
# video 1/1 (848/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.3ms) Inference, (2.0ms) NMS
# video 1/1 (849/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 3 persons, Done. (16.2ms) Inference, (1.8ms) NMS
# video 1/1 (850/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 3 persons, Done. (16.2ms) Inference, (1.7ms) NMS
# video 1/1 (851/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.3ms) Inference, (2.2ms) NMS
# video 1/1 (852/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.3ms) Inference, (2.3ms) NMS
# video 1/1 (853/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.5ms) NMS
# video 1/1 (854/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (855/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (2.0ms) NMS
# video 1/1 (856/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (857/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.3ms) NMS
# video 1/1 (858/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 2 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (859/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 3 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (860/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 3 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (861/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 3 persons, Done. (16.3ms) Inference, (1.4ms) NMS
# video 1/1 (862/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 3 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (863/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 3 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (864/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (865/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 3 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (866/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.2ms) Inference, (1.6ms) NMS
# video 1/1 (867/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (868/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (869/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (870/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (871/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (872/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.3ms) Inference, (1.4ms) NMS
# video 1/1 (873/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (874/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.3ms) Inference, (1.6ms) NMS
# video 1/1 (875/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (876/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (877/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (878/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (879/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.2ms) Inference, (1.5ms) NMS
# video 1/1 (880/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.2ms) Inference, (2.1ms) NMS
# video 1/1 (881/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.2ms) Inference, (1.8ms) NMS
# video 1/1 (882/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.2ms) Inference, (1.9ms) NMS
# video 1/1 (883/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.3ms) Inference, (1.8ms) NMS
# video 1/1 (884/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.2ms) Inference, (1.7ms) NMS
# video 1/1 (885/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.2ms) Inference, (4.3ms) NMS
# video 1/1 (886/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.2ms) Inference, (1.9ms) NMS
# video 1/1 (887/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.2ms) Inference, (2.0ms) NMS
# video 1/1 (888/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (889/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (890/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 5 persons, Done. (16.2ms) Inference, (2.6ms) NMS
# video 1/1 (891/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 5 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (892/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 5 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (893/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (894/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (895/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (896/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.2ms) Inference, (1.5ms) NMS
# video 1/1 (897/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.2ms) Inference, (1.5ms) NMS
# video 1/1 (898/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.2ms) Inference, (1.8ms) NMS
# video 1/1 (899/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 5 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (900/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.3ms) Inference, (1.4ms) NMS
# video 1/1 (901/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.2ms) Inference, (1.5ms) NMS
# video 1/1 (902/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (903/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 5 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (904/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (905/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 5 persons, Done. (16.2ms) Inference, (2.0ms) NMS
# video 1/1 (906/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 5 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (907/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 5 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (908/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 5 persons, Done. (16.2ms) Inference, (1.6ms) NMS
# video 1/1 (909/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 5 persons, Done. (16.2ms) Inference, (1.5ms) NMS
# video 1/1 (910/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 6 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (911/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 5 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (912/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 5 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (913/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 5 persons, Done. (16.2ms) Inference, (1.7ms) NMS
# video 1/1 (914/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 6 persons, Done. (16.2ms) Inference, (2.1ms) NMS
# video 1/1 (915/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 5 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (916/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.2ms) Inference, (1.7ms) NMS
# video 1/1 (917/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 5 persons, Done. (16.2ms) Inference, (3.6ms) NMS
# video 1/1 (918/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 4 persons, Done. (16.2ms) Inference, (1.7ms) NMS
# video 1/1 (919/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 6 persons, Done. (16.2ms) Inference, (1.7ms) NMS
# video 1/1 (920/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 6 persons, Done. (16.2ms) Inference, (2.1ms) NMS
# video 1/1 (921/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 6 persons, Done. (17.5ms) Inference, (6.7ms) NMS
# video 1/1 (922/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 6 persons, Done. (16.2ms) Inference, (2.0ms) NMS
# video 1/1 (923/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 6 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (924/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 7 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (925/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 7 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# video 1/1 (926/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: 6 persons, Done. (16.2ms) Inference, (1.4ms) NMS
# ...
# video 1/1 (5440/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (9.3ms) Inference, (0.3ms) NMS
# video 1/1 (5441/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.9ms) Inference, (0.2ms) NMS
# video 1/1 (5442/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.3ms) NMS
# video 1/1 (5443/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.0ms) Inference, (0.3ms) NMS
# video 1/1 (5444/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (9.6ms) Inference, (0.4ms) NMS
# video 1/1 (5445/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.4ms) Inference, (0.3ms) NMS
# video 1/1 (5446/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.6ms) Inference, (0.2ms) NMS
# video 1/1 (5447/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.4ms) Inference, (0.2ms) NMS
# video 1/1 (5448/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.6ms) Inference, (0.2ms) NMS
# video 1/1 (5449/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.6ms) Inference, (0.2ms) NMS
# video 1/1 (5450/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.4ms) Inference, (0.2ms) NMS
# video 1/1 (5451/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.4ms) Inference, (0.3ms) NMS
# video 1/1 (5452/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.1ms) Inference, (0.2ms) NMS
# video 1/1 (5453/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.1ms) Inference, (0.2ms) NMS
# video 1/1 (5454/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.4ms) Inference, (0.2ms) NMS
# video 1/1 (5455/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.5ms) Inference, (0.2ms) NMS
# video 1/1 (5456/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.4ms) Inference, (0.9ms) NMS
# video 1/1 (5457/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.2ms) Inference, (0.3ms) NMS
# video 1/1 (5458/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.1ms) Inference, (1.0ms) NMS
# video 1/1 (5459/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.1ms) Inference, (0.2ms) NMS
# video 1/1 (5460/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.0ms) Inference, (0.2ms) NMS
# video 1/1 (5461/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (9.1ms) Inference, (0.9ms) NMS
# video 1/1 (5462/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.0ms) Inference, (0.9ms) NMS
# video 1/1 (5463/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.9ms) Inference, (0.9ms) NMS
# video 1/1 (5464/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.4ms) Inference, (0.9ms) NMS
# video 1/1 (5465/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.7ms) Inference, (1.0ms) NMS
# video 1/1 (5466/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.7ms) Inference, (1.0ms) NMS
# video 1/1 (5467/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.6ms) Inference, (1.4ms) NMS
# video 1/1 (5468/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.4ms) Inference, (1.1ms) NMS
# video 1/1 (5469/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.3ms) Inference, (0.9ms) NMS
# video 1/1 (5470/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.2ms) Inference, (0.3ms) NMS
# video 1/1 (5471/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.2ms) Inference, (0.9ms) NMS
# video 1/1 (5472/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.1ms) Inference, (0.4ms) NMS
# video 1/1 (5473/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.9ms) Inference, (0.3ms) NMS
# video 1/1 (5474/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.9ms) Inference, (0.9ms) NMS
# video 1/1 (5475/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.2ms) NMS
# video 1/1 (5476/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.2ms) Inference, (0.2ms) NMS
# video 1/1 (5477/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.6ms) Inference, (0.2ms) NMS
# video 1/1 (5478/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.9ms) Inference, (0.2ms) NMS
# video 1/1 (5479/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.8ms) Inference, (1.0ms) NMS
# video 1/1 (5480/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.4ms) Inference, (0.9ms) NMS
# video 1/1 (5481/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.2ms) Inference, (0.9ms) NMS
# video 1/1 (5482/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.0ms) Inference, (0.2ms) NMS
# video 1/1 (5483/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.9ms) Inference, (1.0ms) NMS
# video 1/1 (5484/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (11.0ms) Inference, (1.0ms) NMS
# video 1/1 (5485/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.9ms) Inference, (0.9ms) NMS
# video 1/1 (5486/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.9ms) NMS
# video 1/1 (5487/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.0ms) Inference, (1.0ms) NMS
# video 1/1 (5488/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.8ms) Inference, (1.0ms) NMS
# video 1/1 (5489/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.9ms) Inference, (1.0ms) NMS
# video 1/1 (5490/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.7ms) Inference, (1.0ms) NMS
# video 1/1 (5491/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.4ms) Inference, (0.9ms) NMS
# video 1/1 (5492/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.3ms) Inference, (1.0ms) NMS
# video 1/1 (5493/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.2ms) Inference, (1.0ms) NMS
# video 1/1 (5494/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.4ms) Inference, (0.9ms) NMS
# video 1/1 (5495/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.7ms) Inference, (1.0ms) NMS
# video 1/1 (5496/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.5ms) Inference, (0.9ms) NMS
# video 1/1 (5497/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.4ms) Inference, (0.9ms) NMS
# video 1/1 (5498/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.2ms) Inference, (0.9ms) NMS
# video 1/1 (5499/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.2ms) Inference, (0.9ms) NMS
# video 1/1 (5500/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.1ms) Inference, (0.9ms) NMS
# video 1/1 (5501/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (18.2ms) Inference, (2.2ms) NMS
# video 1/1 (5502/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (9.3ms) Inference, (1.5ms) NMS
# video 1/1 (5503/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.9ms) Inference, (0.9ms) NMS
# video 1/1 (5504/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.9ms) Inference, (0.9ms) NMS
# video 1/1 (5505/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.8ms) Inference, (0.9ms) NMS
# video 1/1 (5506/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.4ms) Inference, (0.9ms) NMS
# video 1/1 (5507/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.8ms) Inference, (0.9ms) NMS
# video 1/1 (5508/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.8ms) Inference, (1.4ms) NMS
# video 1/1 (5509/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.5ms) Inference, (0.9ms) NMS
# video 1/1 (5510/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.3ms) Inference, (0.9ms) NMS
# video 1/1 (5511/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.2ms) Inference, (0.9ms) NMS
# video 1/1 (5512/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.3ms) Inference, (1.1ms) NMS
# video 1/1 (5513/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.3ms) Inference, (0.9ms) NMS
# video 1/1 (5514/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.6ms) Inference, (0.9ms) NMS
# video 1/1 (5515/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.6ms) Inference, (1.0ms) NMS
# video 1/1 (5516/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.4ms) Inference, (0.9ms) NMS
# video 1/1 (5517/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.3ms) Inference, (1.0ms) NMS
# video 1/1 (5518/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.2ms) Inference, (0.9ms) NMS
# video 1/1 (5519/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.2ms) Inference, (1.0ms) NMS
# video 1/1 (5520/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.1ms) Inference, (0.9ms) NMS
# video 1/1 (5521/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.4ms) Inference, (1.0ms) NMS
# video 1/1 (5522/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.5ms) Inference, (0.9ms) NMS
# video 1/1 (5523/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.4ms) Inference, (0.9ms) NMS
# video 1/1 (5524/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.3ms) Inference, (1.0ms) NMS
# video 1/1 (5525/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.1ms) Inference, (0.9ms) NMS
# video 1/1 (5526/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.2ms) Inference, (1.0ms) NMS
# video 1/1 (5527/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.5ms) Inference, (0.9ms) NMS
# video 1/1 (5528/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.5ms) Inference, (0.9ms) NMS
# video 1/1 (5529/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.4ms) Inference, (1.4ms) NMS
# video 1/1 (5530/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.2ms) Inference, (1.0ms) NMS
# video 1/1 (5531/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.0ms) Inference, (0.9ms) NMS
# video 1/1 (5532/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.0ms) Inference, (0.9ms) NMS
# video 1/1 (5533/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (10.0ms) Inference, (1.1ms) NMS
# video 1/1 (5534/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.5ms) Inference, (0.9ms) NMS
# video 1/1 (5535/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.8ms) Inference, (1.0ms) NMS
# video 1/1 (5536/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.6ms) Inference, (0.9ms) NMS
# video 1/1 (5537/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.4ms) Inference, (1.4ms) NMS
# video 1/1 (5538/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (9.5ms) Inference, (1.0ms) NMS
# video 1/1 (5539/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.6ms) Inference, (1.3ms) NMS
# video 1/1 (5540/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.9ms) Inference, (0.9ms) NMS
# video 1/1 (5541/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.1ms) Inference, (0.9ms) NMS
# video 1/1 (5542/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.6ms) Inference, (0.9ms) NMS
# video 1/1 (5543/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.6ms) Inference, (0.9ms) NMS
# video 1/1 (5544/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.4ms) Inference, (1.0ms) NMS
# video 1/1 (5545/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.2ms) Inference, (0.9ms) NMS
# video 1/1 (5546/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.2ms) Inference, (1.4ms) NMS
# video 1/1 (5547/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.2ms) Inference, (1.2ms) NMS
# video 1/1 (5548/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.1ms) Inference, (1.0ms) NMS
# video 1/1 (5549/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.1ms) Inference, (0.9ms) NMS
# video 1/1 (5550/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.6ms) Inference, (0.9ms) NMS
# video 1/1 (5551/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.6ms) Inference, (1.0ms) NMS
# video 1/1 (5552/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.4ms) Inference, (0.9ms) NMS
# video 1/1 (5553/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.4ms) Inference, (1.1ms) NMS
# video 1/1 (5554/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.2ms) Inference, (0.9ms) NMS
# video 1/1 (5555/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.5ms) Inference, (0.9ms) NMS
# video 1/1 (5556/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.5ms) Inference, (0.9ms) NMS
# video 1/1 (5557/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.8ms) Inference, (1.1ms) NMS
# video 1/1 (5558/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.7ms) Inference, (0.9ms) NMS
# video 1/1 (5559/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.5ms) Inference, (0.9ms) NMS
# video 1/1 (5560/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.3ms) Inference, (1.3ms) NMS
# video 1/1 (5561/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (9.3ms) Inference, (1.2ms) NMS
# video 1/1 (5562/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (8.0ms) Inference, (1.0ms) NMS
# video 1/1 (5563/5563) /content/drive/MyDrive/COLAB/testSys-LSH0568/INPUT/case4_Y2meta.mp4: Done. (7.9ms) Inference, (0.9ms) NMS
# Done. (315.742s)
