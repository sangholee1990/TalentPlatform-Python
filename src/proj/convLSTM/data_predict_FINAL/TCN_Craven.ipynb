# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tcn import TCN # main library
import math
from sklearn.preprocessing import RobustScaler
#from keras.initializers import  glorot_normal, RandomUniform
#from keras import optimizers,regularizers

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import load_model 
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
df = pd.read_csv("station_bike _Craven.csv")
df["timestamp"] = pd.to_datetime(df["timestamp"])
df = df.set_index("timestamp")
#df.head()

df["hour"] = df.index.hour
df["day_of_month"] = df.index.day
df["day_of_week"]  = df.index.dayofweek
df["month"] = df.index.month

training_data_len = math.ceil(len(df) * 0.9) # taking 90% of data to train and 10% of data to test
testing_data_len = len(df) - training_data_len

time_steps = 24
train, test = df.iloc[0:training_data_len], df.iloc[(training_data_len-time_steps):len(df)]
print(df.shape, train.shape, test.shape)

train_trans = train[['t1','t2', 'hum', 'wind_speed']].to_numpy()
test_trans = test[['t1','t2', 'hum', 'wind_speed']].to_numpy()

scaler = RobustScaler() # Handles outliers
train.loc[:, ['t1','t2','hum', 'wind_speed']]=scaler.fit_transform(train_trans)
test.loc[:, ['t1','t2', 'hum', 'wind_speed']]=scaler.fit_transform(test_trans)

train['cnt'] = scaler.fit_transform(train[['cnt']])
test['cnt'] = scaler.fit_transform(test[['cnt']])

from tqdm import tqdm_notebook as tqdm

#Split the data into x_train and y_train data sets
x_train = []
y_train = []

for i in tqdm(range(len(train) - time_steps)):
    x_train.append(train.drop(columns='cnt').iloc[i:i + time_steps].to_numpy())
    y_train.append(train.loc[:,'cnt'].iloc[i + time_steps])

#Convert x_train and y_train to numpy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

#Create the x_test and y_test data sets
x_test = []
y_test = df.loc[:,'cnt'].iloc[training_data_len:len(df)]

for i in tqdm(range(len(test) - time_steps)):
    x_test.append(test.drop(columns='cnt').iloc[i:i + time_steps].to_numpy())
    # y_test.append(test.loc[:,'cnt'].iloc[i + time_steps])

#Convert x_test and y_test to numpy arrays
x_test = np.array(x_test)
y_test = np.array(y_test)

# All 12 columns of the data
print('Train size:')
print(x_train.shape, y_train.shape)
print('Test size:')
print(x_test.shape, y_test.shape)
# Out:
# (160, 13) (144, 13) (40, 13)
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:34: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/120 [00:00<?, ?it/s]
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:46: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/16 [00:00<?, ?it/s]
# Train size:
# (120, 24, 12) (120,)
# Test size:
# (16, 24, 12) (16,)

# %%
#init = glorot_normal(seed=None) # 給 LSTM
#init_d = RandomUniform(minval=-0.05, maxval=0.05) # 給 Dense layer
#nadam = optimizers.Nadam(lr=0.002,clipvalue=0.5)
from tensorflow.keras.initializers import RandomUniform
init_d = RandomUniform(minval=-0.05, maxval=0.05) # 給 Dense layer
model = Sequential()
model.add(TCN(input_shape=(x_train.shape[1],x_train.shape[2]),
        kernel_size=3,
        nb_filters=25,
        nb_stacks=1,
        dilations=(1, 2, 4, 8),
        kernel_initializer='glorot_uniform',
        use_skip_connections=True,
        use_batch_norm=False,
        use_weight_norm=False,
        use_layer_norm=True,
        dropout_rate = 0.05,
        return_sequences=True
        ))
model.add(Dropout(0.5))
model.add(TCN(
        kernel_size=3,
        nb_filters=25,
        nb_stacks=1,
        dilations=(1, 2, 4, 8),
        kernel_initializer='glorot_uniform',
        use_skip_connections=True,
        use_batch_norm=False,
        use_weight_norm=False,
        use_layer_norm=True,
        dropout_rate = 0.05,
        return_sequences=False
        ))  
model.add(Dropout(0.3))
model.add(Dense(1,kernel_initializer=init_d))  
model.summary()

print('Train...')
model.compile(optimizer = "nadam" , loss="mse")
history = model.fit(x_train, y_train, epochs=120, batch_size=12, validation_split=0.1, shuffle=True)
#Save Model
model.save('TCN_model_craven.h5')  # creates a HDF5 file 
del model

custom_ob = {'TCN': TCN}
# model = load_model('TCN_model_1.h5', custom_objects=custom_ob)
model = load_model('TCN_model_craven.h5', custom_objects=custom_ob)
print('Load Success')

import time
t1 = time.time()
y_pred = model.predict(x_test)
t2 = time.time()
print('Predict time: ',t2-t1)
y_pred = scaler.inverse_transform(y_pred)#Undo scaling

from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error
rmse_lstm = np.sqrt(mean_squared_error(y_test, y_pred))
print('RMSE: ',rmse_lstm)

mae = mean_absolute_error(y_test, y_pred)
print('MAE: ',mae)

r2 =  r2_score(y_test, y_pred)
print('R-square: ',r2)

n = len(y_test)
p = 12
Adj_r2 = 1-(1-r2)*(n-1)/(n-p-1)
print('Adj R-square: ',Adj_r2)

plt.plot(history.history["loss"],label="loss")
plt.plot(history.history["val_loss"],label="val_loss")
plt.legend(loc="best")
plt.xlabel("No. Of Epochs")
plt.ylabel("mse score")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# tcn_4 (TCN)                  (None, 24, 25)            14950
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 24, 25)            0
# _________________________________________________________________
# tcn_5 (TCN)                  (None, 25)                15600
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 25)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 26
# =================================================================
# Total params: 30,576
# Trainable params: 30,576
# Non-trainable params: 0
# _________________________________________________________________
# Train...
# Train on 108 samples, validate on 12 samples
# Epoch 1/120
# 108/108 [==============================] - 6s 58ms/sample - loss: 0.8823 - val_loss: 0.8627
# Epoch 2/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.8760 - val_loss: 0.8373
# Epoch 3/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.8385 - val_loss: 0.8220
# Epoch 4/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.7678 - val_loss: 0.7741
# Epoch 5/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.8630 - val_loss: 0.7463
# Epoch 6/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.7537 - val_loss: 0.6860
# Epoch 7/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.7211 - val_loss: 0.6360
# Epoch 8/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.6703 - val_loss: 0.6208
# Epoch 9/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.5926 - val_loss: 0.6094
# Epoch 10/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.5316 - val_loss: 0.5374
# Epoch 11/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4651 - val_loss: 0.5168
# Epoch 12/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.5519 - val_loss: 0.4978
# Epoch 13/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4709 - val_loss: 0.4868
# Epoch 14/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4767 - val_loss: 0.4178
# Epoch 15/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4015 - val_loss: 0.5072
# Epoch 16/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4161 - val_loss: 0.4642
# Epoch 17/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3532 - val_loss: 0.4161
# Epoch 18/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3861 - val_loss: 0.3905
# Epoch 19/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3525 - val_loss: 0.3868
# Epoch 20/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3267 - val_loss: 0.3594
# Epoch 21/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2958 - val_loss: 0.3367
# Epoch 22/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3464 - val_loss: 0.3420
# Epoch 23/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3400 - val_loss: 0.3592
# Epoch 24/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3598 - val_loss: 0.3059
# Epoch 25/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2724 - val_loss: 0.2972
# Epoch 26/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2134 - val_loss: 0.2414
# Epoch 27/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3212 - val_loss: 0.2752
# Epoch 28/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2331 - val_loss: 0.2636
# Epoch 29/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3125 - val_loss: 0.3197
# Epoch 30/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2124 - val_loss: 0.2723
# Epoch 31/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2489 - val_loss: 0.2123
# Epoch 32/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2505 - val_loss: 0.2359
# Epoch 33/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3104 - val_loss: 0.2513
# Epoch 34/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2151 - val_loss: 0.2348
# Epoch 35/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2217 - val_loss: 0.2451
# Epoch 36/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2093 - val_loss: 0.2308
# Epoch 37/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1644 - val_loss: 0.2363
# Epoch 38/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2450 - val_loss: 0.2431
# Epoch 39/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1384 - val_loss: 0.2157
# Epoch 40/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2394 - val_loss: 0.2610
# Epoch 41/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1809 - val_loss: 0.2634
# Epoch 42/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2162 - val_loss: 0.2708
# Epoch 43/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2367 - val_loss: 0.2749
# Epoch 44/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1897 - val_loss: 0.2819
# Epoch 45/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2163 - val_loss: 0.2555
# Epoch 46/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2227 - val_loss: 0.2689
# Epoch 47/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1892 - val_loss: 0.2536
# Epoch 48/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2147 - val_loss: 0.2210
# Epoch 49/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2096 - val_loss: 0.2181
# Epoch 50/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2318 - val_loss: 0.2306
# Epoch 51/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1921 - val_loss: 0.1990
# Epoch 52/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1660 - val_loss: 0.2303
# Epoch 53/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1794 - val_loss: 0.2300
# Epoch 54/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2040 - val_loss: 0.2262
# Epoch 55/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1884 - val_loss: 0.2259
# Epoch 56/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2016 - val_loss: 0.2146
# Epoch 57/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1692 - val_loss: 0.2250
# Epoch 58/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1510 - val_loss: 0.2181
# Epoch 59/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1913 - val_loss: 0.1827
# Epoch 60/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2158 - val_loss: 0.2013
# Epoch 61/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1728 - val_loss: 0.1959
# Epoch 62/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1819 - val_loss: 0.2121
# Epoch 63/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1853 - val_loss: 0.2221
# Epoch 64/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1769 - val_loss: 0.2350
# Epoch 65/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1996 - val_loss: 0.2180
# Epoch 66/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1392 - val_loss: 0.2082
# Epoch 67/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1647 - val_loss: 0.1926
# Epoch 68/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1684 - val_loss: 0.2038
# Epoch 69/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1672 - val_loss: 0.1996
# Epoch 70/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1527 - val_loss: 0.2077
# Epoch 71/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1863 - val_loss: 0.2094
# Epoch 72/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1641 - val_loss: 0.2345
# Epoch 73/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1579 - val_loss: 0.2786
# Epoch 74/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2059 - val_loss: 0.2823
# Epoch 75/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1656 - val_loss: 0.2838
# Epoch 76/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1606 - val_loss: 0.2491
# Epoch 77/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1955 - val_loss: 0.2361
# Epoch 78/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1247 - val_loss: 0.2393
# Epoch 79/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1272 - val_loss: 0.2237
# Epoch 80/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1590 - val_loss: 0.2251
# Epoch 81/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1397 - val_loss: 0.2311
# Epoch 82/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1427 - val_loss: 0.2279
# Epoch 83/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1908 - val_loss: 0.2193
# Epoch 84/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1453 - val_loss: 0.1940
# Epoch 85/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1575 - val_loss: 0.2020
# Epoch 86/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1828 - val_loss: 0.2049
# Epoch 87/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1276 - val_loss: 0.2135
# Epoch 88/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1470 - val_loss: 0.2227
# Epoch 89/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1204 - val_loss: 0.2084
# Epoch 90/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1459 - val_loss: 0.2037
# Epoch 91/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1585 - val_loss: 0.2093
# Epoch 92/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1502 - val_loss: 0.2157
# Epoch 93/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1664 - val_loss: 0.2015
# Epoch 94/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1246 - val_loss: 0.1963
# Epoch 95/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1550 - val_loss: 0.1960
# Epoch 96/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1213 - val_loss: 0.2029
# Epoch 97/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1677 - val_loss: 0.1708
# Epoch 98/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1581 - val_loss: 0.1934
# Epoch 99/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1308 - val_loss: 0.1944
# Epoch 100/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1211 - val_loss: 0.2083
# Epoch 101/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1343 - val_loss: 0.2074
# Epoch 102/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1636 - val_loss: 0.2145
# Epoch 103/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1372 - val_loss: 0.2224
# Epoch 104/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1559 - val_loss: 0.2145
# Epoch 105/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1677 - val_loss: 0.2365
# Epoch 106/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1375 - val_loss: 0.2021
# Epoch 107/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1672 - val_loss: 0.2079
# Epoch 108/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1133 - val_loss: 0.2216
# Epoch 109/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1157 - val_loss: 0.2216
# Epoch 110/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1332 - val_loss: 0.2107
# Epoch 111/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1284 - val_loss: 0.2072
# Epoch 112/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1373 - val_loss: 0.2191
# Epoch 113/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1108 - val_loss: 0.2551
# Epoch 114/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1098 - val_loss: 0.2536
# Epoch 115/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1335 - val_loss: 0.2595
# Epoch 116/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1260 - val_loss: 0.2521
# Epoch 117/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1313 - val_loss: 0.2262
# Epoch 118/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1207 - val_loss: 0.2197
# Epoch 119/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1364 - val_loss: 0.2153
# Epoch 120/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1497 - val_loss: 0.2168
# Load Success
# Predict time:  0.7280528545379639
# RMSE:  14.3533644501636
# MAE:  10.328970938920975
# R-square:  -2.4846965435110913
# Adj R-square:  -16.423482717555455
# Text(0, 0.5, 'mse score')
