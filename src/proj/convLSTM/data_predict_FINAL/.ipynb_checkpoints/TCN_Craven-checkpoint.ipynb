# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tcn import TCN # main library
import math
from sklearn.preprocessing import RobustScaler
#from keras.initializers import  glorot_normal, RandomUniform
#from keras import optimizers,regularizers

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import load_model 
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
df = pd.read_csv("station_bike _Craven.csv")
df["timestamp"] = pd.to_datetime(df["timestamp"])
df = df.set_index("timestamp")
#df.head()

df["hour"] = df.index.hour
df["day_of_month"] = df.index.day
df["day_of_week"]  = df.index.dayofweek
df["month"] = df.index.month

training_data_len = math.ceil(len(df) * 0.9) # taking 90% of data to train and 10% of data to test
testing_data_len = len(df) - training_data_len

time_steps = 24
train, test = df.iloc[0:training_data_len], df.iloc[(training_data_len-time_steps):len(df)]
print(df.shape, train.shape, test.shape)

train_trans = train[['t1','t2', 'hum', 'wind_speed']].to_numpy()
test_trans = test[['t1','t2', 'hum', 'wind_speed']].to_numpy()

scaler = RobustScaler() # Handles outliers
train.loc[:, ['t1','t2','hum', 'wind_speed']]=scaler.fit_transform(train_trans)
test.loc[:, ['t1','t2', 'hum', 'wind_speed']]=scaler.fit_transform(test_trans)

train['cnt'] = scaler.fit_transform(train[['cnt']])
test['cnt'] = scaler.fit_transform(test[['cnt']])

from tqdm import tqdm_notebook as tqdm

#Split the data into x_train and y_train data sets
x_train = []
y_train = []

for i in tqdm(range(len(train) - time_steps)):
    x_train.append(train.drop(columns='cnt').iloc[i:i + time_steps].to_numpy())
    y_train.append(train.loc[:,'cnt'].iloc[i + time_steps])

#Convert x_train and y_train to numpy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

#Create the x_test and y_test data sets
x_test = []
y_test = df.loc[:,'cnt'].iloc[training_data_len:len(df)]

for i in tqdm(range(len(test) - time_steps)):
    x_test.append(test.drop(columns='cnt').iloc[i:i + time_steps].to_numpy())
    # y_test.append(test.loc[:,'cnt'].iloc[i + time_steps])

#Convert x_test and y_test to numpy arrays
x_test = np.array(x_test)
y_test = np.array(y_test)

# All 12 columns of the data
print('Train size:')
print(x_train.shape, y_train.shape)
print('Test size:')
print(x_test.shape, y_test.shape)
# Out:
# (160, 13) (144, 13) (40, 13)
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:34: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/120 [00:00<?, ?it/s]
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:46: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/16 [00:00<?, ?it/s]
# Train size:
# (120, 24, 12) (120,)
# Test size:
# (16, 24, 12) (16,)

# %%
#init = glorot_normal(seed=None) # 給 LSTM
#init_d = RandomUniform(minval=-0.05, maxval=0.05) # 給 Dense layer
#nadam = optimizers.Nadam(lr=0.002,clipvalue=0.5)
from tensorflow.keras.initializers import RandomUniform
init_d = RandomUniform(minval=-0.05, maxval=0.05) # 給 Dense layer
model = Sequential()
model.add(TCN(input_shape=(x_train.shape[1],x_train.shape[2]),
        kernel_size=3,
        nb_filters=25,
        nb_stacks=1,
        dilations=(1, 2, 4, 8),
        kernel_initializer='glorot_uniform',
        use_skip_connections=True,
        use_batch_norm=False,
        use_weight_norm=False,
        use_layer_norm=True,
        dropout_rate = 0.05,
        return_sequences=True
        ))
model.add(Dropout(0.5))
model.add(TCN(
        kernel_size=3,
        nb_filters=25,
        nb_stacks=1,
        dilations=(1, 2, 4, 8),
        kernel_initializer='glorot_uniform',
        use_skip_connections=True,
        use_batch_norm=False,
        use_weight_norm=False,
        use_layer_norm=True,
        dropout_rate = 0.05,
        return_sequences=False
        ))  
model.add(Dropout(0.3))
model.add(Dense(1,kernel_initializer=init_d))  
model.summary()

print('Train...')
model.compile(optimizer = "nadam" , loss="mse")
history = model.fit(x_train, y_train, epochs=120, batch_size=12, validation_split=0.1, shuffle=True)
#Save Model
model.save('TCN_model_craven.h5')  # creates a HDF5 file 
del model

custom_ob = {'TCN': TCN}
# model = load_model('TCN_model_1.h5', custom_objects=custom_ob)
model = load_model('TCN_model_craven.h5', custom_objects=custom_ob)
print('Load Success')

import time
t1 = time.time()
y_pred = model.predict(x_test)
t2 = time.time()
print('Predict time: ',t2-t1)
y_pred = scaler.inverse_transform(y_pred)#Undo scaling

from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error
rmse_lstm = np.sqrt(mean_squared_error(y_test, y_pred))
print('RMSE: ',rmse_lstm)

mae = mean_absolute_error(y_test, y_pred)
print('MAE: ',mae)

r2 =  r2_score(y_test, y_pred)
print('R-square: ',r2)

n = len(y_test)
p = 12
Adj_r2 = 1-(1-r2)*(n-1)/(n-p-1)
print('Adj R-square: ',Adj_r2)

plt.plot(history.history["loss"],label="loss")
plt.plot(history.history["val_loss"],label="val_loss")
plt.legend(loc="best")
plt.xlabel("No. Of Epochs")
plt.ylabel("mse score")
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# tcn_2 (TCN)                  (None, 24, 20)            9860
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 24, 20)            0
# _________________________________________________________________
# tcn_3 (TCN)                  (None, 20)                10080
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 19,961
# Trainable params: 19,961
# Non-trainable params: 0
# _________________________________________________________________
# Train...
# Train on 108 samples, validate on 12 samples
# Epoch 1/120
# 108/108 [==============================] - 7s 61ms/sample - loss: 0.8946 - val_loss: 0.8675
# Epoch 2/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.8024 - val_loss: 0.8374
# Epoch 3/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.8543 - val_loss: 0.8284
# Epoch 4/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.8199 - val_loss: 0.8221
# Epoch 5/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.8338 - val_loss: 0.7927
# Epoch 6/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.8543 - val_loss: 0.7805
# Epoch 7/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.8225 - val_loss: 0.7600
# Epoch 8/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.7354 - val_loss: 0.7316
# Epoch 9/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.6936 - val_loss: 0.6555
# Epoch 10/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.6844 - val_loss: 0.6216
# Epoch 11/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.6753 - val_loss: 0.5836
# Epoch 12/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.6948 - val_loss: 0.5751
# Epoch 13/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.5858 - val_loss: 0.5904
# Epoch 14/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.5649 - val_loss: 0.6456
# Epoch 15/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.5516 - val_loss: 0.5840
# Epoch 16/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.5488 - val_loss: 0.6252
# Epoch 17/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.5169 - val_loss: 0.6105
# Epoch 18/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.5073 - val_loss: 0.5680
# Epoch 19/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4974 - val_loss: 0.5435
# Epoch 20/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.5064 - val_loss: 0.5386
# Epoch 21/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4479 - val_loss: 0.5015
# Epoch 22/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4042 - val_loss: 0.5880
# Epoch 23/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4347 - val_loss: 0.5136
# Epoch 24/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3612 - val_loss: 0.5539
# Epoch 25/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3328 - val_loss: 0.5578
# Epoch 26/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3559 - val_loss: 0.4759
# Epoch 27/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3569 - val_loss: 0.4014
# Epoch 28/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3442 - val_loss: 0.4177
# Epoch 29/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3260 - val_loss: 0.4316
# Epoch 30/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3718 - val_loss: 0.3785
# Epoch 31/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3751 - val_loss: 0.3407
# Epoch 32/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3010 - val_loss: 0.3980
# Epoch 33/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2890 - val_loss: 0.3389
# Epoch 34/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1944 - val_loss: 0.3234
# Epoch 35/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3414 - val_loss: 0.3236
# Epoch 36/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2939 - val_loss: 0.3540
# Epoch 37/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2392 - val_loss: 0.3440
# Epoch 38/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2416 - val_loss: 0.3111
# Epoch 39/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3799 - val_loss: 0.3682
# Epoch 40/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2094 - val_loss: 0.3304
# Epoch 41/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2899 - val_loss: 0.3037
# Epoch 42/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2881 - val_loss: 0.2920
# Epoch 43/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2426 - val_loss: 0.3465
# Epoch 44/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2160 - val_loss: 0.3180
# Epoch 45/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2277 - val_loss: 0.3954
# Epoch 46/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2288 - val_loss: 0.3763
# Epoch 47/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2757 - val_loss: 0.3099
# Epoch 48/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2488 - val_loss: 0.3386
# Epoch 49/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2321 - val_loss: 0.3270
# Epoch 50/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1751 - val_loss: 0.2871
# Epoch 51/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2756 - val_loss: 0.3419
# Epoch 52/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2021 - val_loss: 0.3430
# Epoch 53/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2464 - val_loss: 0.3203
# Epoch 54/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2502 - val_loss: 0.2905
# Epoch 55/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2680 - val_loss: 0.3219
# Epoch 56/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2407 - val_loss: 0.3089
# Epoch 57/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1712 - val_loss: 0.3119
# Epoch 58/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2335 - val_loss: 0.3263
# Epoch 59/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2095 - val_loss: 0.3418
# Epoch 60/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2769 - val_loss: 0.3565
# Epoch 61/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2135 - val_loss: 0.3268
# Epoch 62/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1821 - val_loss: 0.2973
# Epoch 63/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2478 - val_loss: 0.2757
# Epoch 64/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2704 - val_loss: 0.2677
# Epoch 65/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1724 - val_loss: 0.2461
# Epoch 66/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1857 - val_loss: 0.2571
# Epoch 67/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2488 - val_loss: 0.2660
# Epoch 68/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2268 - val_loss: 0.2420
# Epoch 69/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1776 - val_loss: 0.2647
# Epoch 70/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2043 - val_loss: 0.2716
# Epoch 71/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2381 - val_loss: 0.2805
# Epoch 72/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2296 - val_loss: 0.2746
# Epoch 73/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1928 - val_loss: 0.2841
# Epoch 74/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1645 - val_loss: 0.2734
# Epoch 75/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2643 - val_loss: 0.2598
# Epoch 76/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2172 - val_loss: 0.2515
# Epoch 77/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1552 - val_loss: 0.2451
# Epoch 78/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1740 - val_loss: 0.2547
# Epoch 79/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1842 - val_loss: 0.2491
# Epoch 80/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1427 - val_loss: 0.2710
# Epoch 81/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1857 - val_loss: 0.2959
# Epoch 82/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1573 - val_loss: 0.2873
# Epoch 83/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2075 - val_loss: 0.2833
# Epoch 84/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1537 - val_loss: 0.2537
# Epoch 85/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1783 - val_loss: 0.2575
# Epoch 86/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2003 - val_loss: 0.2446
# Epoch 87/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1745 - val_loss: 0.2640
# Epoch 88/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1354 - val_loss: 0.2305
# Epoch 89/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1787 - val_loss: 0.2533
# Epoch 90/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1763 - val_loss: 0.2545
# Epoch 91/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1248 - val_loss: 0.2264
# Epoch 92/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1568 - val_loss: 0.2171
# Epoch 93/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1882 - val_loss: 0.2303
# Epoch 94/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1995 - val_loss: 0.2255
# Epoch 95/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2256 - val_loss: 0.2314
# Epoch 96/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2116 - val_loss: 0.2443
# Epoch 97/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1221 - val_loss: 0.2413
# Epoch 98/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2211 - val_loss: 0.2629
# Epoch 99/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1420 - val_loss: 0.2684
# Epoch 100/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1404 - val_loss: 0.2537
# Epoch 101/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1964 - val_loss: 0.2253
# Epoch 102/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1933 - val_loss: 0.2361
# Epoch 103/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1655 - val_loss: 0.2533
# Epoch 104/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1753 - val_loss: 0.2677
# Epoch 105/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1276 - val_loss: 0.2795
# Epoch 106/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1387 - val_loss: 0.2438
# Epoch 107/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1306 - val_loss: 0.2343
# Epoch 108/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1977 - val_loss: 0.2541
# Epoch 109/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1293 - val_loss: 0.2783
# Epoch 110/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2026 - val_loss: 0.2628
# Epoch 111/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1451 - val_loss: 0.2474
# Epoch 112/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1371 - val_loss: 0.2572
# Epoch 113/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1459 - val_loss: 0.2381
# Epoch 114/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1361 - val_loss: 0.2671
# Epoch 115/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1557 - val_loss: 0.2676
# Epoch 116/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1458 - val_loss: 0.2607
# Epoch 117/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1810 - val_loss: 0.2402
# Epoch 118/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1315 - val_loss: 0.2338
# Epoch 119/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1452 - val_loss: 0.2072
# Epoch 120/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1880 - val_loss: 0.2155
# Load Success
# Predict time:  0.6310968399047852
# RMSE:  10.657156721458986
# MAE:  8.268095672130585
# R-square:  -0.9210569727617468
# Adj R-square:  -8.605284863808734
# Text(0, 0.5, 'mse score')
