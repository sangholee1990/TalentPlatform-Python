# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
import math
from sklearn.preprocessing import RobustScaler, MinMaxScaler
from tqdm import tqdm_notebook as tqdm
from tcn import TCN
import time
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error
from keras.preprocessing import sequence
from keras.models import Sequential , load_model , Model
from keras.layers import Dense, Dropout , LSTM , Bidirectional ,GRU ,Flatten,Add,BatchNormalization
from keras_layer_normalization import LayerNormalization
from keras.initializers import  glorot_normal, RandomUniform
from keras import optimizers,Input
from keras_self_attention import SeqSelfAttention
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
#data

# %%
df = pd.read_csv("station_bike _Craven.csv")
df["timestamp"] = pd.to_datetime(df["timestamp"])
df = df.set_index("timestamp")
#df.head()

df["hour"] = df.index.hour
df["day_of_month"] = df.index.day
df["day_of_week"]  = df.index.dayofweek
df["month"] = df.index.month

training_data_len = math.ceil(len(df) * 0.9) # taking 90% of data to train and 10% of data to test
testing_data_len = len(df) - training_data_len

time_steps = 24
train, test = df.iloc[0:training_data_len], df.iloc[(training_data_len-time_steps):len(df)]
print(df.shape, train.shape, test.shape)

df.head()
# Out:
# (160, 13) (144, 13) (40, 13)
#                      cnt    t1    t2   hum  wind_speed  weather_code  \
# timestamp
# 2015-09-06 00:00:00    2  11.0  11.0  72.0         5.0             1
# 2015-09-06 01:00:00    2  10.0  10.0  82.0         6.0             1
# 2015-09-06 02:00:00    0  10.0  10.0  82.0         5.0             1
# 2015-09-06 03:00:00    0  10.0  10.0  79.0         6.0             1
# 2015-09-06 04:00:00    0   9.0   8.0  84.5         8.0             1
#
#                      is_holiday  is_weekend  season  hour  day_of_month  \
# timestamp
# 2015-09-06 00:00:00           0           1       2     0             6
# 2015-09-06 01:00:00           0           1       2     1             6
# 2015-09-06 02:00:00           0           1       2     2             6
# 2015-09-06 03:00:00           0           1       2     3             6
# 2015-09-06 04:00:00           0           1       2     4             6
#
#                      day_of_week  month
# timestamp
# 2015-09-06 00:00:00            6      9
# 2015-09-06 01:00:00            6      9
# 2015-09-06 02:00:00            6      9
# 2015-09-06 03:00:00            6      9
# 2015-09-06 04:00:00            6      9

# %%
train_trans = train[['t1','t2', 'hum', 'wind_speed']].to_numpy()
test_trans = test[['t1','t2', 'hum', 'wind_speed']].to_numpy()

scaler = RobustScaler() # Handles outliers
#scaler = MinMaxScaler(feature_range=(0, 1)) # scale to (0,1)
train.loc[:, ['t1','t2','hum', 'wind_speed']]=scaler.fit_transform(train_trans)
test.loc[:, ['t1','t2', 'hum', 'wind_speed']]=scaler.fit_transform(test_trans)

train['cnt'] = scaler.fit_transform(train[['cnt']])
test['cnt'] = scaler.fit_transform(test[['cnt']])

#Split the data into x_train and y_train data sets
x_train = []
y_train = []

for i in tqdm(range(len(train) - time_steps)):
    x_train.append(train.drop(columns='cnt').iloc[i:i + time_steps].to_numpy())
    y_train.append(train.loc[:,'cnt'].iloc[i + time_steps])

#Convert x_train and y_train to numpy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

#Create the x_test and y_test data sets
x_test = []
y_test = df.loc[:,'cnt'].iloc[training_data_len:len(df)]

for i in tqdm(range(len(test) - time_steps)):
    x_test.append(test.drop(columns='cnt').iloc[i:i + time_steps].to_numpy())
    # y_test.append(test.loc[:,'cnt'].iloc[i + time_steps])

#Convert x_test and y_test to numpy arrays
x_test = np.array(x_test)
y_test = np.array(y_test)

# All 12 columns of the data
print('Train size:')
print(x_train.shape, y_train.shape)
print('Test size:')
print(x_test.shape, y_test.shape)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:16: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   app.launch_new_instance()
#   0%|          | 0/120 [00:00<?, ?it/s]
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:28: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/16 [00:00<?, ?it/s]
# Train size:
# (120, 24, 12) (120,)
# Test size:
# (16, 24, 12) (16,)

# %%
from keras.layers import Concatenate
init = glorot_normal(seed=None) # 給 GRU
init_d = RandomUniform(minval=-0.05, maxval=0.05) # 給 Dense layer

def Encoder(layer):
    shortcut = layer
    layer = SeqSelfAttention(
                     attention_type=SeqSelfAttention.ATTENTION_TYPE_MUL,
                     kernel_regularizer=tf.keras.regularizers.l2(0.01),
                     bias_regularizer=tf.keras.regularizers.l2(0.01),
                     attention_regularizer_weight=0.0001)(layer)
    layer = Add()([layer,shortcut])
    layer = LayerNormalization()(layer)
    layer = Flatten()(layer)
    
    shortcut2 = layer
    layer = Dense(12,kernel_initializer=init_d)(layer)
    layer = Dropout(0.2)(layer)
    layer = Concatenate()([layer,shortcut2])
    output = Dense(1,kernel_initializer=init_d)(layer)
    return output

def Decoder(layer):
    shortcut = layer
    layer = SeqSelfAttention(
                     attention_type=SeqSelfAttention.ATTENTION_TYPE_MUL,
                     kernel_regularizer=tf.keras.regularizers.l2(0.01),
                     bias_regularizer=tf.keras.regularizers.l2(0.01),
                     attention_regularizer_weight=0.0001)(layer)
    layer = Add()([layer,shortcut])
    layer = LayerNormalization()(layer)
    layer = SeqSelfAttention(
                     attention_type=SeqSelfAttention.ATTENTION_TYPE_MUL,
                     kernel_regularizer=tf.keras.regularizers.l2(0.01),
                     bias_regularizer=tf.keras.regularizers.l2(0.01),
                     attention_regularizer_weight=0.0001)(layer)
    layer = LayerNormalization()(layer)
    
    layer = Flatten()(layer)
    shortcut2 = layer
    layer = Dense(10,kernel_initializer=init_d)(layer)
    #layer = Dropout(0.2)(layer)
    layer = Concatenate()([layer,shortcut2])
    output = Dense(1,kernel_initializer=init_d)(layer)
    return output

def Bi_GRU(layer,unit):
    output = Bidirectional(GRU(unit, dropout=0.1, recurrent_dropout=0.1, return_sequences=True,
                            kernel_initializer=init))(layer)
    return output

# %%
#start = Input(shape = (x_train.shape[1],x_train.shape[2]))
start = Input(shape = (x_train.shape[1:]))
start2 = Input(shape = (x_train.shape[1:]))
x = Bi_GRU(start,12)
x = Encoder(x)

# y = Bi_GRU(start2,8)
# y = Decoder(y)

#Merge = Add()([x,x])
Last = Dense(1)(x)
model = Model([start,start2] , Last)
model.summary()
# Out:
# Model: "model_64"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_126 (InputLayer)          (None, 24, 12)       0
# __________________________________________________________________________________________________
# bidirectional_66 (Bidirectional (None, 24, 24)       1800        input_126[0][0]
# __________________________________________________________________________________________________
# seq_self_attention_68 (SeqSelfA (None, 24, 24)       577         bidirectional_66[0][0]
# __________________________________________________________________________________________________
# add_86 (Add)                    (None, 24, 24)       0           seq_self_attention_68[0][0]
#                                                                  bidirectional_66[0][0]
# __________________________________________________________________________________________________
# layer_normalization_68 (LayerNo (None, 24, 24)       48          add_86[0][0]
# __________________________________________________________________________________________________
# flatten_66 (Flatten)            (None, 576)          0           layer_normalization_68[0][0]
# __________________________________________________________________________________________________
# dense_194 (Dense)               (None, 12)           6924        flatten_66[0][0]
# __________________________________________________________________________________________________
# dropout_49 (Dropout)            (None, 12)           0           dense_194[0][0]
# __________________________________________________________________________________________________
# concatenate_66 (Concatenate)    (None, 588)          0           dropout_49[0][0]
#                                                                  flatten_66[0][0]
# __________________________________________________________________________________________________
# dense_195 (Dense)               (None, 1)            589         concatenate_66[0][0]
# __________________________________________________________________________________________________
# dense_196 (Dense)               (None, 1)            2           dense_195[0][0]
# ==================================================================================================
# Total params: 9,940
# Trainable params: 9,940
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
opt = optimizers.Adam(lr=0.001,decay = 0.0001)
print('Train...')
# model.compile(optimizer = opt , loss="mse")
model.compile(optimizer = "adam" , loss="mse")
history = model.fit([x_train,x_train], y_train, epochs = 500, batch_size=8, validation_split=0.1, shuffle=True)
# history = model.fit(x_train, y_train, epochs = 500, batch_size=6, validation_split=0.1, shuffle=True)
model.summary()
#Save Model
model.save('GRU_Single_Attention_model_craven.h5')  # creates a HDF5 file 
del model
# Out:
# Train...
# Train on 108 samples, validate on 12 samples
# Epoch 1/500
# 108/108 [==============================] - 2s 14ms/step - loss: 1.1259 - val_loss: 1.0780
# Epoch 2/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.9472 - val_loss: 0.9182
# Epoch 3/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.8085 - val_loss: 0.9496
# Epoch 4/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.7847 - val_loss: 0.9406
# Epoch 5/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.7707 - val_loss: 0.7906
# Epoch 6/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.7621 - val_loss: 0.7470
# Epoch 7/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.7785 - val_loss: 1.2588
# Epoch 8/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.6678 - val_loss: 0.8809
# Epoch 9/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.5761 - val_loss: 0.9024
# Epoch 10/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.6244 - val_loss: 0.7799
# Epoch 11/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.5745 - val_loss: 0.9851
# Epoch 12/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.5301 - val_loss: 0.7778
# Epoch 13/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.5523 - val_loss: 0.9007
# Epoch 14/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.5043 - val_loss: 0.6807
# Epoch 15/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.4917 - val_loss: 0.6123
# Epoch 16/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.4033 - val_loss: 0.5903
# Epoch 17/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.4511 - val_loss: 0.7466
# Epoch 18/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.3841 - val_loss: 0.6232
# Epoch 19/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.3789 - val_loss: 0.5330
# Epoch 20/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.5010 - val_loss: 0.7611
# Epoch 21/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.4439 - val_loss: 0.8631
# Epoch 22/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.3693 - val_loss: 0.6169
# Epoch 23/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.3473 - val_loss: 0.4919
# Epoch 24/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.2672 - val_loss: 0.5695
# Epoch 25/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.2986 - val_loss: 0.4476
# Epoch 26/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.3297 - val_loss: 0.4614
# Epoch 27/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.2872 - val_loss: 0.4882
# Epoch 28/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.2744 - val_loss: 0.7308
# Epoch 29/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.3208 - val_loss: 0.5213
# Epoch 30/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.2357 - val_loss: 0.4356
# Epoch 31/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.2628 - val_loss: 0.6728
# Epoch 32/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.2569 - val_loss: 0.4784
# Epoch 33/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.2298 - val_loss: 0.3562
# Epoch 34/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.2561 - val_loss: 0.3573
# Epoch 35/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.2455 - val_loss: 0.4551
# Epoch 36/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.2206 - val_loss: 0.4140
# Epoch 37/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.2274 - val_loss: 0.2897
# Epoch 38/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.2474 - val_loss: 0.3814
# Epoch 39/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.2851 - val_loss: 0.4793
# Epoch 40/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.2107 - val_loss: 0.5875
# Epoch 41/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1926 - val_loss: 0.5433
# Epoch 42/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1819 - val_loss: 0.4154
# Epoch 43/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.2011 - val_loss: 0.3503
# Epoch 44/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1643 - val_loss: 0.4269
# Epoch 45/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1868 - val_loss: 0.3824
# Epoch 46/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1666 - val_loss: 0.2493
# Epoch 47/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1989 - val_loss: 0.3824
# Epoch 48/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.2181 - val_loss: 0.2834
# Epoch 49/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1783 - val_loss: 0.4244
# Epoch 50/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.2188 - val_loss: 0.5566
# Epoch 51/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1898 - val_loss: 0.5629
# Epoch 52/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.2464 - val_loss: 0.2585
# Epoch 53/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1842 - val_loss: 0.3246
# Epoch 54/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1578 - val_loss: 0.4355
# Epoch 55/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1550 - val_loss: 0.3233
# Epoch 56/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.2133 - val_loss: 0.2965
# Epoch 57/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1582 - val_loss: 0.2757
# Epoch 58/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.2145 - val_loss: 0.4103
# Epoch 59/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1956 - val_loss: 0.3965
# Epoch 60/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1463 - val_loss: 0.2087
# Epoch 61/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1828 - val_loss: 0.2535
# Epoch 62/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1292 - val_loss: 0.3339
# Epoch 63/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1610 - val_loss: 0.3270
# Epoch 64/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1750 - val_loss: 0.2462
# Epoch 65/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1576 - val_loss: 0.2894
# Epoch 66/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1533 - val_loss: 0.3402
# Epoch 67/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1696 - val_loss: 0.4653
# Epoch 68/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1575 - val_loss: 0.4851
# Epoch 69/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1762 - val_loss: 0.2893
# Epoch 70/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1257 - val_loss: 0.3138
# Epoch 71/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1417 - val_loss: 0.3839
# Epoch 72/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1071 - val_loss: 0.2802
# Epoch 73/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1346 - val_loss: 0.3960
# Epoch 74/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1208 - val_loss: 0.5197
# Epoch 75/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1587 - val_loss: 0.3208
# Epoch 76/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1467 - val_loss: 0.2539
# Epoch 77/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1242 - val_loss: 0.3153
# Epoch 78/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1199 - val_loss: 0.3876
# Epoch 79/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1580 - val_loss: 0.4374
# Epoch 80/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1404 - val_loss: 0.4580
# Epoch 81/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1965 - val_loss: 0.2547
# Epoch 82/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1153 - val_loss: 0.2132
# Epoch 83/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1491 - val_loss: 0.2426
# Epoch 84/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1431 - val_loss: 0.4427
# Epoch 85/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1272 - val_loss: 0.4142
# Epoch 86/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1485 - val_loss: 0.2680
# Epoch 87/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1280 - val_loss: 0.2334
# Epoch 88/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1048 - val_loss: 0.2945
# Epoch 89/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1123 - val_loss: 0.3153
# Epoch 90/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1223 - val_loss: 0.2537
# Epoch 91/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1084 - val_loss: 0.2580
# Epoch 92/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0954 - val_loss: 0.1917
# Epoch 93/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1161 - val_loss: 0.2636
# Epoch 94/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1328 - val_loss: 0.3994
# Epoch 95/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1195 - val_loss: 0.2824
# Epoch 96/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1036 - val_loss: 0.1927
# Epoch 97/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1597 - val_loss: 0.3263
# Epoch 98/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1632 - val_loss: 0.2778
# Epoch 99/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1469 - val_loss: 0.2588
# Epoch 100/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1268 - val_loss: 0.2601
# Epoch 101/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1209 - val_loss: 0.2808
# Epoch 102/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1747 - val_loss: 0.3476
# Epoch 103/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1231 - val_loss: 0.3265
# Epoch 104/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1249 - val_loss: 0.3094
# Epoch 105/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1168 - val_loss: 0.2769
# Epoch 106/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1497 - val_loss: 0.3785
# Epoch 107/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1293 - val_loss: 0.3654
# Epoch 108/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1168 - val_loss: 0.3476
# Epoch 109/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1131 - val_loss: 0.3019
# Epoch 110/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0980 - val_loss: 0.2506
# Epoch 111/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1485 - val_loss: 0.3029
# Epoch 112/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1269 - val_loss: 0.5260
# Epoch 113/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1493 - val_loss: 0.2296
# Epoch 114/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1025 - val_loss: 0.4118
# Epoch 115/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1094 - val_loss: 0.3945
# Epoch 116/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1385 - val_loss: 0.2751
# Epoch 117/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1168 - val_loss: 0.2166
# Epoch 118/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1320 - val_loss: 0.3475
# Epoch 119/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1154 - val_loss: 0.1973
# Epoch 120/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0949 - val_loss: 0.2263
# Epoch 121/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0958 - val_loss: 0.3171
# Epoch 122/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1050 - val_loss: 0.3249
# Epoch 123/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1404 - val_loss: 0.3558
# Epoch 124/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1074 - val_loss: 0.4662
# Epoch 125/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1267 - val_loss: 0.4341
# Epoch 126/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1104 - val_loss: 0.2744
# Epoch 127/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1247 - val_loss: 0.2537
# Epoch 128/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0956 - val_loss: 0.3795
# Epoch 129/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0917 - val_loss: 0.3150
# Epoch 130/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0883 - val_loss: 0.2809
# Epoch 131/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0797 - val_loss: 0.4351
# Epoch 132/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1195 - val_loss: 0.2375
# Epoch 133/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1043 - val_loss: 0.2763
# Epoch 134/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1567 - val_loss: 0.3369
# Epoch 135/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0858 - val_loss: 0.2733
# Epoch 136/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1267 - val_loss: 0.2808
# Epoch 137/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1053 - val_loss: 0.3158
# Epoch 138/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1077 - val_loss: 0.3769
# Epoch 139/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1191 - val_loss: 0.3165
# Epoch 140/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1010 - val_loss: 0.3338
# Epoch 141/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0847 - val_loss: 0.2353
# Epoch 142/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0934 - val_loss: 0.3353
# Epoch 143/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0727 - val_loss: 0.3159
# Epoch 144/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0926 - val_loss: 0.3004
# Epoch 145/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1023 - val_loss: 0.3775
# Epoch 146/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0907 - val_loss: 0.3381
# Epoch 147/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1090 - val_loss: 0.3120
# Epoch 148/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0938 - val_loss: 0.3961
# Epoch 149/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1060 - val_loss: 0.4035
# Epoch 150/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0894 - val_loss: 0.2869
# Epoch 151/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0891 - val_loss: 0.2373
# Epoch 152/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0858 - val_loss: 0.3307
# Epoch 153/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0788 - val_loss: 0.2704
# Epoch 154/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1363 - val_loss: 0.3177
# Epoch 155/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0882 - val_loss: 0.2791
# Epoch 156/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1222 - val_loss: 0.2986
# Epoch 157/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0700 - val_loss: 0.3204
# Epoch 158/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1190 - val_loss: 0.4150
# Epoch 159/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0801 - val_loss: 0.4488
# Epoch 160/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0871 - val_loss: 0.2524
# Epoch 161/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1082 - val_loss: 0.2938
# Epoch 162/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1180 - val_loss: 0.3214
# Epoch 163/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1135 - val_loss: 0.2683
# Epoch 164/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0916 - val_loss: 0.2534
# Epoch 165/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0918 - val_loss: 0.3223
# Epoch 166/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0819 - val_loss: 0.3081
# Epoch 167/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1531 - val_loss: 0.2648
# Epoch 168/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0932 - val_loss: 0.2815
# Epoch 169/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1161 - val_loss: 0.2449
# Epoch 170/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0953 - val_loss: 0.2763
# Epoch 171/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0934 - val_loss: 0.2437
# Epoch 172/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0712 - val_loss: 0.2874
# Epoch 173/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0918 - val_loss: 0.2573
# Epoch 174/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1051 - val_loss: 0.3424
# Epoch 175/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0848 - val_loss: 0.3805
# Epoch 176/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0813 - val_loss: 0.3754
# Epoch 177/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0696 - val_loss: 0.2636
# Epoch 178/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0848 - val_loss: 0.3245
# Epoch 179/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1116 - val_loss: 0.4029
# Epoch 180/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1001 - val_loss: 0.3595
# Epoch 181/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0966 - val_loss: 0.3146
# Epoch 182/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1043 - val_loss: 0.3328
# Epoch 183/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0825 - val_loss: 0.3741
# Epoch 184/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0868 - val_loss: 0.2992
# Epoch 185/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1425 - val_loss: 0.3276
# Epoch 186/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1142 - val_loss: 0.3082
# Epoch 187/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0646 - val_loss: 0.2814
# Epoch 188/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0800 - val_loss: 0.3229
# Epoch 189/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0961 - val_loss: 0.3003
# Epoch 190/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1092 - val_loss: 0.3102
# Epoch 191/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0861 - val_loss: 0.2250
# Epoch 192/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0862 - val_loss: 0.3278
# Epoch 193/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0880 - val_loss: 0.2921
# Epoch 194/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0827 - val_loss: 0.2513
# Epoch 195/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0697 - val_loss: 0.2245
# Epoch 196/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0736 - val_loss: 0.4103
# Epoch 197/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0786 - val_loss: 0.2694
# Epoch 198/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1096 - val_loss: 0.2405
# Epoch 199/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0779 - val_loss: 0.3557
# Epoch 200/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0872 - val_loss: 0.2959
# Epoch 201/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0688 - val_loss: 0.2100
# Epoch 202/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0981 - val_loss: 0.3457
# Epoch 203/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0799 - val_loss: 0.4276
# Epoch 204/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0856 - val_loss: 0.3109
# Epoch 205/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0636 - val_loss: 0.4267
# Epoch 206/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0688 - val_loss: 0.3150
# Epoch 207/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0748 - val_loss: 0.3944
# Epoch 208/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0862 - val_loss: 0.3500
# Epoch 209/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0760 - val_loss: 0.3402
# Epoch 210/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1372 - val_loss: 0.3091
# Epoch 211/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0636 - val_loss: 0.3350
# Epoch 212/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0699 - val_loss: 0.2416
# Epoch 213/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1231 - val_loss: 0.3165
# Epoch 214/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0651 - val_loss: 0.3212
# Epoch 215/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0793 - val_loss: 0.3253
# Epoch 216/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0693 - val_loss: 0.2857
# Epoch 217/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1115 - val_loss: 0.3158
# Epoch 218/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0803 - val_loss: 0.2704
# Epoch 219/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0960 - val_loss: 0.2951
# Epoch 220/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0864 - val_loss: 0.2804
# Epoch 221/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0788 - val_loss: 0.3931
# Epoch 222/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0839 - val_loss: 0.3131
# Epoch 223/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0814 - val_loss: 0.3804
# Epoch 224/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0812 - val_loss: 0.4084
# Epoch 225/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1205 - val_loss: 0.3216
# Epoch 226/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0741 - val_loss: 0.3055
# Epoch 227/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0634 - val_loss: 0.3522
# Epoch 228/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0754 - val_loss: 0.4610
# Epoch 229/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0756 - val_loss: 0.4302
# Epoch 230/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0629 - val_loss: 0.2888
# Epoch 231/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0650 - val_loss: 0.4661
# Epoch 232/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0761 - val_loss: 0.4543
# Epoch 233/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1003 - val_loss: 0.2646
# Epoch 234/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0868 - val_loss: 0.4242
# Epoch 235/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0716 - val_loss: 0.3608
# Epoch 236/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0653 - val_loss: 0.3193
# Epoch 237/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0738 - val_loss: 0.3589
# Epoch 238/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0592 - val_loss: 0.3309
# Epoch 239/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0847 - val_loss: 0.3710
# Epoch 240/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0903 - val_loss: 0.3280
# Epoch 241/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0755 - val_loss: 0.6610
# Epoch 242/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0627 - val_loss: 0.4841
# Epoch 243/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0510 - val_loss: 0.3575
# Epoch 244/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0579 - val_loss: 0.3856
# Epoch 245/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0606 - val_loss: 0.3879
# Epoch 246/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0710 - val_loss: 0.3566
# Epoch 247/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0723 - val_loss: 0.3444
# Epoch 248/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0579 - val_loss: 0.4368
# Epoch 249/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0742 - val_loss: 0.3188
# Epoch 250/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0698 - val_loss: 0.2068
# Epoch 251/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0973 - val_loss: 0.3958
# Epoch 252/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0739 - val_loss: 0.3867
# Epoch 253/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0664 - val_loss: 0.3640
# Epoch 254/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0699 - val_loss: 0.3355
# Epoch 255/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0672 - val_loss: 0.2475
# Epoch 256/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0748 - val_loss: 0.2979
# Epoch 257/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.1111 - val_loss: 0.5002
# Epoch 258/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0645 - val_loss: 0.3362
# Epoch 259/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0740 - val_loss: 0.4451
# Epoch 260/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0508 - val_loss: 0.4106
# Epoch 261/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0655 - val_loss: 0.3090
# Epoch 262/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0560 - val_loss: 0.4413
# Epoch 263/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0500 - val_loss: 0.4668
# Epoch 264/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0920 - val_loss: 0.2937
# Epoch 265/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0630 - val_loss: 0.3351
# Epoch 266/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0635 - val_loss: 0.3024
# Epoch 267/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0509 - val_loss: 0.3540
# Epoch 268/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0518 - val_loss: 0.3459
# Epoch 269/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0383 - val_loss: 0.4502
# Epoch 270/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0572 - val_loss: 0.3775
# Epoch 271/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0776 - val_loss: 0.2430
# Epoch 272/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0574 - val_loss: 0.3169
# Epoch 273/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0420 - val_loss: 0.3278
# Epoch 274/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0602 - val_loss: 0.4413
# Epoch 275/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0547 - val_loss: 0.4452
# Epoch 276/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0516 - val_loss: 0.3527
# Epoch 277/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0439 - val_loss: 0.4871
# Epoch 278/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0738 - val_loss: 0.3897
# Epoch 279/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0555 - val_loss: 0.4242
# Epoch 280/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0497 - val_loss: 0.3454
# Epoch 281/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0495 - val_loss: 0.3515
# Epoch 282/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0717 - val_loss: 0.4631
# Epoch 283/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0640 - val_loss: 0.5948
# Epoch 284/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0568 - val_loss: 0.4458
# Epoch 285/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0430 - val_loss: 0.4069
# Epoch 286/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0519 - val_loss: 0.4828
# Epoch 287/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0439 - val_loss: 0.4574
# Epoch 288/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0480 - val_loss: 0.3528
# Epoch 289/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0527 - val_loss: 0.3106
# Epoch 290/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0547 - val_loss: 0.3417
# Epoch 291/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0515 - val_loss: 0.3430
# Epoch 292/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0458 - val_loss: 0.3744
# Epoch 293/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0423 - val_loss: 0.4164
# Epoch 294/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0466 - val_loss: 0.4141
# Epoch 295/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0445 - val_loss: 0.3775
# Epoch 296/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0583 - val_loss: 0.2975
# Epoch 297/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0510 - val_loss: 0.2958
# Epoch 298/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0545 - val_loss: 0.4563
# Epoch 299/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0438 - val_loss: 0.3319
# Epoch 300/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0345 - val_loss: 0.3164
# Epoch 301/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0674 - val_loss: 0.4645
# Epoch 302/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0412 - val_loss: 0.4329
# Epoch 303/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0517 - val_loss: 0.3698
# Epoch 304/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0806 - val_loss: 0.4914
# Epoch 305/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0562 - val_loss: 0.4159
# Epoch 306/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0366 - val_loss: 0.3644
# Epoch 307/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0429 - val_loss: 0.3628
# Epoch 308/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0466 - val_loss: 0.4012
# Epoch 309/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0501 - val_loss: 0.3528
# Epoch 310/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0796 - val_loss: 0.5249
# Epoch 311/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0517 - val_loss: 0.3630
# Epoch 312/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0499 - val_loss: 0.4217
# Epoch 313/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0409 - val_loss: 0.3719
# Epoch 314/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0501 - val_loss: 0.3544
# Epoch 315/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0510 - val_loss: 0.3708
# Epoch 316/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0329 - val_loss: 0.4893
# Epoch 317/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0520 - val_loss: 0.3477
# Epoch 318/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0513 - val_loss: 0.4217
# Epoch 319/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0966 - val_loss: 0.3874
# Epoch 320/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0578 - val_loss: 0.4733
# Epoch 321/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0450 - val_loss: 0.3957
# Epoch 322/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0757 - val_loss: 0.3332
# Epoch 323/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0475 - val_loss: 0.3181
# Epoch 324/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0415 - val_loss: 0.3711
# Epoch 325/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0419 - val_loss: 0.5477
# Epoch 326/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0361 - val_loss: 0.4804
# Epoch 327/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0402 - val_loss: 0.4300
# Epoch 328/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0463 - val_loss: 0.4203
# Epoch 329/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0544 - val_loss: 0.4375
# Epoch 330/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0437 - val_loss: 0.4997
# Epoch 331/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0334 - val_loss: 0.4404
# Epoch 332/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0450 - val_loss: 0.4380
# Epoch 333/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0525 - val_loss: 0.2892
# Epoch 334/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0351 - val_loss: 0.3724
# Epoch 335/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0496 - val_loss: 0.4185
# Epoch 336/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0405 - val_loss: 0.3722
# Epoch 337/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0351 - val_loss: 0.4520
# Epoch 338/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0389 - val_loss: 0.4802
# Epoch 339/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0355 - val_loss: 0.5344
# Epoch 340/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0470 - val_loss: 0.3889
# Epoch 341/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0409 - val_loss: 0.2967
# Epoch 342/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0734 - val_loss: 0.3814
# Epoch 343/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0517 - val_loss: 0.3726
# Epoch 344/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0528 - val_loss: 0.4705
# Epoch 345/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0625 - val_loss: 0.3279
# Epoch 346/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0471 - val_loss: 0.3652
# Epoch 347/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0371 - val_loss: 0.4710
# Epoch 348/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0339 - val_loss: 0.3995
# Epoch 349/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0858 - val_loss: 0.2385
# Epoch 350/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0632 - val_loss: 0.5818
# Epoch 351/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0534 - val_loss: 0.4745
# Epoch 352/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0437 - val_loss: 0.3651
# Epoch 353/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0362 - val_loss: 0.4124
# Epoch 354/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0550 - val_loss: 0.3123
# Epoch 355/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0474 - val_loss: 0.3402
# Epoch 356/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0433 - val_loss: 0.3899
# Epoch 357/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0451 - val_loss: 0.5557
# Epoch 358/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0538 - val_loss: 0.3621
# Epoch 359/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0387 - val_loss: 0.3753
# Epoch 360/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0385 - val_loss: 0.3783
# Epoch 361/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0300 - val_loss: 0.4471
# Epoch 362/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0420 - val_loss: 0.4497
# Epoch 363/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0359 - val_loss: 0.3807
# Epoch 364/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0290 - val_loss: 0.4045
# Epoch 365/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0706 - val_loss: 0.5698
# Epoch 366/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0411 - val_loss: 0.4619
# Epoch 367/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0612 - val_loss: 0.4308
# Epoch 368/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0359 - val_loss: 0.3341
# Epoch 369/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0416 - val_loss: 0.4106
# Epoch 370/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0385 - val_loss: 0.5251
# Epoch 371/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0401 - val_loss: 0.3452
# Epoch 372/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0454 - val_loss: 0.2865
# Epoch 373/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0430 - val_loss: 0.4541
# Epoch 374/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0321 - val_loss: 0.3829
# Epoch 375/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0364 - val_loss: 0.3493
# Epoch 376/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0329 - val_loss: 0.3623
# Epoch 377/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0356 - val_loss: 0.4938
# Epoch 378/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0469 - val_loss: 0.4584
# Epoch 379/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0429 - val_loss: 0.5328
# Epoch 380/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0358 - val_loss: 0.4092
# Epoch 381/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0412 - val_loss: 0.3938
# Epoch 382/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0363 - val_loss: 0.4876
# Epoch 383/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0353 - val_loss: 0.4570
# Epoch 384/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0404 - val_loss: 0.4540
# Epoch 385/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0464 - val_loss: 0.4814
# Epoch 386/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0387 - val_loss: 0.4359
# Epoch 387/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0398 - val_loss: 0.4500
# Epoch 388/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0488 - val_loss: 0.3139
# Epoch 389/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0592 - val_loss: 0.4368
# Epoch 390/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0468 - val_loss: 0.4602
# Epoch 391/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0407 - val_loss: 0.3959
# Epoch 392/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0285 - val_loss: 0.3678
# Epoch 393/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0339 - val_loss: 0.3549
# Epoch 394/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0295 - val_loss: 0.3967
# Epoch 395/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0416 - val_loss: 0.3888
# Epoch 396/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0396 - val_loss: 0.3692
# Epoch 397/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0499 - val_loss: 0.4076
# Epoch 398/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0343 - val_loss: 0.4136
# Epoch 399/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0515 - val_loss: 0.3684
# Epoch 400/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0585 - val_loss: 0.4090
# Epoch 401/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0858 - val_loss: 0.3692
# Epoch 402/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0373 - val_loss: 0.5214
# Epoch 403/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0428 - val_loss: 0.5509
# Epoch 404/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0314 - val_loss: 0.3856
# Epoch 405/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0310 - val_loss: 0.5178
# Epoch 406/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0334 - val_loss: 0.4330
# Epoch 407/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0493 - val_loss: 0.4866
# Epoch 408/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0426 - val_loss: 0.3451
# Epoch 409/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0302 - val_loss: 0.4943
# Epoch 410/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0364 - val_loss: 0.4234
# Epoch 411/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0656 - val_loss: 0.3665
# Epoch 412/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0491 - val_loss: 0.4937
# Epoch 413/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0461 - val_loss: 0.5324
# Epoch 414/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0347 - val_loss: 0.4205
# Epoch 415/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0323 - val_loss: 0.4191
# Epoch 416/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0335 - val_loss: 0.4073
# Epoch 417/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0392 - val_loss: 0.4426
# Epoch 418/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0545 - val_loss: 0.4106
# Epoch 419/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0366 - val_loss: 0.5062
# Epoch 420/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0431 - val_loss: 0.4478
# Epoch 421/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0442 - val_loss: 0.3083
# Epoch 422/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0359 - val_loss: 0.4305
# Epoch 423/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0289 - val_loss: 0.4189
# Epoch 424/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0311 - val_loss: 0.4069
# Epoch 425/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0302 - val_loss: 0.4303
# Epoch 426/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0314 - val_loss: 0.4341
# Epoch 427/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0433 - val_loss: 0.4868
# Epoch 428/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0378 - val_loss: 0.5701
# Epoch 429/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0406 - val_loss: 0.6061
# Epoch 430/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0369 - val_loss: 0.5042
# Epoch 431/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0669 - val_loss: 0.4684
# Epoch 432/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0445 - val_loss: 0.4240
# Epoch 433/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0335 - val_loss: 0.6437
# Epoch 434/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0430 - val_loss: 0.4489
# Epoch 435/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0417 - val_loss: 0.3697
# Epoch 436/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0526 - val_loss: 0.3806
# Epoch 437/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0349 - val_loss: 0.4702
# Epoch 438/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0326 - val_loss: 0.4688
# Epoch 439/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0413 - val_loss: 0.3565
# Epoch 440/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0262 - val_loss: 0.4788
# Epoch 441/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0358 - val_loss: 0.4501
# Epoch 442/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0303 - val_loss: 0.3915
# Epoch 443/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0616 - val_loss: 0.5507
# Epoch 444/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0639 - val_loss: 0.5437
# Epoch 445/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0413 - val_loss: 0.3345
# Epoch 446/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0403 - val_loss: 0.4064
# Epoch 447/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0443 - val_loss: 0.4692
# Epoch 448/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0299 - val_loss: 0.4010
# Epoch 449/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0466 - val_loss: 0.3790
# Epoch 450/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0348 - val_loss: 0.3995
# Epoch 451/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0374 - val_loss: 0.4166
# Epoch 452/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0312 - val_loss: 0.4517
# Epoch 453/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0472 - val_loss: 0.4814
# Epoch 454/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0451 - val_loss: 0.4752
# Epoch 455/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0281 - val_loss: 0.4926
# Epoch 456/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0288 - val_loss: 0.3919
# Epoch 457/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0279 - val_loss: 0.4320
# Epoch 458/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0353 - val_loss: 0.4746
# Epoch 459/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0492 - val_loss: 0.3293
# Epoch 460/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0316 - val_loss: 0.4343
# Epoch 461/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0443 - val_loss: 0.5179
# Epoch 462/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0333 - val_loss: 0.3746
# Epoch 463/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0503 - val_loss: 0.3944
# Epoch 464/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0718 - val_loss: 0.3796
# Epoch 465/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0427 - val_loss: 0.4931
# Epoch 466/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0366 - val_loss: 0.4118
# Epoch 467/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0401 - val_loss: 0.4440
# Epoch 468/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0312 - val_loss: 0.5186
# Epoch 469/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0232 - val_loss: 0.4344
# Epoch 470/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0334 - val_loss: 0.5109
# Epoch 471/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0349 - val_loss: 0.4799
# Epoch 472/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0270 - val_loss: 0.4081
# Epoch 473/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0306 - val_loss: 0.3834
# Epoch 474/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0219 - val_loss: 0.4030
# Epoch 475/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0308 - val_loss: 0.3159
# Epoch 476/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0361 - val_loss: 0.4920
# Epoch 477/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0517 - val_loss: 0.3744
# Epoch 478/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0678 - val_loss: 0.3629
# Epoch 479/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0357 - val_loss: 0.5436
# Epoch 480/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0404 - val_loss: 0.3421
# Epoch 481/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0282 - val_loss: 0.4005
# Epoch 482/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0333 - val_loss: 0.4912
# Epoch 483/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0343 - val_loss: 0.3849
# Epoch 484/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0401 - val_loss: 0.3715
# Epoch 485/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0398 - val_loss: 0.5060
# Epoch 486/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0380 - val_loss: 0.4936
# Epoch 487/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0393 - val_loss: 0.3981
# Epoch 488/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0392 - val_loss: 0.2929
# Epoch 489/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0279 - val_loss: 0.4908
# Epoch 490/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0594 - val_loss: 0.4521
# Epoch 491/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0345 - val_loss: 0.4887
# Epoch 492/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0445 - val_loss: 0.4019
# Epoch 493/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0329 - val_loss: 0.4830
# Epoch 494/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0384 - val_loss: 0.4343
# Epoch 495/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0385 - val_loss: 0.4498
# Epoch 496/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0326 - val_loss: 0.4996
# Epoch 497/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0383 - val_loss: 0.3020
# Epoch 498/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0503 - val_loss: 0.4696
# Epoch 499/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0510 - val_loss: 0.5562
# Epoch 500/500
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0293 - val_loss: 0.3906
# Model: "model_64"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_126 (InputLayer)          (None, 24, 12)       0
# __________________________________________________________________________________________________
# bidirectional_66 (Bidirectional (None, 24, 24)       1800        input_126[0][0]
# __________________________________________________________________________________________________
# seq_self_attention_68 (SeqSelfA (None, 24, 24)       577         bidirectional_66[0][0]
# __________________________________________________________________________________________________
# add_86 (Add)                    (None, 24, 24)       0           seq_self_attention_68[0][0]
#                                                                  bidirectional_66[0][0]
# __________________________________________________________________________________________________
# layer_normalization_68 (LayerNo (None, 24, 24)       48          add_86[0][0]
# __________________________________________________________________________________________________
# flatten_66 (Flatten)            (None, 576)          0           layer_normalization_68[0][0]
# __________________________________________________________________________________________________
# dense_194 (Dense)               (None, 12)           6924        flatten_66[0][0]
# __________________________________________________________________________________________________
# dropout_49 (Dropout)            (None, 12)           0           dense_194[0][0]
# __________________________________________________________________________________________________
# concatenate_66 (Concatenate)    (None, 588)          0           dropout_49[0][0]
#                                                                  flatten_66[0][0]
# __________________________________________________________________________________________________
# dense_195 (Dense)               (None, 1)            589         concatenate_66[0][0]
# __________________________________________________________________________________________________
# dense_196 (Dense)               (None, 1)            2           dense_195[0][0]
# ==================================================================================================
# Total params: 9,940
# Trainable params: 9,940
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
custom_ob = {'LayerNormalization': LayerNormalization , 'SeqSelfAttention':SeqSelfAttention}
model = load_model('GRU_Single_Attention_model_craven.h5', custom_objects=custom_ob)
t1 = time.time()
# y_pred = model.predict([x_test,x_test])
y_pred2 = model.predict(x_test)
y_pred = model.predict(x_train)
t2 = time.time()
print('Predict time: ',t2-t1)
y_pred = scaler.inverse_transform(y_pred)#Undo scaling
rmse_lstm2 = np.sqrt(mean_squared_error(y_test, y_pred2))
rmse_lstm = np.sqrt(mean_squared_error(y_train, y_pred))
print('RMSE: ',rmse_lstm)
print('RMSE2: ',rmse_lstm2)
mae = mean_absolute_error(y_test, y_pred2)
mae = mean_absolute_error(y_train, y_pred)
print('MAE: ',mae)
print('MAE2: ',mae)
# r22 =  r2_score(y_test, y_pred2)
# r2 =  r2_score(y_train, y_pred)
# print('R-square: ',r2)
# print('R-square2: ',r22)

# n = len(y_test)
# p = 12
# Adj_r2 = 1-(1-r2)*(n-1)/(n-p-1)
# Adj_r22 = 1-(1-r22)*(n-1)/(n-p-1)
# print('Adj R-square: ',Adj_r2)
# print('Adj R-square2: ',Adj_r22)

plt.plot(history.history["loss"],label="loss")
plt.plot(history.history["val_loss"],label="val_loss")
plt.legend(loc="best")
plt.xlabel("No. Of Epochs")
plt.ylabel("mse score")
# Out:
# Predict time:  0.28623461723327637
# RMSE:  17.789416172912805
# RMSE2:  11.381855861694348
# MAE:  13.167350300720761
# MAE2:  13.167350300720761
# Text(0, 0.5, 'mse score')

# %%
plt.figure(figsize=(16, 8))
plt.plot(y_test, label='true')
# plt.plot(y_train, label='true')
plt.plot(y_pred2, label='predicted')
plt.legend()

# %%
from keras import regularizers
init = glorot_normal(seed=None) # 給 LSTM
init_d = RandomUniform(minval=-0.05, maxval=0.05) # 給 Dense layer
nadam = optimizers.Nadam(lr=0.0015,clipvalue=0.5)

model = Sequential()
model.add(Bidirectional(GRU(6, kernel_initializer=init ,return_sequences = True,kernel_regularizer=regularizers.l2(0.01)
                             ,recurrent_regularizer = regularizers.l2(0.01) ,input_shape=(x_train.shape[1],x_train.shape[2]))))
model.add(LayerNormalization())
model.add(Bidirectional(GRU(6,kernel_initializer=init,kernel_regularizer=regularizers.l2(0.01),recurrent_regularizer = regularizers.l2(0.01))))
model.add(Dropout(0.25))
model.add(Dense(units=1, kernel_initializer=init_d))
model.compile(optimizer = nadam , loss="mse")
history = model.fit(x_train, y_train, epochs=200, batch_size=24, validation_split=0.1, shuffle=True)
#model summary
model.summary()
#Save Model
model.save('GRU_model_craven.h5')  # creates a HDF5 file 
print('Model Saved')
del model  # deletes the existing model

custom_ob = {'LayerNormalization': LayerNormalization , 'SeqSelfAttention':SeqSelfAttention}
model = load_model('GRU_model_craven.h5', custom_objects=custom_ob)
t1 = time.time()
# y_pred = model.predict([x_test,x_test])
y_pred2 = model.predict(x_test)
y_pred = model.predict(x_train)
t2 = time.time()
print('Predict time: ',t2-t1)
y_pred = scaler.inverse_transform(y_pred)#Undo scaling
rmse_lstm2 = np.sqrt(mean_squared_error(y_test, y_pred2))
rmse_lstm = np.sqrt(mean_squared_error(y_train, y_pred))
print('RMSE: ',rmse_lstm)
print('RMSE2: ',rmse_lstm2)
mae = mean_absolute_error(y_test, y_pred2)
mae = mean_absolute_error(y_train, y_pred)
print('MAE: ',mae)
print('MAE2: ',mae)
# r22 =  r2_score(y_test, y_pred2)
# r2 =  r2_score(y_train, y_pred)
# print('R-square: ',r2)
# print('R-square2: ',r22)

# n = len(y_test)
# p = 12
# Adj_r2 = 1-(1-r2)*(n-1)/(n-p-1)
# Adj_r22 = 1-(1-r22)*(n-1)/(n-p-1)
# print('Adj R-square: ',Adj_r2)
# print('Adj R-square2: ',Adj_r22)

plt.plot(history.history["loss"],label="loss")
plt.plot(history.history["val_loss"],label="val_loss")
plt.legend(loc="best")
plt.xlabel("No. Of Epochs")
plt.ylabel("mse score")
# Out:
# Train on 108 samples, validate on 12 samples
# Epoch 1/200
# 108/108 [==============================] - 2s 21ms/step - loss: 1.6577 - val_loss: 1.7325
# Epoch 2/200
# 108/108 [==============================] - 0s 4ms/step - loss: 1.6131 - val_loss: 1.6782
# Epoch 3/200
# 108/108 [==============================] - 0s 4ms/step - loss: 1.5633 - val_loss: 1.6215
# Epoch 4/200
# 108/108 [==============================] - 0s 4ms/step - loss: 1.5112 - val_loss: 1.5675
# Epoch 5/200
# 108/108 [==============================] - 0s 4ms/step - loss: 1.4516 - val_loss: 1.5148
# Epoch 6/200
# 108/108 [==============================] - 0s 4ms/step - loss: 1.4043 - val_loss: 1.4660
# Epoch 7/200
# 108/108 [==============================] - 0s 4ms/step - loss: 1.3553 - val_loss: 1.4221
# Epoch 8/200
# 108/108 [==============================] - 0s 4ms/step - loss: 1.3063 - val_loss: 1.3830
# Epoch 9/200
# 108/108 [==============================] - 0s 4ms/step - loss: 1.2623 - val_loss: 1.3488
# Epoch 10/200
# 108/108 [==============================] - 0s 4ms/step - loss: 1.2208 - val_loss: 1.3152
# Epoch 11/200
# 108/108 [==============================] - 0s 4ms/step - loss: 1.1724 - val_loss: 1.2885
# Epoch 12/200
# 108/108 [==============================] - 0s 4ms/step - loss: 1.1419 - val_loss: 1.2611
# Epoch 13/200
# 108/108 [==============================] - 0s 4ms/step - loss: 1.1261 - val_loss: 1.2290
# Epoch 14/200
# 108/108 [==============================] - 0s 4ms/step - loss: 1.0893 - val_loss: 1.2033
# Epoch 15/200
# 108/108 [==============================] - 0s 4ms/step - loss: 1.0565 - val_loss: 1.1842
# Epoch 16/200
# 108/108 [==============================] - 0s 4ms/step - loss: 1.0410 - val_loss: 1.1635
# Epoch 17/200
# 108/108 [==============================] - 1s 5ms/step - loss: 1.0191 - val_loss: 1.1448
# Epoch 18/200
# 108/108 [==============================] - 1s 5ms/step - loss: 0.9897 - val_loss: 1.1218
# Epoch 19/200
# 108/108 [==============================] - 1s 5ms/step - loss: 0.9456 - val_loss: 1.0998
# Epoch 20/200
# 108/108 [==============================] - 1s 5ms/step - loss: 0.9419 - val_loss: 1.0808
# Epoch 21/200
# 108/108 [==============================] - 1s 5ms/step - loss: 0.9057 - val_loss: 1.0750
# Epoch 22/200
# 108/108 [==============================] - 1s 5ms/step - loss: 0.9118 - val_loss: 1.0487
# Epoch 23/200
# 108/108 [==============================] - 1s 5ms/step - loss: 0.8823 - val_loss: 1.0493
# Epoch 24/200
# 108/108 [==============================] - 1s 5ms/step - loss: 0.8626 - val_loss: 1.0246
# Epoch 25/200
# 108/108 [==============================] - 1s 5ms/step - loss: 0.8731 - val_loss: 1.0018
# Epoch 26/200
# 108/108 [==============================] - 1s 5ms/step - loss: 0.8360 - val_loss: 0.9830
# Epoch 27/200
# 108/108 [==============================] - 1s 5ms/step - loss: 0.8252 - val_loss: 0.9685
# Epoch 28/200
# 108/108 [==============================] - 1s 5ms/step - loss: 0.8192 - val_loss: 0.9572
# Epoch 29/200
# 108/108 [==============================] - 1s 5ms/step - loss: 0.7999 - val_loss: 0.9426
# Epoch 30/200
# 108/108 [==============================] - 0s 5ms/step - loss: 0.7746 - val_loss: 0.9460
# Epoch 31/200
# 108/108 [==============================] - 1s 5ms/step - loss: 0.8604 - val_loss: 0.9414
# Epoch 32/200
# 108/108 [==============================] - 1s 5ms/step - loss: 0.7669 - val_loss: 0.9155
# Epoch 33/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.7463 - val_loss: 0.9044
# Epoch 34/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.7363 - val_loss: 0.8900
# Epoch 35/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.7511 - val_loss: 0.8818
# Epoch 36/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.7086 - val_loss: 0.8844
# Epoch 37/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.7086 - val_loss: 0.8787
# Epoch 38/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.7186 - val_loss: 0.8687
# Epoch 39/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.7100 - val_loss: 0.8589
# Epoch 40/200
# 108/108 [==============================] - 1s 7ms/step - loss: 0.6698 - val_loss: 0.8419
# Epoch 41/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.6923 - val_loss: 0.8351
# Epoch 42/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.7124 - val_loss: 0.8288
# Epoch 43/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.6738 - val_loss: 0.8324
# Epoch 44/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.6644 - val_loss: 0.8107
# Epoch 45/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.6716 - val_loss: 0.8184
# Epoch 46/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.6158 - val_loss: 0.8056
# Epoch 47/200
# 108/108 [==============================] - 1s 7ms/step - loss: 0.6464 - val_loss: 0.7871
# Epoch 48/200
# 108/108 [==============================] - 1s 7ms/step - loss: 0.6298 - val_loss: 0.7875
# Epoch 49/200
# 108/108 [==============================] - 1s 7ms/step - loss: 0.6660 - val_loss: 0.7912
# Epoch 50/200
# 108/108 [==============================] - 1s 7ms/step - loss: 0.6026 - val_loss: 0.7766
# Epoch 51/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.6111 - val_loss: 0.7814
# Epoch 52/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.5998 - val_loss: 0.7596
# Epoch 53/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.5895 - val_loss: 0.7573
# Epoch 54/200
# 108/108 [==============================] - 1s 7ms/step - loss: 0.5877 - val_loss: 0.7538
# Epoch 55/200
# 108/108 [==============================] - 1s 7ms/step - loss: 0.5930 - val_loss: 0.7459
# Epoch 56/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.5583 - val_loss: 0.7452
# Epoch 57/200
# 108/108 [==============================] - 1s 7ms/step - loss: 0.5827 - val_loss: 0.7439
# Epoch 58/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.5517 - val_loss: 0.7485
# Epoch 59/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.5792 - val_loss: 0.7345
# Epoch 60/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.5880 - val_loss: 0.7406
# Epoch 61/200
# 108/108 [==============================] - 1s 7ms/step - loss: 0.5454 - val_loss: 0.7330
# Epoch 62/200
# 108/108 [==============================] - 1s 7ms/step - loss: 0.5927 - val_loss: 0.7447
# Epoch 63/200
# 108/108 [==============================] - 1s 7ms/step - loss: 0.5175 - val_loss: 0.7318
# Epoch 64/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.5230 - val_loss: 0.7324
# Epoch 65/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.5234 - val_loss: 0.7287
# Epoch 66/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4941 - val_loss: 0.7354
# Epoch 67/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.5139 - val_loss: 0.7300
# Epoch 68/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4741 - val_loss: 0.7473
# Epoch 69/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4881 - val_loss: 0.7139
# Epoch 70/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4907 - val_loss: 0.7220
# Epoch 71/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4867 - val_loss: 0.7187
# Epoch 72/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4873 - val_loss: 0.6935
# Epoch 73/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4898 - val_loss: 0.7172
# Epoch 74/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4933 - val_loss: 0.7330
# Epoch 75/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4607 - val_loss: 0.7045
# Epoch 76/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4669 - val_loss: 0.7075
# Epoch 77/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4555 - val_loss: 0.7677
# Epoch 78/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4563 - val_loss: 0.7093
# Epoch 79/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4655 - val_loss: 0.6882
# Epoch 80/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4329 - val_loss: 0.7304
# Epoch 81/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4308 - val_loss: 0.7038
# Epoch 82/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4205 - val_loss: 0.7053
# Epoch 83/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4568 - val_loss: 0.7166
# Epoch 84/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4388 - val_loss: 0.7680
# Epoch 85/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4598 - val_loss: 0.7124
# Epoch 86/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4553 - val_loss: 0.7046
# Epoch 87/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4356 - val_loss: 0.7560
# Epoch 88/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4412 - val_loss: 0.6910
# Epoch 89/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4309 - val_loss: 0.6848
# Epoch 90/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4271 - val_loss: 0.7201
# Epoch 91/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3853 - val_loss: 0.6754
# Epoch 92/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4470 - val_loss: 0.6999
# Epoch 93/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4418 - val_loss: 0.7036
# Epoch 94/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4347 - val_loss: 0.6832
# Epoch 95/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3956 - val_loss: 0.6681
# Epoch 96/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4314 - val_loss: 0.6856
# Epoch 97/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4249 - val_loss: 0.7635
# Epoch 98/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4235 - val_loss: 0.8698
# Epoch 99/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4552 - val_loss: 0.7370
# Epoch 100/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4339 - val_loss: 0.6924
# Epoch 101/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4293 - val_loss: 0.6862
# Epoch 102/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4286 - val_loss: 0.7087
# Epoch 103/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3922 - val_loss: 0.6929
# Epoch 104/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4048 - val_loss: 0.6803
# Epoch 105/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4113 - val_loss: 0.7126
# Epoch 106/200
# 108/108 [==============================] - 1s 5ms/step - loss: 0.4054 - val_loss: 0.6764
# Epoch 107/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4000 - val_loss: 0.6987
# Epoch 108/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4149 - val_loss: 0.7678
# Epoch 109/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3744 - val_loss: 0.7452
# Epoch 110/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3746 - val_loss: 0.7280
# Epoch 111/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4499 - val_loss: 0.7055
# Epoch 112/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4400 - val_loss: 0.6785
# Epoch 113/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3549 - val_loss: 0.7481
# Epoch 114/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3808 - val_loss: 0.8294
# Epoch 115/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3967 - val_loss: 0.7304
# Epoch 116/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4330 - val_loss: 0.7759
# Epoch 117/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4463 - val_loss: 0.7435
# Epoch 118/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3784 - val_loss: 0.7007
# Epoch 119/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4030 - val_loss: 0.6961
# Epoch 120/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3561 - val_loss: 0.7994
# Epoch 121/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3916 - val_loss: 0.7549
# Epoch 122/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3921 - val_loss: 0.7601
# Epoch 123/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3968 - val_loss: 0.7495
# Epoch 124/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3685 - val_loss: 0.7548
# Epoch 125/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3656 - val_loss: 0.8059
# Epoch 126/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3907 - val_loss: 0.7535
# Epoch 127/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4161 - val_loss: 0.6701
# Epoch 128/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3768 - val_loss: 0.7635
# Epoch 129/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4033 - val_loss: 0.7560
# Epoch 130/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3637 - val_loss: 0.8448
# Epoch 131/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3578 - val_loss: 0.6621
# Epoch 132/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3449 - val_loss: 0.6788
# Epoch 133/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3691 - val_loss: 0.6559
# Epoch 134/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3855 - val_loss: 0.7226
# Epoch 135/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3831 - val_loss: 0.6747
# Epoch 136/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3732 - val_loss: 0.7229
# Epoch 137/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3575 - val_loss: 0.7033
# Epoch 138/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3560 - val_loss: 0.8045
# Epoch 139/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4132 - val_loss: 0.7207
# Epoch 140/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4191 - val_loss: 0.7046
# Epoch 141/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3588 - val_loss: 0.7078
# Epoch 142/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.4081 - val_loss: 0.7013
# Epoch 143/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3968 - val_loss: 0.7256
# Epoch 144/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3544 - val_loss: 0.6963
# Epoch 145/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3605 - val_loss: 0.7275
# Epoch 146/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3464 - val_loss: 0.6831
# Epoch 147/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3896 - val_loss: 0.7475
# Epoch 148/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3407 - val_loss: 0.7999
# Epoch 149/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3697 - val_loss: 0.7039
# Epoch 150/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3613 - val_loss: 0.6872
# Epoch 151/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3781 - val_loss: 0.7282
# Epoch 152/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3455 - val_loss: 0.6652
# Epoch 153/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3608 - val_loss: 0.6596
# Epoch 154/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3681 - val_loss: 0.7518
# Epoch 155/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3513 - val_loss: 0.6749
# Epoch 156/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3591 - val_loss: 0.6974
# Epoch 157/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3442 - val_loss: 0.6924
# Epoch 158/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3457 - val_loss: 0.6510
# Epoch 159/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3637 - val_loss: 0.6763
# Epoch 160/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3250 - val_loss: 0.7890
# Epoch 161/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3585 - val_loss: 0.8677
# Epoch 162/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3907 - val_loss: 0.7007
# Epoch 163/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3297 - val_loss: 0.8482
# Epoch 164/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3760 - val_loss: 0.7524
# Epoch 165/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3375 - val_loss: 0.6851
# Epoch 166/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3637 - val_loss: 0.8817
# Epoch 167/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3513 - val_loss: 0.6889
# Epoch 168/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3839 - val_loss: 0.6955
# Epoch 169/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3865 - val_loss: 0.8090
# Epoch 170/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3299 - val_loss: 0.7596
# Epoch 171/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3476 - val_loss: 0.6832
# Epoch 172/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3043 - val_loss: 0.7151
# Epoch 173/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3635 - val_loss: 0.8052
# Epoch 174/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3564 - val_loss: 0.9500
# Epoch 175/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3633 - val_loss: 0.7280
# Epoch 176/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3631 - val_loss: 0.7043
# Epoch 177/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3922 - val_loss: 0.7305
# Epoch 178/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3344 - val_loss: 0.7979
# Epoch 179/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3243 - val_loss: 0.7297
# Epoch 180/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3397 - val_loss: 0.8722
# Epoch 181/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3504 - val_loss: 0.9572
# Epoch 182/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3221 - val_loss: 0.9630
# Epoch 183/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3705 - val_loss: 0.8993
# Epoch 184/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3315 - val_loss: 0.8994
# Epoch 185/200
# 108/108 [==============================] - 1s 6ms/step - loss: 0.3305 - val_loss: 0.8803
# Epoch 186/200
# 108/108 [==============================] - 1s 5ms/step - loss: 0.3411 - val_loss: 0.7001
# Epoch 187/200
# 108/108 [==============================] - 1s 5ms/step - loss: 0.3497 - val_loss: 0.7733
# Epoch 188/200
# 108/108 [==============================] - 1s 5ms/step - loss: 0.3392 - val_loss: 0.8251
# Epoch 189/200
# 108/108 [==============================] - 1s 5ms/step - loss: 0.3095 - val_loss: 0.7897
# Epoch 190/200
# 108/108 [==============================] - 1s 5ms/step - loss: 0.3154 - val_loss: 0.7321
# Epoch 191/200
# 108/108 [==============================] - 1s 5ms/step - loss: 0.3199 - val_loss: 0.9132
# Epoch 192/200
# 108/108 [==============================] - 1s 5ms/step - loss: 0.3420 - val_loss: 0.8312
# Epoch 193/200
# 108/108 [==============================] - 1s 5ms/step - loss: 0.3281 - val_loss: 0.7318
# Epoch 194/200
# 108/108 [==============================] - 1s 5ms/step - loss: 0.3466 - val_loss: 0.8603
# Epoch 195/200
# 108/108 [==============================] - 1s 5ms/step - loss: 0.3154 - val_loss: 0.8635
# Epoch 196/200
# 108/108 [==============================] - 1s 5ms/step - loss: 0.3429 - val_loss: 0.8932
# Epoch 197/200
# 108/108 [==============================] - 0s 5ms/step - loss: 0.3540 - val_loss: 0.8084
# Epoch 198/200
# 108/108 [==============================] - 0s 5ms/step - loss: 0.3200 - val_loss: 0.8254
# Epoch 199/200
# 108/108 [==============================] - 0s 5ms/step - loss: 0.3094 - val_loss: 0.8422
# Epoch 200/200
# 108/108 [==============================] - 1s 5ms/step - loss: 0.3733 - val_loss: 0.7270
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_69 (Bidirectio (None, 24, 12)            684
# _________________________________________________________________
# layer_normalization_70 (Laye (None, 24, 12)            24
# _________________________________________________________________
# bidirectional_70 (Bidirectio (None, 12)                684
# _________________________________________________________________
# dropout_51 (Dropout)         (None, 12)                0
# _________________________________________________________________
# dense_198 (Dense)            (None, 1)                 13
# =================================================================
# Total params: 1,405
# Trainable params: 1,405
# Non-trainable params: 0
# _________________________________________________________________
# Model Saved
# Predict time:  0.4085671901702881
# RMSE:  15.19041361382106
# RMSE2:  11.966163016815132
# MAE:  12.731013003985087
# MAE2:  12.731013003985087
# Text(0, 0.5, 'mse score')
