# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tcn import TCN # main library
import math
from sklearn.preprocessing import RobustScaler
#from keras.initializers import  glorot_normal, RandomUniform
#from keras import optimizers,regularizers

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import load_model 
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
df = pd.read_csv("station_bike _Soho.csv")
df["timestamp"] = pd.to_datetime(df["timestamp"])
df = df.set_index("timestamp")
#df.head()

df["hour"] = df.index.hour
df["day_of_month"] = df.index.day
df["day_of_week"]  = df.index.dayofweek
df["month"] = df.index.month

training_data_len = math.ceil(len(df) * 0.9) # taking 90% of data to train and 10% of data to test
testing_data_len = len(df) - training_data_len

time_steps = 24
train, test = df.iloc[0:training_data_len], df.iloc[(training_data_len-time_steps):len(df)]
print(df.shape, train.shape, test.shape)

train_trans = train[['t1','t2', 'hum', 'wind_speed']].to_numpy()
test_trans = test[['t1','t2', 'hum', 'wind_speed']].to_numpy()

scaler = RobustScaler() # Handles outliers
train.loc[:, ['t1','t2','hum', 'wind_speed']]=scaler.fit_transform(train_trans)
test.loc[:, ['t1','t2', 'hum', 'wind_speed']]=scaler.fit_transform(test_trans)

train['cnt'] = scaler.fit_transform(train[['cnt']])
test['cnt'] = scaler.fit_transform(test[['cnt']])

from tqdm import tqdm_notebook as tqdm

#Split the data into x_train and y_train data sets
x_train = []
y_train = []

for i in tqdm(range(len(train) - time_steps)):
    x_train.append(train.drop(columns='cnt').iloc[i:i + time_steps].to_numpy())
    y_train.append(train.loc[:,'cnt'].iloc[i + time_steps])

#Convert x_train and y_train to numpy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

#Create the x_test and y_test data sets
x_test = []
y_test = df.loc[:,'cnt'].iloc[training_data_len:len(df)]

for i in tqdm(range(len(test) - time_steps)):
    x_test.append(test.drop(columns='cnt').iloc[i:i + time_steps].to_numpy())
    # y_test.append(test.loc[:,'cnt'].iloc[i + time_steps])

#Convert x_test and y_test to numpy arrays
x_test = np.array(x_test)
y_test = np.array(y_test)

# All 12 columns of the data
print('Train size:')
print(x_train.shape, y_train.shape)
print('Test size:')
print(x_test.shape, y_test.shape)
# Out:
# (160, 13) (144, 13) (40, 13)
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:34: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/120 [00:00<?, ?it/s]
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:46: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/16 [00:00<?, ?it/s]
# Train size:
# (120, 24, 12) (120,)
# Test size:
# (16, 24, 12) (16,)

# %%
#init = glorot_normal(seed=None) # 給 LSTM
#init_d = RandomUniform(minval=-0.05, maxval=0.05) # 給 Dense layer
#nadam = optimizers.Nadam(lr=0.002,clipvalue=0.5)
from tensorflow.keras.initializers import RandomUniform
init_d = RandomUniform(minval=-0.05, maxval=0.05) # 給 Dense layer
model = Sequential()
model.add(TCN(input_shape=(x_train.shape[1],x_train.shape[2]),
        kernel_size=3,
        nb_filters=25,
        nb_stacks=1,
        dilations=(1, 2, 4, 8),
        kernel_initializer='glorot_uniform',
        use_skip_connections=True,
        use_batch_norm=False,
        use_weight_norm=False,
        use_layer_norm=True,
        dropout_rate = 0.05,
        return_sequences=True
        ))
model.add(Dropout(0.3))
model.add(TCN(
        kernel_size=3,
        nb_filters=25,
        nb_stacks=1,
        dilations=(1, 2, 4, 8),
        kernel_initializer='glorot_uniform',
        use_skip_connections=True,
        use_batch_norm=False,
        use_weight_norm=False,
        use_layer_norm=True,
        dropout_rate = 0.05,
        return_sequences=False
        ))  
model.add(Dropout(0.3))
model.add(Dense(1,kernel_initializer=init_d))  
model.summary()

print('Train...')
model.compile(optimizer = "nadam" , loss="mse")
history = model.fit(x_train, y_train, epochs=120, batch_size=12, validation_split=0.1, shuffle=True)
#Save Model
model.save('TCN_model_soho.h5')  # creates a HDF5 file 
del model

custom_ob = {'TCN': TCN}
# model = load_model('TCN_model_1.h5', custom_objects=custom_ob)
model = load_model('TCN_model_soho.h5', custom_objects=custom_ob)
print('Load Success')

import time
t1 = time.time()
y_pred = model.predict(x_test)
t2 = time.time()
print('Predict time: ',t2-t1)
y_pred = scaler.inverse_transform(y_pred)#Undo scaling

from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error
rmse_lstm = np.sqrt(mean_squared_error(y_test, y_pred))
print('RMSE: ',rmse_lstm)

mae = mean_absolute_error(y_test, y_pred)
print('MAE: ',mae)

r2 =  r2_score(y_test, y_pred)
print('R-square: ',r2)


n = len(y_test)
p = 12
Adj_r2 = 1-(1-r2)*(n-1)/(n-p-1)
print('Adj R-square: ',Adj_r2)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# tcn_2 (TCN)                  (None, 24, 20)            9860
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 24, 20)            0
# _________________________________________________________________
# tcn_3 (TCN)                  (None, 20)                10080
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 19,961
# Trainable params: 19,961
# Non-trainable params: 0
# _________________________________________________________________
# Train...
# Train on 108 samples, validate on 12 samples
# Epoch 1/120
# 108/108 [==============================] - 7s 66ms/sample - loss: 0.6014 - val_loss: 0.5951
# Epoch 2/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.5692 - val_loss: 0.5768
# Epoch 3/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.5629 - val_loss: 0.4836
# Epoch 4/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4923 - val_loss: 0.4586
# Epoch 5/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.5116 - val_loss: 0.4108
# Epoch 6/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4556 - val_loss: 0.3481
# Epoch 7/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4301 - val_loss: 0.3113
# Epoch 8/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3696 - val_loss: 0.2856
# Epoch 9/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4101 - val_loss: 0.2933
# Epoch 10/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3869 - val_loss: 0.2562
# Epoch 11/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3506 - val_loss: 0.2631
# Epoch 12/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3358 - val_loss: 0.2454
# Epoch 13/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2944 - val_loss: 0.2470
# Epoch 14/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3229 - val_loss: 0.2478
# Epoch 15/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3398 - val_loss: 0.2565
# Epoch 16/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3675 - val_loss: 0.2366
# Epoch 17/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3137 - val_loss: 0.2121
# Epoch 18/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2948 - val_loss: 0.2228
# Epoch 19/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3363 - val_loss: 0.2132
# Epoch 20/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2799 - val_loss: 0.1969
# Epoch 21/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2669 - val_loss: 0.1836
# Epoch 22/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2501 - val_loss: 0.2070
# Epoch 23/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2507 - val_loss: 0.1876
# Epoch 24/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2604 - val_loss: 0.1919
# Epoch 25/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2536 - val_loss: 0.2213
# Epoch 26/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2618 - val_loss: 0.1702
# Epoch 27/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2612 - val_loss: 0.1450
# Epoch 28/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2295 - val_loss: 0.1437
# Epoch 29/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2254 - val_loss: 0.1405
# Epoch 30/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2622 - val_loss: 0.1506
# Epoch 31/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1930 - val_loss: 0.1591
# Epoch 32/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2606 - val_loss: 0.1359
# Epoch 33/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1828 - val_loss: 0.1427
# Epoch 34/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2598 - val_loss: 0.1620
# Epoch 35/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2297 - val_loss: 0.1682
# Epoch 36/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2156 - val_loss: 0.1786
# Epoch 37/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2572 - val_loss: 0.2127
# Epoch 38/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2415 - val_loss: 0.1550
# Epoch 39/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1507 - val_loss: 0.1281
# Epoch 40/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1915 - val_loss: 0.1482
# Epoch 41/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1830 - val_loss: 0.1665
# Epoch 42/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1772 - val_loss: 0.1831
# Epoch 43/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2094 - val_loss: 0.1817
# Epoch 44/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2098 - val_loss: 0.1578
# Epoch 45/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1499 - val_loss: 0.2366
# Epoch 46/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1763 - val_loss: 0.1447
# Epoch 47/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1884 - val_loss: 0.1989
# Epoch 48/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1382 - val_loss: 0.1807
# Epoch 49/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1212 - val_loss: 0.1448
# Epoch 50/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1887 - val_loss: 0.1519
# Epoch 51/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1851 - val_loss: 0.1989
# Epoch 52/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1662 - val_loss: 0.1419
# Epoch 53/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1100 - val_loss: 0.1792
# Epoch 54/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1294 - val_loss: 0.1569
# Epoch 55/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1746 - val_loss: 0.1158
# Epoch 56/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1485 - val_loss: 0.1156
# Epoch 57/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1389 - val_loss: 0.1039
# Epoch 58/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1687 - val_loss: 0.1228
# Epoch 59/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1236 - val_loss: 0.1566
# Epoch 60/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1606 - val_loss: 0.1515
# Epoch 61/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1591 - val_loss: 0.1115
# Epoch 62/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1217 - val_loss: 0.1454
# Epoch 63/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1401 - val_loss: 0.1747
# Epoch 64/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1324 - val_loss: 0.1408
# Epoch 65/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1122 - val_loss: 0.1554
# Epoch 66/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1775 - val_loss: 0.1412
# Epoch 67/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1754 - val_loss: 0.1613
# Epoch 68/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1354 - val_loss: 0.1071
# Epoch 69/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1122 - val_loss: 0.1076
# Epoch 70/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1350 - val_loss: 0.1159
# Epoch 71/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1504 - val_loss: 0.1579
# Epoch 72/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0975 - val_loss: 0.1531
# Epoch 73/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1474 - val_loss: 0.1146
# Epoch 74/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0887 - val_loss: 0.1115
# Epoch 75/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1049 - val_loss: 0.1171
# Epoch 76/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1468 - val_loss: 0.1667
# Epoch 77/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1595 - val_loss: 0.1566
# Epoch 78/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1368 - val_loss: 0.1565
# Epoch 79/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1482 - val_loss: 0.1076
# Epoch 80/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1980 - val_loss: 0.1358
# Epoch 81/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1161 - val_loss: 0.1188
# Epoch 82/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1043 - val_loss: 0.1377
# Epoch 83/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1436 - val_loss: 0.1535
# Epoch 84/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1176 - val_loss: 0.1354
# Epoch 85/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1005 - val_loss: 0.1392
# Epoch 86/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1250 - val_loss: 0.1363
# Epoch 87/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1020 - val_loss: 0.1315
# Epoch 88/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1056 - val_loss: 0.1424
# Epoch 89/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1226 - val_loss: 0.1394
# Epoch 90/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1034 - val_loss: 0.1681
# Epoch 91/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1250 - val_loss: 0.1551
# Epoch 92/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1028 - val_loss: 0.1278
# Epoch 93/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1426 - val_loss: 0.1366
# Epoch 94/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1547 - val_loss: 0.1372
# Epoch 95/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0829 - val_loss: 0.1734
# Epoch 96/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0969 - val_loss: 0.1439
# Epoch 97/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1026 - val_loss: 0.1268
# Epoch 98/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1307 - val_loss: 0.1491
# Epoch 99/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0834 - val_loss: 0.1568
# Epoch 100/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1012 - val_loss: 0.1622
# Epoch 101/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0987 - val_loss: 0.1725
# Epoch 102/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0865 - val_loss: 0.1574
# Epoch 103/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1398 - val_loss: 0.1155
# Epoch 104/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0995 - val_loss: 0.1192
# Epoch 105/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0997 - val_loss: 0.1176
# Epoch 106/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1395 - val_loss: 0.1208
# Epoch 107/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1004 - val_loss: 0.1134
# Epoch 108/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1066 - val_loss: 0.1219
# Epoch 109/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0873 - val_loss: 0.1436
# Epoch 110/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0797 - val_loss: 0.1374
# Epoch 111/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0974 - val_loss: 0.1322
# Epoch 112/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0942 - val_loss: 0.1201
# Epoch 113/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0882 - val_loss: 0.1416
# Epoch 114/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1118 - val_loss: 0.1496
# Epoch 115/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0972 - val_loss: 0.1539
# Epoch 116/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1294 - val_loss: 0.1637
# Epoch 117/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0675 - val_loss: 0.1623
# Epoch 118/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1124 - val_loss: 0.1287
# Epoch 119/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1081 - val_loss: 0.1453
# Epoch 120/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0837 - val_loss: 0.1449
# Load Success
# Predict time:  0.6349618434906006
# RMSE:  14.585537710918238
# MAE:  11.283328086137772
# R-square:  -1.374058633001492
# Adj R-square:  -10.87029316500746
