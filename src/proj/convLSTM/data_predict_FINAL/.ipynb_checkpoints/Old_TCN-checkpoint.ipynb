# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tcn import TCN # main library
import math
from sklearn.preprocessing import RobustScaler
#from keras.initializers import  glorot_normal, RandomUniform
#from keras import optimizers,regularizers

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import load_model 
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
df = pd.read_csv("station_bike _Old.csv")
df["timestamp"] = pd.to_datetime(df["timestamp"])
df = df.set_index("timestamp")
#df.head()

df["hour"] = df.index.hour
df["day_of_month"] = df.index.day
df["day_of_week"]  = df.index.dayofweek
df["month"] = df.index.month

training_data_len = math.ceil(len(df) * 0.9) # taking 90% of data to train and 10% of data to test
testing_data_len = len(df) - training_data_len

time_steps = 24
train, test = df.iloc[0:training_data_len], df.iloc[(training_data_len-time_steps):len(df)]
print(df.shape, train.shape, test.shape)

train_trans = train[['t1','t2', 'hum', 'wind_speed']].to_numpy()
test_trans = test[['t1','t2', 'hum', 'wind_speed']].to_numpy()

scaler = RobustScaler() # Handles outliers
train.loc[:, ['t1','t2','hum', 'wind_speed']]=scaler.fit_transform(train_trans)
test.loc[:, ['t1','t2', 'hum', 'wind_speed']]=scaler.fit_transform(test_trans)

train['cnt'] = scaler.fit_transform(train[['cnt']])
test['cnt'] = scaler.fit_transform(test[['cnt']])

from tqdm import tqdm_notebook as tqdm

#Split the data into x_train and y_train data sets
x_train = []
y_train = []

for i in tqdm(range(len(train) - time_steps)):
    x_train.append(train.drop(columns='cnt').iloc[i:i + time_steps].to_numpy())
    y_train.append(train.loc[:,'cnt'].iloc[i + time_steps])

#Convert x_train and y_train to numpy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

#Create the x_test and y_test data sets
x_test = []
y_test = df.loc[:,'cnt'].iloc[training_data_len:len(df)]

for i in tqdm(range(len(test) - time_steps)):
    x_test.append(test.drop(columns='cnt').iloc[i:i + time_steps].to_numpy())
    # y_test.append(test.loc[:,'cnt'].iloc[i + time_steps])

#Convert x_test and y_test to numpy arrays
x_test = np.array(x_test)
y_test = np.array(y_test)

# All 12 columns of the data
print('Train size:')
print(x_train.shape, y_train.shape)
print('Test size:')
print(x_test.shape, y_test.shape)
# Out:
# (160, 13) (144, 13) (40, 13)
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:34: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/120 [00:00<?, ?it/s]
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:46: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/16 [00:00<?, ?it/s]
# Train size:
# (120, 24, 12) (120,)
# Test size:
# (16, 24, 12) (16,)

# %%
#init = glorot_normal(seed=None) # 給 LSTM
#init_d = RandomUniform(minval=-0.05, maxval=0.05) # 給 Dense layer
#nadam = optimizers.Nadam(lr=0.002,clipvalue=0.5)
from tensorflow.keras.initializers import RandomUniform
init_d = RandomUniform(minval=-0.05, maxval=0.05) # 給 Dense layer
model = Sequential()
model.add(TCN(input_shape=(x_train.shape[1],x_train.shape[2]),
        kernel_size=3,
        nb_filters=25,
        nb_stacks=1,
        dilations=(1, 2, 4, 8),
        kernel_initializer='glorot_uniform',
        use_skip_connections=True,
        use_batch_norm=False,
        use_weight_norm=False,
        use_layer_norm=True,
        dropout_rate = 0.05,
        return_sequences=True
        ))
model.add(Dropout(0.5))
model.add(TCN(
        kernel_size=3,
        nb_filters=25,
        nb_stacks=1,
        dilations=(1, 2, 4, 8),
        kernel_initializer='glorot_uniform',
        use_skip_connections=True,
        use_batch_norm=False,
        use_weight_norm=False,
        use_layer_norm=True,
        dropout_rate = 0.05,
        return_sequences=False
        ))  
model.add(Dropout(0.3))
model.add(Dense(1,kernel_initializer=init_d))  
model.summary()

print('Train...')
model.compile(optimizer = "nadam" , loss="mse")
history = model.fit(x_train, y_train, epochs=120, batch_size=12, validation_split=0.1, shuffle=True)
#Save Model
model.save('TCN_model_OLD.h5')  # creates a HDF5 file 
del model

custom_ob = {'TCN': TCN}
# model = load_model('TCN_model_1.h5', custom_objects=custom_ob)
model = load_model('TCN_model_OLD.h5', custom_objects=custom_ob)
print('Load Success')

import time
t1 = time.time()
y_pred = model.predict(x_test)
t2 = time.time()
print('Predict time: ',t2-t1)
y_pred = scaler.inverse_transform(y_pred)#Undo scaling

from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error
rmse_lstm = np.sqrt(mean_squared_error(y_test, y_pred))
print('RMSE: ',rmse_lstm)

mae = mean_absolute_error(y_test, y_pred)
print('MAE: ',mae)

r2 =  r2_score(y_test, y_pred)
print('R-square: ',r2)

n = len(y_test)
p = 12
Adj_r2 = 1-(1-r2)*(n-1)/(n-p-1)
print('Adj R-square: ',Adj_r2)

plt.plot(history.history["loss"],label="loss")
plt.plot(history.history["val_loss"],label="val_loss")
plt.legend(loc="best")
plt.xlabel("No. Of Epochs")
plt.ylabel("mse score")
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# tcn_2 (TCN)                  (None, 24, 20)            9860
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 24, 20)            0
# _________________________________________________________________
# tcn_3 (TCN)                  (None, 20)                10080
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 19,961
# Trainable params: 19,961
# Non-trainable params: 0
# _________________________________________________________________
# Train...
# Train on 108 samples, validate on 12 samples
# Epoch 1/120
# 108/108 [==============================] - 7s 61ms/sample - loss: 0.9822 - val_loss: 0.5925
# Epoch 2/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.8524 - val_loss: 0.5031
# Epoch 3/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.8359 - val_loss: 0.4850
# Epoch 4/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.8794 - val_loss: 0.4777
# Epoch 5/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.8369 - val_loss: 0.4484
# Epoch 6/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.8039 - val_loss: 0.4000
# Epoch 7/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.8029 - val_loss: 0.3476
# Epoch 8/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.7226 - val_loss: 0.3160
# Epoch 9/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.6090 - val_loss: 0.3158
# Epoch 10/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.6850 - val_loss: 0.2914
# Epoch 11/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.6475 - val_loss: 0.2849
# Epoch 12/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.6264 - val_loss: 0.2781
# Epoch 13/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.6587 - val_loss: 0.3037
# Epoch 14/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.5970 - val_loss: 0.2663
# Epoch 15/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.5624 - val_loss: 0.2706
# Epoch 16/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4700 - val_loss: 0.2236
# Epoch 17/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4156 - val_loss: 0.2584
# Epoch 18/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.5136 - val_loss: 0.2177
# Epoch 19/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4942 - val_loss: 0.2369
# Epoch 20/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4475 - val_loss: 0.1903
# Epoch 21/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3620 - val_loss: 0.2028
# Epoch 22/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4230 - val_loss: 0.2105
# Epoch 23/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3406 - val_loss: 0.2087
# Epoch 24/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3505 - val_loss: 0.2017
# Epoch 25/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3964 - val_loss: 0.3013
# Epoch 26/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.4604 - val_loss: 0.2940
# Epoch 27/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3475 - val_loss: 0.2468
# Epoch 28/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3366 - val_loss: 0.2009
# Epoch 29/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3323 - val_loss: 0.2034
# Epoch 30/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2991 - val_loss: 0.1728
# Epoch 31/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3308 - val_loss: 0.1164
# Epoch 32/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3201 - val_loss: 0.1898
# Epoch 33/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2625 - val_loss: 0.1242
# Epoch 34/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2912 - val_loss: 0.1969
# Epoch 35/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1971 - val_loss: 0.2186
# Epoch 36/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2623 - val_loss: 0.1778
# Epoch 37/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2050 - val_loss: 0.1286
# Epoch 38/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1909 - val_loss: 0.1510
# Epoch 39/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2045 - val_loss: 0.1150
# Epoch 40/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2100 - val_loss: 0.1159
# Epoch 41/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2449 - val_loss: 0.1321
# Epoch 42/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1985 - val_loss: 0.1258
# Epoch 43/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1668 - val_loss: 0.1828
# Epoch 44/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1993 - val_loss: 0.1796
# Epoch 45/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2129 - val_loss: 0.2590
# Epoch 46/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2197 - val_loss: 0.1414
# Epoch 47/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2259 - val_loss: 0.1013
# Epoch 48/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1755 - val_loss: 0.1134
# Epoch 49/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2215 - val_loss: 0.1320
# Epoch 50/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2053 - val_loss: 0.1508
# Epoch 51/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1713 - val_loss: 0.1143
# Epoch 52/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1741 - val_loss: 0.1770
# Epoch 53/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2394 - val_loss: 0.1478
# Epoch 54/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1601 - val_loss: 0.1654
# Epoch 55/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1797 - val_loss: 0.1281
# Epoch 56/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1829 - val_loss: 0.1201
# Epoch 57/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1604 - val_loss: 0.1218
# Epoch 58/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1840 - val_loss: 0.0964
# Epoch 59/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2614 - val_loss: 0.0752
# Epoch 60/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1803 - val_loss: 0.1538
# Epoch 61/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1977 - val_loss: 0.1026
# Epoch 62/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2018 - val_loss: 0.0726
# Epoch 63/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1547 - val_loss: 0.1272
# Epoch 64/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1764 - val_loss: 0.1052
# Epoch 65/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1451 - val_loss: 0.1088
# Epoch 66/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1609 - val_loss: 0.1387
# Epoch 67/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1784 - val_loss: 0.1212
# Epoch 68/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1731 - val_loss: 0.1318
# Epoch 69/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2258 - val_loss: 0.1460
# Epoch 70/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1680 - val_loss: 0.1249
# Epoch 71/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1456 - val_loss: 0.1054
# Epoch 72/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2116 - val_loss: 0.1203
# Epoch 73/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1735 - val_loss: 0.1431
# Epoch 74/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1596 - val_loss: 0.1778
# Epoch 75/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1849 - val_loss: 0.1770
# Epoch 76/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1973 - val_loss: 0.1365
# Epoch 77/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1340 - val_loss: 0.1310
# Epoch 78/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1468 - val_loss: 0.0957
# Epoch 79/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1253 - val_loss: 0.1016
# Epoch 80/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1732 - val_loss: 0.1286
# Epoch 81/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1696 - val_loss: 0.1296
# Epoch 82/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1640 - val_loss: 0.1189
# Epoch 83/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1836 - val_loss: 0.1092
# Epoch 84/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1677 - val_loss: 0.1157
# Epoch 85/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1163 - val_loss: 0.1210
# Epoch 86/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2309 - val_loss: 0.1088
# Epoch 87/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1520 - val_loss: 0.0999
# Epoch 88/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1742 - val_loss: 0.0903
# Epoch 89/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1295 - val_loss: 0.0816
# Epoch 90/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1767 - val_loss: 0.0779
# Epoch 91/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1499 - val_loss: 0.0911
# Epoch 92/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1339 - val_loss: 0.0904
# Epoch 93/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1495 - val_loss: 0.0846
# Epoch 94/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1139 - val_loss: 0.0934
# Epoch 95/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1674 - val_loss: 0.0873
# Epoch 96/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1393 - val_loss: 0.1029
# Epoch 97/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1480 - val_loss: 0.0886
# Epoch 98/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1754 - val_loss: 0.0659
# Epoch 99/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1332 - val_loss: 0.0722
# Epoch 100/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1516 - val_loss: 0.0815
# Epoch 101/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1437 - val_loss: 0.0811
# Epoch 102/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1690 - val_loss: 0.0854
# Epoch 103/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1430 - val_loss: 0.0858
# Epoch 104/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1678 - val_loss: 0.0873
# Epoch 105/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1174 - val_loss: 0.0873
# Epoch 106/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1553 - val_loss: 0.0811
# Epoch 107/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1760 - val_loss: 0.0979
# Epoch 108/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1510 - val_loss: 0.1087
# Epoch 109/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1424 - val_loss: 0.0903
# Epoch 110/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1626 - val_loss: 0.1132
# Epoch 111/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1280 - val_loss: 0.0819
# Epoch 112/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1662 - val_loss: 0.0990
# Epoch 113/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1501 - val_loss: 0.0902
# Epoch 114/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1694 - val_loss: 0.0921
# Epoch 115/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1670 - val_loss: 0.0820
# Epoch 116/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1560 - val_loss: 0.0826
# Epoch 117/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1371 - val_loss: 0.1048
# Epoch 118/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1252 - val_loss: 0.0918
# Epoch 119/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1480 - val_loss: 0.0881
# Epoch 120/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1062 - val_loss: 0.1068
# Load Success
# Predict time:  0.6921477317810059
# RMSE:  6.678813790342635
# MAE:  4.998379945755005
# R-square:  -1.9745448641297636
# Adj R-square:  -13.87272432064882
# Text(0, 0.5, 'mse score')
