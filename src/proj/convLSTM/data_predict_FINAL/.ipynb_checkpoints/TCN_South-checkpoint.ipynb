# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tcn import TCN # main library
import math
from sklearn.preprocessing import RobustScaler
#from keras.initializers import  glorot_normal, RandomUniform
#from keras import optimizers,regularizers

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import load_model 
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
df = pd.read_csv("station_bike _South.csv")
df["timestamp"] = pd.to_datetime(df["timestamp"])
df = df.set_index("timestamp")
#df.head()

df["hour"] = df.index.hour
df["day_of_month"] = df.index.day
df["day_of_week"]  = df.index.dayofweek
df["month"] = df.index.month

training_data_len = math.ceil(len(df) * 0.9) # taking 90% of data to train and 10% of data to test
testing_data_len = len(df) - training_data_len

time_steps = 24
train, test = df.iloc[0:training_data_len], df.iloc[(training_data_len-time_steps):len(df)]
print(df.shape, train.shape, test.shape)

train_trans = train[['t1','t2', 'hum', 'wind_speed']].to_numpy()
test_trans = test[['t1','t2', 'hum', 'wind_speed']].to_numpy()

scaler = RobustScaler() # Handles outliers
train.loc[:, ['t1','t2','hum', 'wind_speed']]=scaler.fit_transform(train_trans)
test.loc[:, ['t1','t2', 'hum', 'wind_speed']]=scaler.fit_transform(test_trans)

train['cnt'] = scaler.fit_transform(train[['cnt']])
test['cnt'] = scaler.fit_transform(test[['cnt']])

from tqdm import tqdm_notebook as tqdm

#Split the data into x_train and y_train data sets
x_train = []
y_train = []

for i in tqdm(range(len(train) - time_steps)):
    x_train.append(train.drop(columns='cnt').iloc[i:i + time_steps].to_numpy())
    y_train.append(train.loc[:,'cnt'].iloc[i + time_steps])

#Convert x_train and y_train to numpy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

#Create the x_test and y_test data sets
x_test = []
y_test = df.loc[:,'cnt'].iloc[training_data_len:len(df)]

for i in tqdm(range(len(test) - time_steps)):
    x_test.append(test.drop(columns='cnt').iloc[i:i + time_steps].to_numpy())
    # y_test.append(test.loc[:,'cnt'].iloc[i + time_steps])

#Convert x_test and y_test to numpy arrays
x_test = np.array(x_test)
y_test = np.array(y_test)

# All 12 columns of the data
print('Train size:')
print(x_train.shape, y_train.shape)
print('Test size:')
print(x_test.shape, y_test.shape)
# Out:
# (160, 13) (144, 13) (40, 13)
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:34: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/120 [00:00<?, ?it/s]
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:46: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/16 [00:00<?, ?it/s]
# Train size:
# (120, 24, 12) (120,)
# Test size:
# (16, 24, 12) (16,)

# %%
#init = glorot_normal(seed=None) # 給 LSTM
#init_d = RandomUniform(minval=-0.05, maxval=0.05) # 給 Dense layer
#nadam = optimizers.Nadam(lr=0.002,clipvalue=0.5)
from tensorflow.keras.initializers import RandomUniform
init_d = RandomUniform(minval=-0.05, maxval=0.05) # 給 Dense layer
model = Sequential()
model.add(TCN(input_shape=(x_train.shape[1],x_train.shape[2]),
        kernel_size=3,
        nb_filters=20,
        nb_stacks=1,
        dilations=(1, 2, 4, 8),
        kernel_initializer='glorot_uniform',
        use_skip_connections=True,
        use_batch_norm=False,
        use_weight_norm=False,
        use_layer_norm=True,
        dropout_rate = 0.05,
        return_sequences=True
        ))
model.add(Dropout(0.3))
model.add(TCN(
        kernel_size=3,
        nb_filters=20,
        nb_stacks=1,
        dilations=(1, 2, 4, 8),
        kernel_initializer='glorot_uniform',
        use_skip_connections=True,
        use_batch_norm=False,
        use_weight_norm=False,
        use_layer_norm=True,
        dropout_rate = 0.05,
        return_sequences=False
        ))  
model.add(Dropout(0.3))
model.add(Dense(1,kernel_initializer=init_d))  
model.summary()

print('Train...')
model.compile(optimizer = "nadam" , loss="mse")
history = model.fit(x_train, y_train, epochs=120, batch_size=12, validation_split=0.1, shuffle=True)
#Save Model
model.save('TCN_model_south.h5')  # creates a HDF5 file 
del model

custom_ob = {'TCN': TCN}
# model = load_model('TCN_model_1.h5', custom_objects=custom_ob)
model = load_model('TCN_model_south.h5', custom_objects=custom_ob)
print('Load Success')

import time
t1 = time.time()
y_pred = model.predict(x_test)
t2 = time.time()
print('Predict time: ',t2-t1)
y_pred = scaler.inverse_transform(y_pred)#Undo scaling

from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error
rmse_lstm = np.sqrt(mean_squared_error(y_test, y_pred))
print('RMSE: ',rmse_lstm)

mae = mean_absolute_error(y_test, y_pred)
print('MAE: ',mae)

r2 =  r2_score(y_test, y_pred)
print('R-square: ',r2)


n = len(y_test)
p = 12
Adj_r2 = 1-(1-r2)*(n-1)/(n-p-1)
print('Adj R-square: ',Adj_r2)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# tcn_2 (TCN)                  (None, 24, 20)            9860
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 24, 20)            0
# _________________________________________________________________
# tcn_3 (TCN)                  (None, 20)                10080
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 19,961
# Trainable params: 19,961
# Non-trainable params: 0
# _________________________________________________________________
# Train...
# Train on 108 samples, validate on 12 samples
# Epoch 1/120
# 108/108 [==============================] - 7s 64ms/sample - loss: 1.0151 - val_loss: 0.6034
# Epoch 2/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 1.0270 - val_loss: 0.6238
# Epoch 3/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 1.0601 - val_loss: 0.6561
# Epoch 4/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.9203 - val_loss: 0.5887
# Epoch 5/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.9845 - val_loss: 0.5460
# Epoch 6/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 1.0604 - val_loss: 0.5511
# Epoch 7/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 1.0074 - val_loss: 0.5751
# Epoch 8/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.9825 - val_loss: 0.5692
# Epoch 9/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.9552 - val_loss: 0.5421
# Epoch 10/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.9661 - val_loss: 0.5015
# Epoch 11/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.9173 - val_loss: 0.4093
# Epoch 12/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.9633 - val_loss: 0.3958
# Epoch 13/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.8932 - val_loss: 0.3127
# Epoch 14/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.8025 - val_loss: 0.2760
# Epoch 15/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.7568 - val_loss: 0.2837
# Epoch 16/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.7389 - val_loss: 0.1848
# Epoch 17/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.6180 - val_loss: 0.2188
# Epoch 18/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.7019 - val_loss: 0.1719
# Epoch 19/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.6371 - val_loss: 0.1551
# Epoch 20/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.8091 - val_loss: 0.1880
# Epoch 21/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.7829 - val_loss: 0.1612
# Epoch 22/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.6022 - val_loss: 0.1910
# Epoch 23/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.5647 - val_loss: 0.2363
# Epoch 24/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4546 - val_loss: 0.2331
# Epoch 25/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4751 - val_loss: 0.1737
# Epoch 26/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.5196 - val_loss: 0.1641
# Epoch 27/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.5374 - val_loss: 0.1675
# Epoch 28/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.5126 - val_loss: 0.1780
# Epoch 29/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4372 - val_loss: 0.2273
# Epoch 30/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.6236 - val_loss: 0.2226
# Epoch 31/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.5402 - val_loss: 0.2008
# Epoch 32/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4111 - val_loss: 0.2454
# Epoch 33/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.6466 - val_loss: 0.2116
# Epoch 34/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4384 - val_loss: 0.1877
# Epoch 35/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4807 - val_loss: 0.2051
# Epoch 36/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4861 - val_loss: 0.2257
# Epoch 37/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4960 - val_loss: 0.2586
# Epoch 38/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.5222 - val_loss: 0.2708
# Epoch 39/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4542 - val_loss: 0.2693
# Epoch 40/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4046 - val_loss: 0.3103
# Epoch 41/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4126 - val_loss: 0.3323
# Epoch 42/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4733 - val_loss: 0.2782
# Epoch 43/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3704 - val_loss: 0.2793
# Epoch 44/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3932 - val_loss: 0.2540
# Epoch 45/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3502 - val_loss: 0.2315
# Epoch 46/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4406 - val_loss: 0.2467
# Epoch 47/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4506 - val_loss: 0.2558
# Epoch 48/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4676 - val_loss: 0.2867
# Epoch 49/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3578 - val_loss: 0.2123
# Epoch 50/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4242 - val_loss: 0.1995
# Epoch 51/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3149 - val_loss: 0.2437
# Epoch 52/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4153 - val_loss: 0.2692
# Epoch 53/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3822 - val_loss: 0.2484
# Epoch 54/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3924 - val_loss: 0.2295
# Epoch 55/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3235 - val_loss: 0.2879
# Epoch 56/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.5052 - val_loss: 0.2998
# Epoch 57/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3204 - val_loss: 0.3011
# Epoch 58/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3619 - val_loss: 0.2739
# Epoch 59/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3430 - val_loss: 0.2808
# Epoch 60/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3375 - val_loss: 0.3099
# Epoch 61/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4382 - val_loss: 0.2493
# Epoch 62/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3808 - val_loss: 0.2915
# Epoch 63/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3144 - val_loss: 0.2792
# Epoch 64/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2797 - val_loss: 0.2831
# Epoch 65/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3140 - val_loss: 0.2937
# Epoch 66/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2767 - val_loss: 0.2556
# Epoch 67/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3489 - val_loss: 0.2701
# Epoch 68/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3531 - val_loss: 0.2565
# Epoch 69/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2612 - val_loss: 0.2928
# Epoch 70/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3190 - val_loss: 0.2896
# Epoch 71/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3727 - val_loss: 0.2843
# Epoch 72/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2686 - val_loss: 0.2966
# Epoch 73/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2693 - val_loss: 0.2733
# Epoch 74/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2924 - val_loss: 0.2871
# Epoch 75/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2248 - val_loss: 0.3077
# Epoch 76/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2601 - val_loss: 0.3502
# Epoch 77/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3336 - val_loss: 0.2820
# Epoch 78/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2344 - val_loss: 0.2718
# Epoch 79/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1966 - val_loss: 0.2845
# Epoch 80/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2547 - val_loss: 0.3812
# Epoch 81/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2149 - val_loss: 0.3500
# Epoch 82/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2924 - val_loss: 0.3287
# Epoch 83/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3278 - val_loss: 0.2981
# Epoch 84/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2311 - val_loss: 0.3041
# Epoch 85/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2493 - val_loss: 0.3171
# Epoch 86/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3010 - val_loss: 0.3381
# Epoch 87/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3394 - val_loss: 0.2505
# Epoch 88/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2863 - val_loss: 0.2905
# Epoch 89/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3086 - val_loss: 0.2975
# Epoch 90/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2656 - val_loss: 0.3079
# Epoch 91/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3377 - val_loss: 0.2896
# Epoch 92/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2608 - val_loss: 0.2772
# Epoch 93/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2405 - val_loss: 0.2471
# Epoch 94/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2367 - val_loss: 0.3122
# Epoch 95/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3295 - val_loss: 0.3294
# Epoch 96/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2545 - val_loss: 0.2881
# Epoch 97/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4224 - val_loss: 0.3739
# Epoch 98/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3820 - val_loss: 0.1949
# Epoch 99/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2321 - val_loss: 0.2285
# Epoch 100/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2928 - val_loss: 0.2158
# Epoch 101/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3152 - val_loss: 0.2792
# Epoch 102/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1732 - val_loss: 0.2615
# Epoch 103/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2408 - val_loss: 0.2880
# Epoch 104/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2404 - val_loss: 0.3060
# Epoch 105/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2365 - val_loss: 0.3494
# Epoch 106/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3436 - val_loss: 0.2246
# Epoch 107/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3473 - val_loss: 0.4166
# Epoch 108/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2226 - val_loss: 0.3968
# Epoch 109/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2916 - val_loss: 0.3428
# Epoch 110/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3488 - val_loss: 0.3470
# Epoch 111/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1965 - val_loss: 0.3359
# Epoch 112/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2327 - val_loss: 0.2721
# Epoch 113/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.5483 - val_loss: 0.2293
# Epoch 114/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3206 - val_loss: 0.2497
# Epoch 115/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3084 - val_loss: 0.2971
# Epoch 116/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3181 - val_loss: 0.2814
# Epoch 117/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3293 - val_loss: 0.2816
# Epoch 118/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2716 - val_loss: 0.2537
# Epoch 119/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2232 - val_loss: 0.2688
# Epoch 120/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2238 - val_loss: 0.2761
# Load Success
# Predict time:  0.7171077728271484
# RMSE:  2.6991388498596467
# MAE:  1.9433936178684235
# R-square:  -3.200562468221495
# Adj R-square:  -20.002812341107475
