# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
import math
from sklearn.preprocessing import RobustScaler, MinMaxScaler
from tqdm import tqdm_notebook as tqdm
from tcn import TCN
import time
from sklearn.metrics import mean_squared_error, r2_score
from keras.preprocessing import sequence
from keras.models import Sequential , load_model , Model
from keras.layers import Dense, Dropout , LSTM , Bidirectional ,GRU ,Flatten,Add,BatchNormalization
from keras_layer_normalization import LayerNormalization
from keras.initializers import  glorot_normal, RandomUniform
from keras import optimizers,Input
from keras_self_attention import SeqSelfAttention
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv("london_merged.csv")
df["timestamp"] = pd.to_datetime(df["timestamp"])
df = df.set_index("timestamp")
#df.head()

df["hour"] = df.index.hour
df["day_of_month"] = df.index.day
df["day_of_week"]  = df.index.dayofweek
df["month"] = df.index.month

training_data_len = math.ceil(len(df) * 0.9) # taking 90% of data to train and 10% of data to test
testing_data_len = len(df) - training_data_len

time_steps = 24
train, test = df.iloc[0:training_data_len], df.iloc[(training_data_len-time_steps):len(df)]
print(df.shape, train.shape, test.shape)
train_trans = train[['t1','t2', 'hum', 'wind_speed']].to_numpy()
test_trans = test[['t1','t2', 'hum', 'wind_speed']].to_numpy()

scaler = RobustScaler() # Handles outliers
#scaler = MinMaxScaler(feature_range=(0, 1)) # scale to (0,1)
train.loc[:, ['t1','t2','hum', 'wind_speed']]=scaler.fit_transform(train_trans)
test.loc[:, ['t1','t2', 'hum', 'wind_speed']]=scaler.fit_transform(test_trans)

train['cnt'] = scaler.fit_transform(train[['cnt']])
test['cnt'] = scaler.fit_transform(test[['cnt']])

#Split the data into x_train and y_train data sets
x_train = []
y_train = []

for i in tqdm(range(len(train) - time_steps)):
    x_train.append(train.drop(columns='cnt').iloc[i:i + time_steps].to_numpy())
    y_train.append(train.loc[:,'cnt'].iloc[i + time_steps])

#Convert x_train and y_train to numpy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

#Create the x_test and y_test data sets
x_test = []
y_test = df.loc[:,'cnt'].iloc[training_data_len:len(df)]

for i in tqdm(range(len(test) - time_steps)):
    x_test.append(test.drop(columns='cnt').iloc[i:i + time_steps].to_numpy())
    # y_test.append(test.loc[:,'cnt'].iloc[i + time_steps])

#Convert x_test and y_test to numpy arrays
x_test = np.array(x_test)
y_test = np.array(y_test)

# All 12 columns of the data
print('Train size:')
print(x_train.shape, y_train.shape)
print('Test size:')
print(x_test.shape, y_test.shape)
# Out:
# (17414, 13) (15673, 13) (1765, 13)
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:32: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/15649 [00:00<?, ?it/s]
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:44: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/1741 [00:00<?, ?it/s]
# Train size:
# (15649, 24, 12) (15649,)
# Test size:
# (1741, 24, 12) (1741,)

# %%
from keras.layers import Concatenate
init = glorot_normal(seed=None) # 給 GRU
init_d = RandomUniform(minval=-0.05, maxval=0.05) # 給 Dense layer

def Encoder(layer):
    shortcut = layer
    layer = SeqSelfAttention(
                     attention_type=SeqSelfAttention.ATTENTION_TYPE_MUL,
                     kernel_regularizer=tf.keras.regularizers.l2(0.01),
                     bias_regularizer=tf.keras.regularizers.l2(0.01),
                     attention_regularizer_weight=0.001)(layer)
    layer = Add()([layer,shortcut])
    layer = LayerNormalization()(layer)
    layer = Flatten()(layer)
    
    shortcut2 = layer
    layer = Dense(32,kernel_initializer=init_d)(layer)
    layer = Dropout(0.3)(layer)
    layer = Concatenate()([layer,shortcut2])
    output = Dense(1,kernel_initializer=init_d)(layer)
    return output

def Decoder(layer):
    shortcut = layer
    layer = SeqSelfAttention(
                     attention_type=SeqSelfAttention.ATTENTION_TYPE_MUL,
                     kernel_regularizer=tf.keras.regularizers.l2(0.01),
                     bias_regularizer=tf.keras.regularizers.l2(0.01),
                     attention_regularizer_weight=0.001)(layer)
    layer = Add()([layer,shortcut])
    layer = LayerNormalization()(layer)
    layer = SeqSelfAttention(
                     attention_type=SeqSelfAttention.ATTENTION_TYPE_MUL,
                     kernel_regularizer=tf.keras.regularizers.l2(0.01),
                     bias_regularizer=tf.keras.regularizers.l2(0.01),
                     attention_regularizer_weight=0.001)(layer)
    layer = LayerNormalization()(layer)
    
    layer = Flatten()(layer)
    shortcut2 = layer
    layer = Dense(32,kernel_initializer=init_d)(layer)
    layer = Dropout(0.3)(layer)
    layer = Concatenate()([layer,shortcut2])
    output = Dense(1,kernel_initializer=init_d)(layer)
    return output

def Bi_GRU(layer,unit):
    output = Bidirectional(GRU(unit, dropout=0.1, recurrent_dropout=0.1, return_sequences=True,
                            kernel_initializer=init))(layer)
    return output
def Bi_GRU2(layer,unit):
    output = GRU(unit, dropout=0.15, recurrent_dropout=0.15, return_sequences=True,
                            kernel_initializer=init)(layer)
    return output

# %%
#start = Input(shape = (x_train.shape[1],x_train.shape[2]))
start = Input(shape = (x_train.shape[1:]))
start2 = Input(shape = (x_train.shape[1:]))
x = Bi_GRU2(start,32)
x = Encoder(x)

y = Bi_GRU2(start2,64)
y = Decoder(y)

Merge = Add()([x,y])
# Merge = Add()([x,x])
Last = Dense(1)(Merge)
model = Model([start,start2] , Last)
model.summary()
# Out:
# Model: "model_13"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_26 (InputLayer)           (None, 24, 12)       0
# __________________________________________________________________________________________________
# gru_26 (GRU)                    (None, 24, 64)       14784       input_26[0][0]
# __________________________________________________________________________________________________
# input_25 (InputLayer)           (None, 24, 12)       0
# __________________________________________________________________________________________________
# seq_self_attention_38 (SeqSelfA (None, 24, 64)       4097        gru_26[0][0]
# __________________________________________________________________________________________________
# gru_25 (GRU)                    (None, 24, 32)       4320        input_25[0][0]
# __________________________________________________________________________________________________
# add_38 (Add)                    (None, 24, 64)       0           seq_self_attention_38[0][0]
#                                                                  gru_26[0][0]
# __________________________________________________________________________________________________
# seq_self_attention_37 (SeqSelfA (None, 24, 32)       1025        gru_25[0][0]
# __________________________________________________________________________________________________
# layer_normalization_38 (LayerNo (None, 24, 64)       128         add_38[0][0]
# __________________________________________________________________________________________________
# add_37 (Add)                    (None, 24, 32)       0           seq_self_attention_37[0][0]
#                                                                  gru_25[0][0]
# __________________________________________________________________________________________________
# seq_self_attention_39 (SeqSelfA (None, 24, 64)       4097        layer_normalization_38[0][0]
# __________________________________________________________________________________________________
# layer_normalization_37 (LayerNo (None, 24, 32)       64          add_37[0][0]
# __________________________________________________________________________________________________
# layer_normalization_39 (LayerNo (None, 24, 64)       128         seq_self_attention_39[0][0]
# __________________________________________________________________________________________________
# flatten_25 (Flatten)            (None, 768)          0           layer_normalization_37[0][0]
# __________________________________________________________________________________________________
# flatten_26 (Flatten)            (None, 1536)         0           layer_normalization_39[0][0]
# __________________________________________________________________________________________________
# dense_61 (Dense)                (None, 32)           24608       flatten_25[0][0]
# __________________________________________________________________________________________________
# dense_63 (Dense)                (None, 32)           49184       flatten_26[0][0]
# __________________________________________________________________________________________________
# dropout_25 (Dropout)            (None, 32)           0           dense_61[0][0]
# __________________________________________________________________________________________________
# dropout_26 (Dropout)            (None, 32)           0           dense_63[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 800)          0           dropout_25[0][0]
#                                                                  flatten_25[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 1568)         0           dropout_26[0][0]
#                                                                  flatten_26[0][0]
# __________________________________________________________________________________________________
# dense_62 (Dense)                (None, 1)            801         concatenate_25[0][0]
# __________________________________________________________________________________________________
# dense_64 (Dense)                (None, 1)            1569        concatenate_26[0][0]
# __________________________________________________________________________________________________
# add_39 (Add)                    (None, 1)            0           dense_62[0][0]
#                                                                  dense_64[0][0]
# __________________________________________________________________________________________________
# dense_65 (Dense)                (None, 1)            2           add_39[0][0]
# ==================================================================================================
# Total params: 104,807
# Trainable params: 104,807
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
print('Train...')
model.compile(optimizer = "nadam" , loss="mse")
history = model.fit([x_train,x_train], y_train, epochs = 150, batch_size=24, validation_split=0.1, shuffle=True)
model.summary()
#Save Model
model.save('GRU_Single_Attention_model_NO_BI.h5')  # creates a HDF5 file 
del model
# Out:
# Train...
# Train on 14084 samples, validate on 1565 samples
# Epoch 1/200
# 14084/14084 [==============================] - 27s 2ms/step - loss: 0.8612 - val_loss: 0.7830
# Epoch 2/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.3177 - val_loss: 0.2704
# Epoch 3/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.2599 - val_loss: 0.2130
# Epoch 4/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.2301 - val_loss: 0.2527
# Epoch 5/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.2153 - val_loss: 0.1977
# Epoch 6/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.2114 - val_loss: 0.1789
# Epoch 7/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1995 - val_loss: 0.2202
# Epoch 8/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1962 - val_loss: 0.2064
# Epoch 9/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1870 - val_loss: 0.2343
# Epoch 10/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1955 - val_loss: 0.1927
# Epoch 11/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1889 - val_loss: 0.1642
# Epoch 12/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1818 - val_loss: 0.1563
# Epoch 13/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1833 - val_loss: 0.1728
# Epoch 14/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1816 - val_loss: 0.1735
# Epoch 15/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1750 - val_loss: 0.1611
# Epoch 16/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1804 - val_loss: 0.1738
# Epoch 17/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1862 - val_loss: 0.1617
# Epoch 18/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1697 - val_loss: 0.1545
# Epoch 19/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1700 - val_loss: 0.1346
# Epoch 20/200
# 14084/14084 [==============================] - 33s 2ms/step - loss: 0.1790 - val_loss: 0.1544
# Epoch 21/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1732 - val_loss: 0.1477
# Epoch 22/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1671 - val_loss: 0.1756
# Epoch 23/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1784 - val_loss: 0.1540
# Epoch 24/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1798 - val_loss: 0.1538
# Epoch 25/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1748 - val_loss: 0.1656
# Epoch 26/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1753 - val_loss: 0.1692
# Epoch 27/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1706 - val_loss: 0.1625
# Epoch 28/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1720 - val_loss: 0.1555
# Epoch 29/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1639 - val_loss: 0.1526
# Epoch 30/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1628 - val_loss: 0.1345
# Epoch 31/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1606 - val_loss: 0.1516
# Epoch 32/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1765 - val_loss: 0.1356
# Epoch 33/200
# 14084/14084 [==============================] - 33s 2ms/step - loss: 0.1696 - val_loss: 0.1341
# Epoch 34/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1667 - val_loss: 0.1563
# Epoch 35/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1728 - val_loss: 0.1430
# Epoch 36/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1607 - val_loss: 0.1322
# Epoch 37/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1642 - val_loss: 0.1432
# Epoch 38/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1787 - val_loss: 0.1625
# Epoch 39/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1591 - val_loss: 0.1497
# Epoch 40/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1566 - val_loss: 0.1400
# Epoch 41/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1604 - val_loss: 0.1453
# Epoch 42/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1622 - val_loss: 0.1324
# Epoch 43/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1657 - val_loss: 0.1302
# Epoch 44/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1594 - val_loss: 0.1927
# Epoch 45/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1559 - val_loss: 0.1322
# Epoch 46/200
# 14084/14084 [==============================] - 33s 2ms/step - loss: 0.1543 - val_loss: 0.1301
# Epoch 47/200
# 14084/14084 [==============================] - 33s 2ms/step - loss: 0.1576 - val_loss: 0.1307
# Epoch 48/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1614 - val_loss: 0.1402
# Epoch 49/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1775 - val_loss: 0.1590
# Epoch 50/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1695 - val_loss: 0.1534
# Epoch 51/200
# 14084/14084 [==============================] - 33s 2ms/step - loss: 0.1586 - val_loss: 0.1291
# Epoch 52/200
# 14084/14084 [==============================] - 34s 2ms/step - loss: 0.1523 - val_loss: 0.1333
# Epoch 53/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1544 - val_loss: 0.1235
# Epoch 54/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1560 - val_loss: 0.1270
# Epoch 55/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1545 - val_loss: 0.1237
# Epoch 56/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1548 - val_loss: 0.1226
# Epoch 57/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1554 - val_loss: 0.1233
# Epoch 58/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1536 - val_loss: 0.1307
# Epoch 59/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1520 - val_loss: 0.1371
# Epoch 60/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1570 - val_loss: 0.1460
# Epoch 61/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1559 - val_loss: 0.1256
# Epoch 62/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1508 - val_loss: 0.1433
# Epoch 63/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1543 - val_loss: 0.1270
# Epoch 64/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1571 - val_loss: 0.1344
# Epoch 65/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1529 - val_loss: 0.1305
# Epoch 66/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1599 - val_loss: 0.1244
# Epoch 67/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1541 - val_loss: 0.1289
# Epoch 68/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1522 - val_loss: 0.1325
# Epoch 69/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1502 - val_loss: 0.1419
# Epoch 70/200
# 14084/14084 [==============================] - 26s 2ms/step - loss: 0.1510 - val_loss: 0.1531
# Epoch 71/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1526 - val_loss: 0.1677
# Epoch 72/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1526 - val_loss: 0.1235
# Epoch 73/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1478 - val_loss: 0.1371
# Epoch 74/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1538 - val_loss: 0.1327
# Epoch 75/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1551 - val_loss: 0.1310
# Epoch 76/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1516 - val_loss: 0.1353
# Epoch 77/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1494 - val_loss: 0.1362
# Epoch 78/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1567 - val_loss: 0.2269
# Epoch 79/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1561 - val_loss: 0.1352
# Epoch 80/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1476 - val_loss: 0.1229
# Epoch 81/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1460 - val_loss: 0.1298
# Epoch 82/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1462 - val_loss: 0.1305
# Epoch 83/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1506 - val_loss: 0.1334
# Epoch 84/200
# 14084/14084 [==============================] - 26s 2ms/step - loss: 0.1603 - val_loss: 0.1247
# Epoch 85/200
# 14084/14084 [==============================] - 26s 2ms/step - loss: 0.1514 - val_loss: 0.1177
# Epoch 86/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1479 - val_loss: 0.1390
# Epoch 87/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1456 - val_loss: 0.1323
# Epoch 88/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1522 - val_loss: 0.1310
# Epoch 89/200
# 14084/14084 [==============================] - 26s 2ms/step - loss: 0.1482 - val_loss: 0.1233
# Epoch 90/200
# 14084/14084 [==============================] - 26s 2ms/step - loss: 0.1468 - val_loss: 0.1340
# Epoch 91/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1464 - val_loss: 0.1273
# Epoch 92/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1474 - val_loss: 0.1240
# Epoch 93/200
# 14084/14084 [==============================] - 26s 2ms/step - loss: 0.1416 - val_loss: 0.1211
# Epoch 94/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1445 - val_loss: 0.1401
# Epoch 95/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1435 - val_loss: 0.1179
# Epoch 96/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1511 - val_loss: 0.1199
# Epoch 97/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1488 - val_loss: 0.1280
# Epoch 98/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1450 - val_loss: 0.1200
# Epoch 99/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1443 - val_loss: 0.1178
# Epoch 100/200
# 14084/14084 [==============================] - 26s 2ms/step - loss: 0.1629 - val_loss: 0.1180
# Epoch 101/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1532 - val_loss: 0.1181
# Epoch 102/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1504 - val_loss: 0.1157
# Epoch 103/200
# 14084/14084 [==============================] - 26s 2ms/step - loss: 0.1474 - val_loss: 0.1209
# Epoch 104/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1475 - val_loss: 0.1223
# Epoch 105/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1566 - val_loss: 0.1169
# Epoch 106/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1453 - val_loss: 0.1327
# Epoch 107/200
# 14084/14084 [==============================] - 26s 2ms/step - loss: 0.1442 - val_loss: 0.1327
# Epoch 108/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1440 - val_loss: 0.1266
# Epoch 109/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1408 - val_loss: 0.1229
# Epoch 110/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1504 - val_loss: 0.1295
# Epoch 111/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1494 - val_loss: 0.1182
# Epoch 112/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1401 - val_loss: 0.1182
# Epoch 113/200
# 14084/14084 [==============================] - 30s 2ms/step - loss: 0.1410 - val_loss: 0.1325
# Epoch 114/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1552 - val_loss: 0.1255
# Epoch 115/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1611 - val_loss: 0.1210
# Epoch 116/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1532 - val_loss: 0.1260
# Epoch 117/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1498 - val_loss: 0.1235
# Epoch 118/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1493 - val_loss: 0.1329
# Epoch 119/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1461 - val_loss: 0.1265
# Epoch 120/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1497 - val_loss: 0.1192
# Epoch 121/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1450 - val_loss: 0.1291
# Epoch 122/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1517 - val_loss: 0.1202
# Epoch 123/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1477 - val_loss: 0.1279
# Epoch 124/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1538 - val_loss: 0.1296
# Epoch 125/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1528 - val_loss: 0.1418
# Epoch 126/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1453 - val_loss: 0.2030
# Epoch 127/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1478 - val_loss: 0.1235
# Epoch 128/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1520 - val_loss: 0.1484
# Epoch 129/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1472 - val_loss: 0.1242
# Epoch 130/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1460 - val_loss: 0.1183
# Epoch 131/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1452 - val_loss: 0.1290
# Epoch 132/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1456 - val_loss: 0.1257
# Epoch 133/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1460 - val_loss: 0.1273
# Epoch 134/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1444 - val_loss: 0.1211
# Epoch 135/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1434 - val_loss: 0.1163
# Epoch 136/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1420 - val_loss: 0.1204
# Epoch 137/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1401 - val_loss: 0.1245
# Epoch 138/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1432 - val_loss: 0.1193
# Epoch 139/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1423 - val_loss: 0.1249
# Epoch 140/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1447 - val_loss: 0.1237
# Epoch 141/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1407 - val_loss: 0.1114
# Epoch 142/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1496 - val_loss: 0.1188
# Epoch 143/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1451 - val_loss: 0.1268
# Epoch 144/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1506 - val_loss: 0.1345
# Epoch 145/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1563 - val_loss: 0.1279
# Epoch 146/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1481 - val_loss: 0.1335
# Epoch 147/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1496 - val_loss: 0.1468
# Epoch 148/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1511 - val_loss: 0.1335
# Epoch 149/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1530 - val_loss: 0.1207
# Epoch 150/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1482 - val_loss: 0.1332
# Epoch 151/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1591 - val_loss: 0.1323
# Epoch 152/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1479 - val_loss: 0.1175
# Epoch 153/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1468 - val_loss: 0.1139
# Epoch 154/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1434 - val_loss: 0.1217
# Epoch 155/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1506 - val_loss: 0.1216
# Epoch 156/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1466 - val_loss: 0.1236
# Epoch 157/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1418 - val_loss: 0.1173
# Epoch 158/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1471 - val_loss: 0.1296
# Epoch 159/200
# 14084/14084 [==============================] - 33s 2ms/step - loss: 0.1482 - val_loss: 0.1261
# Epoch 160/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1525 - val_loss: 0.1305
# Epoch 161/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1517 - val_loss: 0.1350
# Epoch 162/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1436 - val_loss: 0.1224
# Epoch 163/200
# 14084/14084 [==============================] - 33s 2ms/step - loss: 0.1429 - val_loss: 0.1162
# Epoch 164/200
# 14084/14084 [==============================] - 33s 2ms/step - loss: 0.1461 - val_loss: 0.1194
# Epoch 165/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1559 - val_loss: 0.1345
# Epoch 166/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1753 - val_loss: 0.1323
# Epoch 167/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1692 - val_loss: 0.1250
# Epoch 168/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1622 - val_loss: 0.1252
# Epoch 169/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1713 - val_loss: 0.1303
# Epoch 170/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1726 - val_loss: 0.1278
# Epoch 171/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1676 - val_loss: 0.1280
# Epoch 172/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1654 - val_loss: 0.1220
# Epoch 173/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1677 - val_loss: 0.1215
# Epoch 174/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1754 - val_loss: 0.1457
# Epoch 175/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1721 - val_loss: 0.1943
# Epoch 176/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1687 - val_loss: 0.1323
# Epoch 177/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1670 - val_loss: 0.1255
# Epoch 178/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1627 - val_loss: 0.1303
# Epoch 179/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1601 - val_loss: 0.1230
# Epoch 180/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1639 - val_loss: 0.1358
# Epoch 181/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1630 - val_loss: 0.1270
# Epoch 182/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1538 - val_loss: 0.1397
# Epoch 183/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1544 - val_loss: 0.1221
# Epoch 184/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1644 - val_loss: 0.1332
# Epoch 185/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1704 - val_loss: 0.1724
# Epoch 186/200
# 14084/14084 [==============================] - 31s 2ms/step - loss: 0.1688 - val_loss: 0.1427
# Epoch 187/200
# 14084/14084 [==============================] - 27s 2ms/step - loss: 0.1616 - val_loss: 0.1374
# Epoch 188/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1537 - val_loss: 0.1366
# Epoch 189/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1596 - val_loss: 0.1204
# Epoch 190/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1537 - val_loss: 0.1224
# Epoch 191/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1565 - val_loss: 0.1321
# Epoch 192/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1585 - val_loss: 0.1415
# Epoch 193/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1678 - val_loss: 0.1319
# Epoch 194/200
# 14084/14084 [==============================] - 25s 2ms/step - loss: 0.1702 - val_loss: 0.1356
# Epoch 195/200
# 14084/14084 [==============================] - 28s 2ms/step - loss: 0.1587 - val_loss: 0.1203
# Epoch 196/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1568 - val_loss: 0.1515
# Epoch 197/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1613 - val_loss: 0.1337
# Epoch 198/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1580 - val_loss: 0.1329
# Epoch 199/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1606 - val_loss: 0.1275
# Epoch 200/200
# 14084/14084 [==============================] - 32s 2ms/step - loss: 0.1587 - val_loss: 0.1378
# Model: "model_12"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_24 (InputLayer)           (None, 24, 12)       0
# __________________________________________________________________________________________________
# gru_24 (GRU)                    (None, 24, 64)       14784       input_24[0][0]
# __________________________________________________________________________________________________
# input_23 (InputLayer)           (None, 24, 12)       0
# __________________________________________________________________________________________________
# seq_self_attention_35 (SeqSelfA (None, 24, 64)       4097        gru_24[0][0]
# __________________________________________________________________________________________________
# gru_23 (GRU)                    (None, 24, 32)       4320        input_23[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, 24, 64)       0           seq_self_attention_35[0][0]
#                                                                  gru_24[0][0]
# __________________________________________________________________________________________________
# seq_self_attention_34 (SeqSelfA (None, 24, 32)       1025        gru_23[0][0]
# __________________________________________________________________________________________________
# layer_normalization_35 (LayerNo (None, 24, 64)       128         add_35[0][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, 24, 32)       0           seq_self_attention_34[0][0]
#                                                                  gru_23[0][0]
# __________________________________________________________________________________________________
# seq_self_attention_36 (SeqSelfA (None, 24, 64)       4097        layer_normalization_35[0][0]
# __________________________________________________________________________________________________
# layer_normalization_34 (LayerNo (None, 24, 32)       64          add_34[0][0]
# __________________________________________________________________________________________________
# layer_normalization_36 (LayerNo (None, 24, 64)       128         seq_self_attention_36[0][0]
# __________________________________________________________________________________________________
# flatten_23 (Flatten)            (None, 768)          0           layer_normalization_34[0][0]
# __________________________________________________________________________________________________
# flatten_24 (Flatten)            (None, 1536)         0           layer_normalization_36[0][0]
# __________________________________________________________________________________________________
# dense_56 (Dense)                (None, 32)           24608       flatten_23[0][0]
# __________________________________________________________________________________________________
# dense_58 (Dense)                (None, 32)           49184       flatten_24[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 32)           0           dense_56[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 32)           0           dense_58[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 800)          0           dropout_23[0][0]
#                                                                  flatten_23[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 1568)         0           dropout_24[0][0]
#                                                                  flatten_24[0][0]
# __________________________________________________________________________________________________
# dense_57 (Dense)                (None, 1)            801         concatenate_23[0][0]
# __________________________________________________________________________________________________
# dense_59 (Dense)                (None, 1)            1569        concatenate_24[0][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, 1)            0           dense_57[0][0]
#                                                                  dense_59[0][0]
# __________________________________________________________________________________________________
# dense_60 (Dense)                (None, 1)            2           add_36[0][0]
# ==================================================================================================
# Total params: 104,807
# Trainable params: 104,807
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
custom_ob = {'LayerNormalization': LayerNormalization , 'SeqSelfAttention':SeqSelfAttention,'TCN':TCN}
model = load_model('GRU_Single_Attention_model_NO_BI.h5', custom_objects=custom_ob)
t1 = time.time()
y_pred = model.predict([x_test,x_test])
t2 = time.time()
print('Predict time: ',t2-t1)
y_pred = scaler.inverse_transform(y_pred)#Undo scaling

rmse_lstm = np.sqrt(mean_squared_error(y_test, y_pred))
print('RMSE: ',rmse_lstm)

r2 =  r2_score(y_test, y_pred)
print('R-square: ',r2)

n = len(y_test)
p = 12
Adj_r2 = 1-(1-r2)*(n-1)/(n-p-1)
print('Adj R-square: ',r2)

plt.plot(history.history["loss"],label="loss")
plt.plot(history.history["val_loss"],label="val_loss")
plt.legend(loc="best")
plt.xlabel("No. Of Epochs")
plt.ylabel("mse score")
# Out:
# Predict time:  0.9151082038879395
# RMSE:  392.8097663471313
# R-square:  0.8212850754938751
# Adj R-square:  0.8212850754938751
# Text(0, 0.5, 'mse score')

# %%
plt.figure(figsize=(16, 8))
plt.plot(y_test, label='true')
plt.plot(y_pred, label='predicted')
plt.legend()

# %%
plt.figure(figsize=(16, 8))
plt.plot(y_test[1200:1500], label='true')
plt.plot(y_pred[1200:1500], label='predicted')
plt.legend()
