# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tcn import TCN # main library
import math
from sklearn.preprocessing import RobustScaler
#from keras.initializers import  glorot_normal, RandomUniform
#from keras import optimizers,regularizers

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import load_model 
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
df = pd.read_csv("station_bike _Old.csv")
df["timestamp"] = pd.to_datetime(df["timestamp"])
df = df.set_index("timestamp")
#df.head()

df["hour"] = df.index.hour
df["day_of_month"] = df.index.day
df["day_of_week"]  = df.index.dayofweek
df["month"] = df.index.month

training_data_len = math.ceil(len(df) * 0.9) # taking 90% of data to train and 10% of data to test
testing_data_len = len(df) - training_data_len

time_steps = 24
train, test = df.iloc[0:training_data_len], df.iloc[(training_data_len-time_steps):len(df)]
print(df.shape, train.shape, test.shape)

train_trans = train[['t1','t2', 'hum', 'wind_speed']].to_numpy()
test_trans = test[['t1','t2', 'hum', 'wind_speed']].to_numpy()

scaler = RobustScaler() # Handles outliers
train.loc[:, ['t1','t2','hum', 'wind_speed']]=scaler.fit_transform(train_trans)
test.loc[:, ['t1','t2', 'hum', 'wind_speed']]=scaler.fit_transform(test_trans)

train['cnt'] = scaler.fit_transform(train[['cnt']])
test['cnt'] = scaler.fit_transform(test[['cnt']])

from tqdm import tqdm_notebook as tqdm

#Split the data into x_train and y_train data sets
x_train = []
y_train = []

for i in tqdm(range(len(train) - time_steps)):
    x_train.append(train.drop(columns='cnt').iloc[i:i + time_steps].to_numpy())
    y_train.append(train.loc[:,'cnt'].iloc[i + time_steps])

#Convert x_train and y_train to numpy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

#Create the x_test and y_test data sets
x_test = []
y_test = df.loc[:,'cnt'].iloc[training_data_len:len(df)]

for i in tqdm(range(len(test) - time_steps)):
    x_test.append(test.drop(columns='cnt').iloc[i:i + time_steps].to_numpy())
    # y_test.append(test.loc[:,'cnt'].iloc[i + time_steps])

#Convert x_test and y_test to numpy arrays
x_test = np.array(x_test)
y_test = np.array(y_test)

# All 12 columns of the data
print('Train size:')
print(x_train.shape, y_train.shape)
print('Test size:')
print(x_test.shape, y_test.shape)
# Out:
# (160, 13) (144, 13) (40, 13)
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:34: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/120 [00:00<?, ?it/s]
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:46: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/16 [00:00<?, ?it/s]
# Train size:
# (120, 24, 12) (120,)
# Test size:
# (16, 24, 12) (16,)

# %%
#init = glorot_normal(seed=None) # 給 LSTM
#init_d = RandomUniform(minval=-0.05, maxval=0.05) # 給 Dense layer
#nadam = optimizers.Nadam(lr=0.002,clipvalue=0.5)
from tensorflow.keras.initializers import RandomUniform
init_d = RandomUniform(minval=-0.05, maxval=0.05) # 給 Dense layer
model = Sequential()
model.add(TCN(input_shape=(x_train.shape[1],x_train.shape[2]),
        kernel_size=3,
        nb_filters=25,
        nb_stacks=1,
        dilations=(1, 2, 4, 8),
        kernel_initializer='glorot_uniform',
        use_skip_connections=True,
        use_batch_norm=False,
        use_weight_norm=False,
        use_layer_norm=True,
        dropout_rate = 0.05,
        return_sequences=True
        ))
model.add(Dropout(0.5))
model.add(TCN(
        kernel_size=3,
        nb_filters=25,
        nb_stacks=1,
        dilations=(1, 2, 4, 8),
        kernel_initializer='glorot_uniform',
        use_skip_connections=True,
        use_batch_norm=False,
        use_weight_norm=False,
        use_layer_norm=True,
        dropout_rate = 0.05,
        return_sequences=False
        ))  
model.add(Dropout(0.3))
model.add(Dense(1,kernel_initializer=init_d))  
model.summary()

print('Train...')
model.compile(optimizer = "nadam" , loss="mse")
history = model.fit(x_train, y_train, epochs=120, batch_size=12, validation_split=0.1, shuffle=True)
#Save Model
model.save('TCN_model_pit.h5')  # creates a HDF5 file 
del model

custom_ob = {'TCN': TCN}
# model = load_model('TCN_model_1.h5', custom_objects=custom_ob)
model = load_model('TCN_model_pit.h5', custom_objects=custom_ob)
print('Load Success')

import time
t1 = time.time()
y_pred = model.predict(x_test)
t2 = time.time()
print('Predict time: ',t2-t1)
y_pred = scaler.inverse_transform(y_pred)#Undo scaling

from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error
rmse_lstm = np.sqrt(mean_squared_error(y_test, y_pred))
print('RMSE: ',rmse_lstm)

mae = mean_absolute_error(y_test, y_pred)
print('MAE: ',mae)

r2 =  r2_score(y_test, y_pred)
print('R-square: ',r2)


n = len(y_test)
p = 12
Adj_r2 = 1-(1-r2)*(n-1)/(n-p-1)
print('Adj R-square: ',Adj_r2)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# tcn_2 (TCN)                  (None, 24, 20)            9860
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 24, 20)            0
# _________________________________________________________________
# tcn_3 (TCN)                  (None, 20)                10080
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 19,961
# Trainable params: 19,961
# Non-trainable params: 0
# _________________________________________________________________
# Train...
# Train on 108 samples, validate on 12 samples
# Epoch 1/120
# 108/108 [==============================] - 5s 50ms/sample - loss: 0.8573 - val_loss: 0.5111
# Epoch 2/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.9225 - val_loss: 0.4968
# Epoch 3/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.8595 - val_loss: 0.4734
# Epoch 4/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.8379 - val_loss: 0.4338
# Epoch 5/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.8516 - val_loss: 0.4001
# Epoch 6/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.8335 - val_loss: 0.4094
# Epoch 7/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.7359 - val_loss: 0.3376
# Epoch 8/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.7013 - val_loss: 0.4010
# Epoch 9/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.6662 - val_loss: 0.3642
# Epoch 10/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.5950 - val_loss: 0.3267
# Epoch 11/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.7063 - val_loss: 0.2816
# Epoch 12/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.5924 - val_loss: 0.1936
# Epoch 13/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.5808 - val_loss: 0.1737
# Epoch 14/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.5798 - val_loss: 0.1917
# Epoch 15/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.4693 - val_loss: 0.1763
# Epoch 16/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.4517 - val_loss: 0.1853
# Epoch 17/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.4027 - val_loss: 0.1661
# Epoch 18/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.4021 - val_loss: 0.1045
# Epoch 19/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.4157 - val_loss: 0.1183
# Epoch 20/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3114 - val_loss: 0.1466
# Epoch 21/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2878 - val_loss: 0.1269
# Epoch 22/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3399 - val_loss: 0.1171
# Epoch 23/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3380 - val_loss: 0.1421
# Epoch 24/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3140 - val_loss: 0.1178
# Epoch 25/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2485 - val_loss: 0.1511
# Epoch 26/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3001 - val_loss: 0.1559
# Epoch 27/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2701 - val_loss: 0.1159
# Epoch 28/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3663 - val_loss: 0.1234
# Epoch 29/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2371 - val_loss: 0.1585
# Epoch 30/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2124 - val_loss: 0.1352
# Epoch 31/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3053 - val_loss: 0.1933
# Epoch 32/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2654 - val_loss: 0.1721
# Epoch 33/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2633 - val_loss: 0.1625
# Epoch 34/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2172 - val_loss: 0.1481
# Epoch 35/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2827 - val_loss: 0.1395
# Epoch 36/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2533 - val_loss: 0.1602
# Epoch 37/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2079 - val_loss: 0.1512
# Epoch 38/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1906 - val_loss: 0.1208
# Epoch 39/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2516 - val_loss: 0.1487
# Epoch 40/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1988 - val_loss: 0.1568
# Epoch 41/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2290 - val_loss: 0.1405
# Epoch 42/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2579 - val_loss: 0.1485
# Epoch 43/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2594 - val_loss: 0.1748
# Epoch 44/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2641 - val_loss: 0.1699
# Epoch 45/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2295 - val_loss: 0.1853
# Epoch 46/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1823 - val_loss: 0.2147
# Epoch 47/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2362 - val_loss: 0.1916
# Epoch 48/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2132 - val_loss: 0.1536
# Epoch 49/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2656 - val_loss: 0.1471
# Epoch 50/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2183 - val_loss: 0.1866
# Epoch 51/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2442 - val_loss: 0.1823
# Epoch 52/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1908 - val_loss: 0.2137
# Epoch 53/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1517 - val_loss: 0.1870
# Epoch 54/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2485 - val_loss: 0.2029
# Epoch 55/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1634 - val_loss: 0.2054
# Epoch 56/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2060 - val_loss: 0.1792
# Epoch 57/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1306 - val_loss: 0.1598
# Epoch 58/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1625 - val_loss: 0.1199
# Epoch 59/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1729 - val_loss: 0.1488
# Epoch 60/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1297 - val_loss: 0.1743
# Epoch 61/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2402 - val_loss: 0.1817
# Epoch 62/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1828 - val_loss: 0.1700
# Epoch 63/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1582 - val_loss: 0.1979
# Epoch 64/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1681 - val_loss: 0.2222
# Epoch 65/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1821 - val_loss: 0.1885
# Epoch 66/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2106 - val_loss: 0.1634
# Epoch 67/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2006 - val_loss: 0.1776
# Epoch 68/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1679 - val_loss: 0.2161
# Epoch 69/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1719 - val_loss: 0.1708
# Epoch 70/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1498 - val_loss: 0.2040
# Epoch 71/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2029 - val_loss: 0.2064
# Epoch 72/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1701 - val_loss: 0.1919
# Epoch 73/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1740 - val_loss: 0.1432
# Epoch 74/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1484 - val_loss: 0.1428
# Epoch 75/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2236 - val_loss: 0.1936
# Epoch 76/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1499 - val_loss: 0.2111
# Epoch 77/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1700 - val_loss: 0.2095
# Epoch 78/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1648 - val_loss: 0.1977
# Epoch 79/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1761 - val_loss: 0.2099
# Epoch 80/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1479 - val_loss: 0.1885
# Epoch 81/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1863 - val_loss: 0.1670
# Epoch 82/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1485 - val_loss: 0.1305
# Epoch 83/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1626 - val_loss: 0.1484
# Epoch 84/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1506 - val_loss: 0.1826
# Epoch 85/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1756 - val_loss: 0.2177
# Epoch 86/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1887 - val_loss: 0.1777
# Epoch 87/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1414 - val_loss: 0.1882
# Epoch 88/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1332 - val_loss: 0.1657
# Epoch 89/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1646 - val_loss: 0.1896
# Epoch 90/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1743 - val_loss: 0.1598
# Epoch 91/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1569 - val_loss: 0.1574
# Epoch 92/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1113 - val_loss: 0.1780
# Epoch 93/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1183 - val_loss: 0.1690
# Epoch 94/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1763 - val_loss: 0.1538
# Epoch 95/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1732 - val_loss: 0.1572
# Epoch 96/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1573 - val_loss: 0.1633
# Epoch 97/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1501 - val_loss: 0.1573
# Epoch 98/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1707 - val_loss: 0.1599
# Epoch 99/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1950 - val_loss: 0.1129
# Epoch 100/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1484 - val_loss: 0.1277
# Epoch 101/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1642 - val_loss: 0.1191
# Epoch 102/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1736 - val_loss: 0.1089
# Epoch 103/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1444 - val_loss: 0.1187
# Epoch 104/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1310 - val_loss: 0.1110
# Epoch 105/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1578 - val_loss: 0.1078
# Epoch 106/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2133 - val_loss: 0.1281
# Epoch 107/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1509 - val_loss: 0.1193
# Epoch 108/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1393 - val_loss: 0.1134
# Epoch 109/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1638 - val_loss: 0.1275
# Epoch 110/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1545 - val_loss: 0.1242
# Epoch 111/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1639 - val_loss: 0.1147
# Epoch 112/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1536 - val_loss: 0.1723
# Epoch 113/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1261 - val_loss: 0.1547
# Epoch 114/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1926 - val_loss: 0.1301
# Epoch 115/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1620 - val_loss: 0.1663
# Epoch 116/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1232 - val_loss: 0.1330
# Epoch 117/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1666 - val_loss: 0.1435
# Epoch 118/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1324 - val_loss: 0.1293
# Epoch 119/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1566 - val_loss: 0.1410
# Epoch 120/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1352 - val_loss: 0.1408
# Load Success
# Predict time:  0.7465684413909912
# RMSE:  5.142617643295498
# MAE:  4.318658918142319
# R-square:  -0.7635603421813861
# Adj R-square:  -7.817801710906931
