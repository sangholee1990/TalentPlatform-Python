# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
import math
from sklearn.preprocessing import RobustScaler
from tqdm import tqdm_notebook as tqdm
from keras.preprocessing import sequence
from keras.models import Sequential , load_model
from keras.layers import Dense, Dropout , LSTM , Bidirectional ,GRU
from keras_layer_normalization import LayerNormalization
from keras.initializers import  glorot_normal, RandomUniform
from keras import optimizers
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv("london_merged.csv")
df["timestamp"] = pd.to_datetime(df["timestamp"])
df = df.set_index("timestamp")
#df.head()

df["hour"] = df.index.hour
df["day_of_month"] = df.index.day
df["day_of_week"]  = df.index.dayofweek
df["month"] = df.index.month
df.head()
# Out:
#                      cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#                      is_holiday  is_weekend  season  hour  day_of_month  \
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0     0             4
# 2015-01-04 01:00:00         0.0         1.0     3.0     1             4
# 2015-01-04 02:00:00         0.0         1.0     3.0     2             4
# 2015-01-04 03:00:00         0.0         1.0     3.0     3             4
# 2015-01-04 04:00:00         0.0         1.0     3.0     4             4
#
#                      day_of_week  month
# timestamp
# 2015-01-04 00:00:00            6      1
# 2015-01-04 01:00:00            6      1
# 2015-01-04 02:00:00            6      1
# 2015-01-04 03:00:00            6      1
# 2015-01-04 04:00:00            6      1

# %%
training_data_len = math.ceil(len(df) * 0.9) # taking 90% of data to train and 10% of data to test
testing_data_len = len(df) - training_data_len

time_steps = 24
train, test = df.iloc[0:training_data_len], df.iloc[(training_data_len-time_steps):len(df)]
print(df.shape, train.shape, test.shape)
# Out:
# (17414, 13) (15673, 13) (1765, 13)

# %%
train_trans = train[['t1','t2', 'hum', 'wind_speed']].to_numpy()
test_trans = test[['t1','t2', 'hum', 'wind_speed']].to_numpy()

scaler = RobustScaler() # Handles outliers
train.loc[:, ['t1','t2','hum', 'wind_speed']]=scaler.fit_transform(train_trans)
test.loc[:, ['t1','t2', 'hum', 'wind_speed']]=scaler.fit_transform(test_trans)
train['cnt'] = scaler.fit_transform(train[['cnt']])
test['cnt'] = scaler.fit_transform(test[['cnt']])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Split the data into x_train and y_train data sets
x_train = []
y_train = []

for i in tqdm(range(len(train) - time_steps)):
    x_train.append(train.drop(columns='cnt').iloc[i:i + time_steps].to_numpy())
    y_train.append(train.loc[:,'cnt'].iloc[i + time_steps])

#Convert x_train and y_train to numpy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   """
#   0%|          | 0/15649 [00:00<?, ?it/s]

# %%
#Create the x_test and y_test data sets
x_test = []
y_test = df.loc[:,'cnt'].iloc[training_data_len:len(df)]

for i in tqdm(range(len(test) - time_steps)):
    x_test.append(test.drop(columns='cnt').iloc[i:i + time_steps].to_numpy())
    # y_test.append(test.loc[:,'cnt'].iloc[i + time_steps])

#Convert x_test and y_test to numpy arrays
x_test = np.array(x_test)
y_test = np.array(y_test)
print('Train size:')
print(x_train.shape, y_train.shape)
print('Test size:')
print(x_test.shape, y_test.shape)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   """
#   0%|          | 0/1741 [00:00<?, ?it/s]
# Train size:
# (15649, 24, 12) (15649,)
# Test size:
# (1741, 24, 12) (1741,)

# %%
from keras import regularizers

init = glorot_normal(seed=None) # 給 LSTM
init_d = RandomUniform(minval=-0.05, maxval=0.05) # 給 Dense layer
nadam = optimizers.Nadam(lr=0.0015,clipvalue=0.5)

model = Sequential()
model.add(Bidirectional(GRU(64, kernel_initializer=init ,return_sequences = True,kernel_regularizer=regularizers.l2(0.01)
                             ,recurrent_regularizer = regularizers.l2(0.01) ,input_shape=(x_train.shape[1],x_train.shape[2]))))
model.add(LayerNormalization())
model.add(Bidirectional(GRU(64,kernel_initializer=init,kernel_regularizer=regularizers.l2(0.01),recurrent_regularizer = regularizers.l2(0.01))))
model.add(Dropout(0.1))
model.add(Dense(units=1, kernel_initializer=init_d))
model.compile(optimizer = nadam , loss="mse")
history = model.fit(x_train, y_train, epochs=200, batch_size=24, validation_split=0.1, shuffle=True)
#model summary
model.summary()
#Save Model
model.save('GRU_model_2.h5')  # creates a HDF5 file 
print('Model Saved')
del model  # deletes the existing model
# Out:
# Train on 14084 samples, validate on 1565 samples
# Epoch 1/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.7347 - val_loss: 0.4114
# Epoch 2/120
# 14084/14084 [==============================] - 45s 3ms/step - loss: 0.2779 - val_loss: 0.3466
# Epoch 3/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.2325 - val_loss: 0.2238
# Epoch 4/120
# 14084/14084 [==============================] - 45s 3ms/step - loss: 0.1942 - val_loss: 0.2196
# Epoch 5/120
# 14084/14084 [==============================] - 45s 3ms/step - loss: 0.1769 - val_loss: 0.1896
# Epoch 6/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.1614 - val_loss: 0.1615
# Epoch 7/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.1532 - val_loss: 0.1926
# Epoch 8/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.1483 - val_loss: 0.2419
# Epoch 9/120
# 14084/14084 [==============================] - 45s 3ms/step - loss: 0.1412 - val_loss: 0.1435
# Epoch 10/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.1345 - val_loss: 0.1301
# Epoch 11/120
# 14084/14084 [==============================] - 45s 3ms/step - loss: 0.1287 - val_loss: 0.1378
# Epoch 12/120
# 14084/14084 [==============================] - 45s 3ms/step - loss: 0.1238 - val_loss: 0.1363
# Epoch 13/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.1240 - val_loss: 0.1194
# Epoch 14/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.1202 - val_loss: 0.1428
# Epoch 15/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.1236 - val_loss: 0.1186
# Epoch 16/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.1178 - val_loss: 0.1367
# Epoch 17/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.1155 - val_loss: 0.1182
# Epoch 18/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.1162 - val_loss: 0.1120
# Epoch 19/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.1134 - val_loss: 0.1205
# Epoch 20/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.1113 - val_loss: 0.1084
# Epoch 21/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.1104 - val_loss: 0.1212
# Epoch 22/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.1121 - val_loss: 0.1429
# Epoch 23/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.1093 - val_loss: 0.1280
# Epoch 24/120
# 14084/14084 [==============================] - 45s 3ms/step - loss: 0.1087 - val_loss: 0.1304
# Epoch 25/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.1096 - val_loss: 0.1009
# Epoch 26/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.1081 - val_loss: 0.1053
# Epoch 27/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.1068 - val_loss: 0.1056
# Epoch 28/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.1062 - val_loss: 0.1074
# Epoch 29/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.1079 - val_loss: 0.0976
# Epoch 30/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.1033 - val_loss: 0.1014
# Epoch 31/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.1046 - val_loss: 0.1147
# Epoch 32/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.1023 - val_loss: 0.1118
# Epoch 33/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.1031 - val_loss: 0.1234
# Epoch 34/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.1025 - val_loss: 0.1121
# Epoch 35/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.1010 - val_loss: 0.0936
# Epoch 36/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.1026 - val_loss: 0.1076
# Epoch 37/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.1016 - val_loss: 0.1001
# Epoch 38/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.1017 - val_loss: 0.0986
# Epoch 39/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.1005 - val_loss: 0.1078
# Epoch 40/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.1005 - val_loss: 0.0963
# Epoch 41/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.0987 - val_loss: 0.0886
# Epoch 42/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.0994 - val_loss: 0.1298
# Epoch 43/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.1002 - val_loss: 0.1167
# Epoch 44/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.1002 - val_loss: 0.1052
# Epoch 45/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.0989 - val_loss: 0.1053
# Epoch 46/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.0974 - val_loss: 0.0920
# Epoch 47/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.0951 - val_loss: 0.1037
# Epoch 48/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.0965 - val_loss: 0.0969
# Epoch 49/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.0973 - val_loss: 0.1130
# Epoch 50/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.0987 - val_loss: 0.0823
# Epoch 51/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.0955 - val_loss: 0.1060
# Epoch 52/120
# 14084/14084 [==============================] - 42s 3ms/step - loss: 0.0955 - val_loss: 0.1113
# Epoch 53/120
# 14084/14084 [==============================] - 40s 3ms/step - loss: 0.0951 - val_loss: 0.0905
# Epoch 54/120
# 14084/14084 [==============================] - 41s 3ms/step - loss: 0.0943 - val_loss: 0.1377
# Epoch 55/120
# 14084/14084 [==============================] - 42s 3ms/step - loss: 0.0949 - val_loss: 0.0873
# Epoch 56/120
# 14084/14084 [==============================] - 41s 3ms/step - loss: 0.0953 - val_loss: 0.0974
# Epoch 57/120
# 14084/14084 [==============================] - 41s 3ms/step - loss: 0.0958 - val_loss: 0.0876
# Epoch 58/120
# 14084/14084 [==============================] - 41s 3ms/step - loss: 0.0956 - val_loss: 0.1156
# Epoch 59/120
# 14084/14084 [==============================] - 40s 3ms/step - loss: 0.0938 - val_loss: 0.1052
# Epoch 60/120
# 14084/14084 [==============================] - 41s 3ms/step - loss: 0.0960 - val_loss: 0.1055
# Epoch 61/120
# 14084/14084 [==============================] - 42s 3ms/step - loss: 0.0933 - val_loss: 0.0951
# Epoch 62/120
# 14084/14084 [==============================] - 44s 3ms/step - loss: 0.0945 - val_loss: 0.1051
# Epoch 63/120
# 14084/14084 [==============================] - 48s 3ms/step - loss: 0.0960 - val_loss: 0.1012
# Epoch 64/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.0965 - val_loss: 0.1274
# Epoch 65/120
# 14084/14084 [==============================] - 48s 3ms/step - loss: 0.0937 - val_loss: 0.1053
# Epoch 66/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.0923 - val_loss: 0.1166
# Epoch 67/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.0975 - val_loss: 0.1133
# Epoch 68/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.0921 - val_loss: 0.0867
# Epoch 69/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.0937 - val_loss: 0.0921
# Epoch 70/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.0963 - val_loss: 0.1687
# Epoch 71/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.0934 - val_loss: 0.0808
# Epoch 72/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.0934 - val_loss: 0.0924
# Epoch 73/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.0933 - val_loss: 0.1529
# Epoch 74/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.0975 - val_loss: 0.1333
# Epoch 75/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.0968 - val_loss: 0.1178
# Epoch 76/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.0968 - val_loss: 0.1073
# Epoch 77/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.0934 - val_loss: 0.1085
# Epoch 78/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.0952 - val_loss: 0.0966
# Epoch 79/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.0927 - val_loss: 0.0807
# Epoch 80/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.0936 - val_loss: 0.0929
# Epoch 81/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.0904 - val_loss: 0.1417
# Epoch 82/120
# 14084/14084 [==============================] - 48s 3ms/step - loss: 0.0925 - val_loss: 0.0797
# Epoch 83/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.0927 - val_loss: 0.0857
# Epoch 84/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.0943 - val_loss: 0.1135
# Epoch 85/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.0923 - val_loss: 0.0920
# Epoch 86/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.0910 - val_loss: 0.1081
# Epoch 87/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.0911 - val_loss: 0.0969
# Epoch 88/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.0918 - val_loss: 0.0855
# Epoch 89/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.0918 - val_loss: 0.0869
# Epoch 90/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.0922 - val_loss: 0.0917
# Epoch 91/120
# 14084/14084 [==============================] - 51s 4ms/step - loss: 0.0916 - val_loss: 0.1000
# Epoch 92/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.0953 - val_loss: 0.1031
# Epoch 93/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.0913 - val_loss: 0.0966
# Epoch 94/120
# 14084/14084 [==============================] - 48s 3ms/step - loss: 0.0945 - val_loss: 0.0918
# Epoch 95/120
# 14084/14084 [==============================] - 48s 3ms/step - loss: 0.0943 - val_loss: 0.1021
# Epoch 96/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.0940 - val_loss: 0.0870
# Epoch 97/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.0900 - val_loss: 0.1232
# Epoch 98/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.0933 - val_loss: 0.0925
# Epoch 99/120
# 14084/14084 [==============================] - 48s 3ms/step - loss: 0.0904 - val_loss: 0.0904
# Epoch 100/120
# 14084/14084 [==============================] - 48s 3ms/step - loss: 0.0896 - val_loss: 0.0781
# Epoch 101/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.0916 - val_loss: 0.1163
# Epoch 102/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.0885 - val_loss: 0.0953
# Epoch 103/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.0903 - val_loss: 0.0974
# Epoch 104/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.0897 - val_loss: 0.0906
# Epoch 105/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.0920 - val_loss: 0.1167
# Epoch 106/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.0938 - val_loss: 0.0881
# Epoch 107/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.0925 - val_loss: 0.0926
# Epoch 108/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.0912 - val_loss: 0.1178
# Epoch 109/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.0912 - val_loss: 0.0942
# Epoch 110/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.0903 - val_loss: 0.0925
# Epoch 111/120
# 14084/14084 [==============================] - 48s 3ms/step - loss: 0.0905 - val_loss: 0.1209
# Epoch 112/120
# 14084/14084 [==============================] - 47s 3ms/step - loss: 0.0901 - val_loss: 0.0857
# Epoch 113/120
# 14084/14084 [==============================] - 46s 3ms/step - loss: 0.0906 - val_loss: 0.1311
# Epoch 114/120
# 14084/14084 [==============================] - 42s 3ms/step - loss: 0.0902 - val_loss: 0.0837
# Epoch 115/120
# 14084/14084 [==============================] - 41s 3ms/step - loss: 0.0903 - val_loss: 0.1123
# Epoch 116/120
# 14084/14084 [==============================] - 42s 3ms/step - loss: 0.0920 - val_loss: 0.0949
# Epoch 117/120
# 14084/14084 [==============================] - 42s 3ms/step - loss: 0.0898 - val_loss: 0.1065
# Epoch 118/120
# 14084/14084 [==============================] - 41s 3ms/step - loss: 0.0881 - val_loss: 0.0958
# Epoch 119/120
# 14084/14084 [==============================] - 40s 3ms/step - loss: 0.0917 - val_loss: 0.1094
# Epoch 120/120
# 14084/14084 [==============================] - 41s 3ms/step - loss: 0.0919 - val_loss: 0.0857
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_12 (Bidirectio (None, 24, 128)           29568
# _________________________________________________________________
# layer_normalization_7 (Layer (None, 24, 128)           256
# _________________________________________________________________
# bidirectional_13 (Bidirectio (None, 128)               74112
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 104,065
# Trainable params: 104,065
# Non-trainable params: 0
# _________________________________________________________________
# Model Saved

# %%
import time
# layernormalization 屬於自訂義層,直接load model 會報錯
custom_ob = {'LayerNormalization': LayerNormalization}
model = load_model('GRU_model_2.h5', custom_objects=custom_ob)
t1 = time.time()
y_pred = model.predict(x_test)
t2 = time.time()
print('Predict time: ',t2-t1)
y_pred = scaler.inverse_transform(y_pred)#Undo scaling
#y_pred
# Out:
# Predict time:  0.971829891204834

# %%
from sklearn.metrics import mean_squared_error, r2_score
rmse_lstm = np.sqrt(mean_squared_error(y_test, y_pred))
print('RMSE: ',rmse_lstm)

r2 =  r2_score(y_test, y_pred)
print('R-square: ',r2)

n = len(y_test)
p = 12
Adj_r2 = 1-(1-r2)*(n-1)/(n-p-1)
print('Adj R-square: ',r2)
# Out:
# RMSE:  388.26975471228945
# R-square:  0.8253923004019403
# Adj R-square:  0.8253923004019403

# %%
plt.figure(figsize=(16, 8))
plt.plot(y_test, label='true')
plt.plot(y_pred, label='predicted')
plt.legend()

# %%
plt.plot(history.history["loss"],label="loss")
plt.plot(history.history["val_loss"],label="val_loss")
plt.legend(loc="best")
plt.xlabel("No. Of Epochs")
plt.ylabel("mse score")
# Out:
# Text(0, 0.5, 'mse score')

# %%
plt.figure(figsize=(16, 8))
plt.plot(y_test[1200:1500], label='true')
plt.plot(y_pred[1200:1500], label='predicted')
plt.legend()
