# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tcn import TCN # main library
import math
from sklearn.preprocessing import RobustScaler
#from keras.initializers import  glorot_normal, RandomUniform
#from keras import optimizers,regularizers

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import load_model 
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
df = pd.read_csv("station_bike _Duke.csv")
df["timestamp"] = pd.to_datetime(df["timestamp"])
df = df.set_index("timestamp")
#df.head()

df["hour"] = df.index.hour
df["day_of_month"] = df.index.day
df["day_of_week"]  = df.index.dayofweek
df["month"] = df.index.month

training_data_len = math.ceil(len(df) * 0.9) # taking 90% of data to train and 10% of data to test
testing_data_len = len(df) - training_data_len

time_steps = 24
train, test = df.iloc[0:training_data_len], df.iloc[(training_data_len-time_steps):len(df)]
print(df.shape, train.shape, test.shape)

train_trans = train[['t1','t2', 'hum', 'wind_speed']].to_numpy()
test_trans = test[['t1','t2', 'hum', 'wind_speed']].to_numpy()

scaler = RobustScaler() # Handles outliers
train.loc[:, ['t1','t2','hum', 'wind_speed']]=scaler.fit_transform(train_trans)
test.loc[:, ['t1','t2', 'hum', 'wind_speed']]=scaler.fit_transform(test_trans)

train['cnt'] = scaler.fit_transform(train[['cnt']])
test['cnt'] = scaler.fit_transform(test[['cnt']])

from tqdm import tqdm_notebook as tqdm

#Split the data into x_train and y_train data sets
x_train = []
y_train = []

for i in tqdm(range(len(train) - time_steps)):
    x_train.append(train.drop(columns='cnt').iloc[i:i + time_steps].to_numpy())
    y_train.append(train.loc[:,'cnt'].iloc[i + time_steps])

#Convert x_train and y_train to numpy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

#Create the x_test and y_test data sets
x_test = []
y_test = df.loc[:,'cnt'].iloc[training_data_len:len(df)]

for i in tqdm(range(len(test) - time_steps)):
    x_test.append(test.drop(columns='cnt').iloc[i:i + time_steps].to_numpy())
    # y_test.append(test.loc[:,'cnt'].iloc[i + time_steps])

#Convert x_test and y_test to numpy arrays
x_test = np.array(x_test)
y_test = np.array(y_test)

# All 12 columns of the data
print('Train size:')
print(x_train.shape, y_train.shape)
print('Test size:')
print(x_test.shape, y_test.shape)
# Out:
# (160, 13) (144, 13) (40, 13)
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:34: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/120 [00:00<?, ?it/s]
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:46: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/16 [00:00<?, ?it/s]
# Train size:
# (120, 24, 12) (120,)
# Test size:
# (16, 24, 12) (16,)

# %%
#init = glorot_normal(seed=None) # 給 LSTM
#init_d = RandomUniform(minval=-0.05, maxval=0.05) # 給 Dense layer
#nadam = optimizers.Nadam(lr=0.002,clipvalue=0.5)
from tensorflow.keras.initializers import RandomUniform
init_d = RandomUniform(minval=-0.05, maxval=0.05) # 給 Dense layer
model = Sequential()
model.add(TCN(input_shape=(x_train.shape[1],x_train.shape[2]),
        kernel_size=3,
        nb_filters=20,
        nb_stacks=1,
        dilations=(1, 2, 4, 8),
        kernel_initializer='glorot_uniform',
        use_skip_connections=True,
        use_batch_norm=False,
        use_weight_norm=False,
        use_layer_norm=True,
        dropout_rate = 0.05,
        return_sequences=True
        ))
model.add(Dropout(0.3))
model.add(TCN(
        kernel_size=3,
        nb_filters=20,
        nb_stacks=1,
        dilations=(1, 2, 4, 8),
        kernel_initializer='glorot_uniform',
        use_skip_connections=True,
        use_batch_norm=False,
        use_weight_norm=False,
        use_layer_norm=True,
        dropout_rate = 0.05,
        return_sequences=False
        ))  
model.add(Dropout(0.3))
model.add(Dense(1,kernel_initializer=init_d))  
model.summary()

print('Train...')
model.compile(optimizer = "nadam" , loss="mse")
history = model.fit(x_train, y_train, epochs=120, batch_size=12, validation_split=0.1, shuffle=True)
#Save Model
model.save('TCN_model_duke.h5')  # creates a HDF5 file 
del model

custom_ob = {'TCN': TCN}
# model = load_model('TCN_model_1.h5', custom_objects=custom_ob)
model = load_model('TCN_model_duke.h5', custom_objects=custom_ob)
print('Load Success')

import time
t1 = time.time()
y_pred = model.predict(x_test)
t2 = time.time()
print('Predict time: ',t2-t1)
y_pred = scaler.inverse_transform(y_pred)#Undo scaling

from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error
rmse_lstm = np.sqrt(mean_squared_error(y_test, y_pred))
print('RMSE: ',rmse_lstm)

mae = mean_absolute_error(y_test, y_pred)
print('MAE: ',mae)

r2 =  r2_score(y_test, y_pred)
print('R-square: ',r2)


n = len(y_test)
p = 12
Adj_r2 = 1-(1-r2)*(n-1)/(n-p-1)
print('Adj R-square: ',Adj_r2)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# tcn_2 (TCN)                  (None, 24, 20)            9860
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 24, 20)            0
# _________________________________________________________________
# tcn_3 (TCN)                  (None, 20)                10080
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 19,961
# Trainable params: 19,961
# Non-trainable params: 0
# _________________________________________________________________
# Train...
# Train on 108 samples, validate on 12 samples
# Epoch 1/120
# 108/108 [==============================] - 6s 60ms/sample - loss: 1.1567 - val_loss: 0.7316
# Epoch 2/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 1.1107 - val_loss: 0.6818
# Epoch 3/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 1.1541 - val_loss: 0.6792
# Epoch 4/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 1.1200 - val_loss: 0.6769
# Epoch 5/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 1.0580 - val_loss: 0.6525
# Epoch 6/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 1.0589 - val_loss: 0.6342
# Epoch 7/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 1.0416 - val_loss: 0.5998
# Epoch 8/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 1.0008 - val_loss: 0.5483
# Epoch 9/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.9509 - val_loss: 0.4755
# Epoch 10/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.9222 - val_loss: 0.4354
# Epoch 11/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.9801 - val_loss: 0.3844
# Epoch 12/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.9410 - val_loss: 0.3644
# Epoch 13/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.8157 - val_loss: 0.3437
# Epoch 14/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.7790 - val_loss: 0.3379
# Epoch 15/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.8168 - val_loss: 0.3128
# Epoch 16/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.6695 - val_loss: 0.3044
# Epoch 17/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.6831 - val_loss: 0.2687
# Epoch 18/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.6855 - val_loss: 0.2239
# Epoch 19/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.7270 - val_loss: 0.2336
# Epoch 20/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.6418 - val_loss: 0.2018
# Epoch 21/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.6411 - val_loss: 0.2108
# Epoch 22/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.5777 - val_loss: 0.2310
# Epoch 23/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.5395 - val_loss: 0.2471
# Epoch 24/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.5164 - val_loss: 0.2226
# Epoch 25/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.6253 - val_loss: 0.2352
# Epoch 26/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.5387 - val_loss: 0.2700
# Epoch 27/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4320 - val_loss: 0.2759
# Epoch 28/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4748 - val_loss: 0.3186
# Epoch 29/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4780 - val_loss: 0.2657
# Epoch 30/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4706 - val_loss: 0.2513
# Epoch 31/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4534 - val_loss: 0.2712
# Epoch 32/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3507 - val_loss: 0.2438
# Epoch 33/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3965 - val_loss: 0.1802
# Epoch 34/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3880 - val_loss: 0.2032
# Epoch 35/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3779 - val_loss: 0.2416
# Epoch 36/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3767 - val_loss: 0.2232
# Epoch 37/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.4442 - val_loss: 0.2735
# Epoch 38/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3033 - val_loss: 0.2695
# Epoch 39/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3896 - val_loss: 0.1861
# Epoch 40/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3314 - val_loss: 0.2511
# Epoch 41/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.4026 - val_loss: 0.2754
# Epoch 42/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3601 - val_loss: 0.3018
# Epoch 43/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2628 - val_loss: 0.3312
# Epoch 44/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.4513 - val_loss: 0.2065
# Epoch 45/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.5367 - val_loss: 0.2392
# Epoch 46/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3401 - val_loss: 0.2141
# Epoch 47/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2808 - val_loss: 0.2150
# Epoch 48/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3131 - val_loss: 0.2165
# Epoch 49/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2517 - val_loss: 0.2510
# Epoch 50/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2678 - val_loss: 0.2278
# Epoch 51/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2597 - val_loss: 0.2322
# Epoch 52/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3409 - val_loss: 0.2353
# Epoch 53/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3791 - val_loss: 0.2330
# Epoch 54/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2514 - val_loss: 0.2638
# Epoch 55/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3750 - val_loss: 0.2469
# Epoch 56/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2374 - val_loss: 0.3066
# Epoch 57/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2533 - val_loss: 0.2929
# Epoch 58/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2570 - val_loss: 0.2729
# Epoch 59/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2299 - val_loss: 0.3045
# Epoch 60/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2481 - val_loss: 0.2801
# Epoch 61/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2400 - val_loss: 0.2904
# Epoch 62/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3472 - val_loss: 0.2403
# Epoch 63/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2623 - val_loss: 0.2254
# Epoch 64/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2545 - val_loss: 0.2374
# Epoch 65/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2550 - val_loss: 0.2642
# Epoch 66/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2724 - val_loss: 0.2895
# Epoch 67/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2469 - val_loss: 0.2634
# Epoch 68/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3353 - val_loss: 0.2461
# Epoch 69/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3274 - val_loss: 0.2583
# Epoch 70/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2280 - val_loss: 0.2594
# Epoch 71/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3018 - val_loss: 0.2399
# Epoch 72/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2665 - val_loss: 0.2390
# Epoch 73/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1728 - val_loss: 0.2685
# Epoch 74/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1571 - val_loss: 0.2642
# Epoch 75/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2622 - val_loss: 0.2659
# Epoch 76/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2659 - val_loss: 0.2371
# Epoch 77/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1735 - val_loss: 0.2466
# Epoch 78/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1977 - val_loss: 0.2621
# Epoch 79/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2191 - val_loss: 0.2458
# Epoch 80/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2785 - val_loss: 0.2147
# Epoch 81/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2055 - val_loss: 0.2285
# Epoch 82/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2779 - val_loss: 0.2464
# Epoch 83/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2370 - val_loss: 0.2476
# Epoch 84/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1660 - val_loss: 0.2598
# Epoch 85/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2013 - val_loss: 0.2465
# Epoch 86/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2836 - val_loss: 0.2652
# Epoch 87/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1776 - val_loss: 0.2970
# Epoch 88/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1349 - val_loss: 0.2953
# Epoch 89/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1285 - val_loss: 0.2732
# Epoch 90/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1992 - val_loss: 0.2647
# Epoch 91/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2270 - val_loss: 0.2681
# Epoch 92/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2541 - val_loss: 0.2285
# Epoch 93/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1470 - val_loss: 0.2489
# Epoch 94/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2508 - val_loss: 0.2458
# Epoch 95/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1428 - val_loss: 0.2210
# Epoch 96/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2468 - val_loss: 0.2104
# Epoch 97/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1319 - val_loss: 0.2292
# Epoch 98/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1662 - val_loss: 0.2163
# Epoch 99/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1909 - val_loss: 0.2312
# Epoch 100/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1933 - val_loss: 0.2430
# Epoch 101/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1919 - val_loss: 0.2448
# Epoch 102/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2045 - val_loss: 0.2622
# Epoch 103/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1662 - val_loss: 0.2136
# Epoch 104/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1985 - val_loss: 0.2115
# Epoch 105/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1393 - val_loss: 0.2099
# Epoch 106/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1819 - val_loss: 0.2361
# Epoch 107/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1566 - val_loss: 0.2482
# Epoch 108/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2025 - val_loss: 0.2394
# Epoch 109/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1650 - val_loss: 0.2248
# Epoch 110/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2277 - val_loss: 0.2063
# Epoch 111/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1947 - val_loss: 0.2120
# Epoch 112/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1444 - val_loss: 0.2415
# Epoch 113/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2222 - val_loss: 0.2331
# Epoch 114/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1219 - val_loss: 0.2515
# Epoch 115/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1901 - val_loss: 0.2182
# Epoch 116/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2526 - val_loss: 0.2390
# Epoch 117/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1789 - val_loss: 0.2545
# Epoch 118/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1541 - val_loss: 0.2331
# Epoch 119/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1588 - val_loss: 0.2604
# Epoch 120/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1570 - val_loss: 0.2487
# Load Success
# Predict time:  0.8383841514587402
# RMSE:  14.324626726594964
# MAE:  10.434061020612717
# R-square:  -1.003810883051969
# Adj R-square:  -9.019054415259845
