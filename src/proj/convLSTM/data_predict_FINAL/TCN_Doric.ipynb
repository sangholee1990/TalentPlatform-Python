# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tcn import TCN # main library
import math
from sklearn.preprocessing import RobustScaler
#from keras.initializers import  glorot_normal, RandomUniform
#from keras import optimizers,regularizers

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import load_model 
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
df = pd.read_csv("station_bike_Doric.csv")
df["timestamp"] = pd.to_datetime(df["timestamp"])
df = df.set_index("timestamp")
#df.head()

df["hour"] = df.index.hour
df["day_of_month"] = df.index.day
df["day_of_week"]  = df.index.dayofweek
df["month"] = df.index.month

training_data_len = math.ceil(len(df) * 0.9) # taking 90% of data to train and 10% of data to test
testing_data_len = len(df) - training_data_len

time_steps = 24
train, test = df.iloc[0:training_data_len], df.iloc[(training_data_len-time_steps):len(df)]
print(df.shape, train.shape, test.shape)

train_trans = train[['t1','t2', 'hum', 'wind_speed']].to_numpy()
test_trans = test[['t1','t2', 'hum', 'wind_speed']].to_numpy()

scaler = RobustScaler() # Handles outliers
train.loc[:, ['t1','t2','hum', 'wind_speed']]=scaler.fit_transform(train_trans)
test.loc[:, ['t1','t2', 'hum', 'wind_speed']]=scaler.fit_transform(test_trans)

train['cnt'] = scaler.fit_transform(train[['cnt']])
test['cnt'] = scaler.fit_transform(test[['cnt']])

from tqdm import tqdm_notebook as tqdm

#Split the data into x_train and y_train data sets
x_train = []
y_train = []

for i in tqdm(range(len(train) - time_steps)):
    x_train.append(train.drop(columns='cnt').iloc[i:i + time_steps].to_numpy())
    y_train.append(train.loc[:,'cnt'].iloc[i + time_steps])

#Convert x_train and y_train to numpy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

#Create the x_test and y_test data sets
x_test = []
y_test = df.loc[:,'cnt'].iloc[training_data_len:len(df)]

for i in tqdm(range(len(test) - time_steps)):
    x_test.append(test.drop(columns='cnt').iloc[i:i + time_steps].to_numpy())
    # y_test.append(test.loc[:,'cnt'].iloc[i + time_steps])

#Convert x_test and y_test to numpy arrays
x_test = np.array(x_test)
y_test = np.array(y_test)

# All 12 columns of the data
print('Train size:')
print(x_train.shape, y_train.shape)
print('Test size:')
print(x_test.shape, y_test.shape)
# Out:
# (160, 13) (144, 13) (40, 13)
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:34: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/120 [00:00<?, ?it/s]
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:46: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/16 [00:00<?, ?it/s]
# Train size:
# (120, 24, 12) (120,)
# Test size:
# (16, 24, 12) (16,)

# %%
#init = glorot_normal(seed=None) # 給 LSTM
#init_d = RandomUniform(minval=-0.05, maxval=0.05) # 給 Dense layer
#nadam = optimizers.Nadam(lr=0.002,clipvalue=0.5)
from tensorflow.keras.initializers import RandomUniform
init_d = RandomUniform(minval=-0.05, maxval=0.05) # 給 Dense layer
model = Sequential()
model.add(TCN(input_shape=(x_train.shape[1],x_train.shape[2]),
        kernel_size=3,
        nb_filters=20,
        nb_stacks=1,
        dilations=(1, 2, 4, 8),
        kernel_initializer='glorot_uniform',
        use_skip_connections=True,
        use_batch_norm=False,
        use_weight_norm=False,
        use_layer_norm=True,
        dropout_rate = 0.05,
        return_sequences=True
        ))
model.add(Dropout(0.3))
model.add(TCN(
        kernel_size=3,
        nb_filters=20,
        nb_stacks=1,
        dilations=(1, 2, 4, 8),
        kernel_initializer='glorot_uniform',
        use_skip_connections=True,
        use_batch_norm=False,
        use_weight_norm=False,
        use_layer_norm=True,
        dropout_rate = 0.05,
        return_sequences=False
        ))  
model.add(Dropout(0.3))
model.add(Dense(1,kernel_initializer=init_d))  
model.summary()

print('Train...')
model.compile(optimizer = "nadam" , loss="mse")
history = model.fit(x_train, y_train, epochs=120, batch_size=12, validation_split=0.1, shuffle=True)
#Save Model
model.save('TCN_model_doric.h5')  # creates a HDF5 file 
del model

custom_ob = {'TCN': TCN}
# model = load_model('TCN_model_1.h5', custom_objects=custom_ob)
model = load_model('TCN_model_doric.h5', custom_objects=custom_ob)
print('Load Success')

import time
t1 = time.time()
y_pred = model.predict(x_test)
t2 = time.time()
print('Predict time: ',t2-t1)
y_pred = scaler.inverse_transform(y_pred)#Undo scaling

from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error
rmse_lstm = np.sqrt(mean_squared_error(y_test, y_pred))
print('RMSE: ',rmse_lstm)

mae = mean_absolute_error(y_test, y_pred)
print('MAE: ',mae)

r2 =  r2_score(y_test, y_pred)
print('R-square: ',r2)


n = len(y_test)
p = 12
Adj_r2 = 1-(1-r2)*(n-1)/(n-p-1)
print('Adj R-square: ',Adj_r2)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# tcn_4 (TCN)                  (None, 24, 20)            9860
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 24, 20)            0
# _________________________________________________________________
# tcn_5 (TCN)                  (None, 20)                10080
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 19,961
# Trainable params: 19,961
# Non-trainable params: 0
# _________________________________________________________________
# Train...
# Train on 108 samples, validate on 12 samples
# Epoch 1/120
# 108/108 [==============================] - 7s 65ms/sample - loss: 2.0061 - val_loss: 0.9316
# Epoch 2/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 1.7634 - val_loss: 0.8827
# Epoch 3/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 1.7689 - val_loss: 0.8646
# Epoch 4/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 1.7308 - val_loss: 0.8640
# Epoch 5/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 1.5970 - val_loss: 0.8664
# Epoch 6/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 1.6331 - val_loss: 0.7863
# Epoch 7/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 1.5595 - val_loss: 0.7498
# Epoch 8/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 1.4783 - val_loss: 0.5606
# Epoch 9/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 1.2685 - val_loss: 0.6019
# Epoch 10/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 1.4650 - val_loss: 0.5938
# Epoch 11/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 1.1892 - val_loss: 0.4889
# Epoch 12/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 1.0341 - val_loss: 0.5683
# Epoch 13/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.8800 - val_loss: 0.4404
# Epoch 14/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.7087 - val_loss: 0.4824
# Epoch 15/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.9402 - val_loss: 0.6550
# Epoch 16/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.7040 - val_loss: 0.2925
# Epoch 17/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.7332 - val_loss: 0.4853
# Epoch 18/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4870 - val_loss: 0.3149
# Epoch 19/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.6215 - val_loss: 0.3726
# Epoch 20/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.6179 - val_loss: 0.3569
# Epoch 21/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.7706 - val_loss: 0.2338
# Epoch 22/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.5225 - val_loss: 0.3615
# Epoch 23/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.5840 - val_loss: 0.2549
# Epoch 24/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4504 - val_loss: 0.3900
# Epoch 25/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4531 - val_loss: 0.2883
# Epoch 26/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4793 - val_loss: 0.2993
# Epoch 27/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.5064 - val_loss: 0.3935
# Epoch 28/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.6076 - val_loss: 0.3478
# Epoch 29/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.5838 - val_loss: 0.2961
# Epoch 30/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4327 - val_loss: 0.3025
# Epoch 31/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4404 - val_loss: 0.2789
# Epoch 32/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.5886 - val_loss: 0.2384
# Epoch 33/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3532 - val_loss: 0.2641
# Epoch 34/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.5275 - val_loss: 0.2379
# Epoch 35/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4783 - val_loss: 0.2660
# Epoch 36/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3403 - val_loss: 0.3180
# Epoch 37/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4582 - val_loss: 0.3345
# Epoch 38/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4318 - val_loss: 0.3383
# Epoch 39/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3305 - val_loss: 0.4319
# Epoch 40/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3383 - val_loss: 0.3336
# Epoch 41/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4265 - val_loss: 0.3459
# Epoch 42/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4727 - val_loss: 0.2636
# Epoch 43/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2837 - val_loss: 0.2722
# Epoch 44/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4058 - val_loss: 0.3437
# Epoch 45/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4730 - val_loss: 0.2993
# Epoch 46/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3709 - val_loss: 0.3228
# Epoch 47/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4374 - val_loss: 0.2380
# Epoch 48/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4132 - val_loss: 0.2704
# Epoch 49/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3822 - val_loss: 0.2726
# Epoch 50/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2731 - val_loss: 0.3003
# Epoch 51/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3761 - val_loss: 0.3004
# Epoch 52/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3515 - val_loss: 0.2426
# Epoch 53/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2437 - val_loss: 0.3384
# Epoch 54/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3343 - val_loss: 0.2943
# Epoch 55/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3310 - val_loss: 0.3007
# Epoch 56/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3033 - val_loss: 0.3509
# Epoch 57/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4042 - val_loss: 0.3451
# Epoch 58/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3147 - val_loss: 0.3032
# Epoch 59/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4163 - val_loss: 0.3452
# Epoch 60/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3178 - val_loss: 0.3081
# Epoch 61/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3876 - val_loss: 0.2982
# Epoch 62/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3063 - val_loss: 0.3760
# Epoch 63/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3665 - val_loss: 0.4108
# Epoch 64/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4061 - val_loss: 0.3787
# Epoch 65/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2328 - val_loss: 0.2783
# Epoch 66/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3746 - val_loss: 0.3384
# Epoch 67/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3695 - val_loss: 0.2919
# Epoch 68/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2999 - val_loss: 0.4203
# Epoch 69/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2936 - val_loss: 0.3955
# Epoch 70/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2590 - val_loss: 0.3385
# Epoch 71/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3279 - val_loss: 0.3455
# Epoch 72/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3093 - val_loss: 0.3392
# Epoch 73/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3200 - val_loss: 0.3483
# Epoch 74/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3077 - val_loss: 0.3083
# Epoch 75/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2650 - val_loss: 0.3830
# Epoch 76/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2856 - val_loss: 0.3625
# Epoch 77/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3145 - val_loss: 0.2656
# Epoch 78/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2920 - val_loss: 0.2553
# Epoch 79/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3424 - val_loss: 0.2790
# Epoch 80/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3446 - val_loss: 0.2684
# Epoch 81/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3527 - val_loss: 0.3044
# Epoch 82/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2607 - val_loss: 0.3075
# Epoch 83/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3173 - val_loss: 0.3196
# Epoch 84/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2607 - val_loss: 0.2899
# Epoch 85/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.4311 - val_loss: 0.3329
# Epoch 86/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3560 - val_loss: 0.2543
# Epoch 87/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2429 - val_loss: 0.3447
# Epoch 88/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3041 - val_loss: 0.3461
# Epoch 89/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3612 - val_loss: 0.3163
# Epoch 90/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2539 - val_loss: 0.2762
# Epoch 91/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.4441 - val_loss: 0.2411
# Epoch 92/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3828 - val_loss: 0.2407
# Epoch 93/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2486 - val_loss: 0.2543
# Epoch 94/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2893 - val_loss: 0.3282
# Epoch 95/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2993 - val_loss: 0.2973
# Epoch 96/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3517 - val_loss: 0.2566
# Epoch 97/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2871 - val_loss: 0.2359
# Epoch 98/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2755 - val_loss: 0.2866
# Epoch 99/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3197 - val_loss: 0.2780
# Epoch 100/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2841 - val_loss: 0.2665
# Epoch 101/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.4821 - val_loss: 0.3836
# Epoch 102/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3237 - val_loss: 0.2722
# Epoch 103/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3057 - val_loss: 0.2809
# Epoch 104/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3652 - val_loss: 0.2620
# Epoch 105/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1955 - val_loss: 0.2808
# Epoch 106/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2354 - val_loss: 0.2621
# Epoch 107/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3447 - val_loss: 0.2735
# Epoch 108/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2991 - val_loss: 0.2714
# Epoch 109/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3092 - val_loss: 0.2313
# Epoch 110/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2875 - val_loss: 0.2895
# Epoch 111/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2751 - val_loss: 0.2816
# Epoch 112/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3350 - val_loss: 0.3668
# Epoch 113/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3601 - val_loss: 0.3737
# Epoch 114/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3987 - val_loss: 0.3867
# Epoch 115/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3431 - val_loss: 0.3539
# Epoch 116/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3030 - val_loss: 0.3660
# Epoch 117/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3151 - val_loss: 0.3532
# Epoch 118/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3188 - val_loss: 0.3134
# Epoch 119/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2473 - val_loss: 0.2858
# Epoch 120/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2197 - val_loss: 0.2829
# Load Success
# Predict time:  0.5878925323486328
# RMSE:  6.173083126555527
# MAE:  4.810214497148991
# R-square:  -4.000195055645991
# Adj R-square:  -24.000975278229955
