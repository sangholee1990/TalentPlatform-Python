# %% [markdown]
# # 匯入基本套件

# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#匯入 data

# %%
df = pd.read_csv("london_merged.csv")
df["timestamp"] = pd.to_datetime(df["timestamp"])
df = df.set_index("timestamp")
#df.head()

df["hour"] = df.index.hour
df["day_of_month"] = df.index.day
df["day_of_week"]  = df.index.dayofweek
df["month"] = df.index.month
df.head()
# Out:
#                      cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#                      is_holiday  is_weekend  season  hour  day_of_month  \
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0     0             4
# 2015-01-04 01:00:00         0.0         1.0     3.0     1             4
# 2015-01-04 02:00:00         0.0         1.0     3.0     2             4
# 2015-01-04 03:00:00         0.0         1.0     3.0     3             4
# 2015-01-04 04:00:00         0.0         1.0     3.0     4             4
#
#                      day_of_week  month
# timestamp
# 2015-01-04 00:00:00            6      1
# 2015-01-04 01:00:00            6      1
# 2015-01-04 02:00:00            6      1
# 2015-01-04 03:00:00            6      1
# 2015-01-04 04:00:00            6      1

# %%
# Data Processing

# %%
import math
from sklearn.preprocessing import RobustScaler

# %%
training_data_len = math.ceil(len(df) * 0.9) # taking 90% of data to train and 10% of data to test
testing_data_len = len(df) - training_data_len

time_steps = 24
train, test = df.iloc[0:training_data_len], df.iloc[(training_data_len-time_steps):len(df)]
print(df.shape, train.shape, test.shape)
# Out:
# (17414, 13) (15673, 13) (1765, 13)

# %%
# Scale  all of the data from columns ['t1','t2' ,'season', 'hum', 'wind_speed','weather_code']

# %%
train_trans = train[['t1','t2', 'hum', 'wind_speed']].to_numpy()
test_trans = test[['t1','t2', 'hum', 'wind_speed']].to_numpy()

scaler = RobustScaler() # Handles outliers
train.loc[:, ['t1','t2','hum', 'wind_speed']]=scaler.fit_transform(train_trans)
test.loc[:, ['t1','t2', 'hum', 'wind_speed']]=scaler.fit_transform(test_trans)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)

# %%
#Scale the all of the data from columns ['cnt']

# %%
train['cnt'] = scaler.fit_transform(train[['cnt']])
test['cnt'] = scaler.fit_transform(test[['cnt']])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Split Train and test data set

# %%
from tqdm import tqdm_notebook as tqdm

#Split the data into x_train and y_train data sets
x_train = []
y_train = []

for i in tqdm(range(len(train) - time_steps)):
    x_train.append(train.drop(columns='cnt').iloc[i:i + time_steps].to_numpy())
    y_train.append(train.loc[:,'cnt'].iloc[i + time_steps])

#Convert x_train and y_train to numpy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   import sys
#   0%|          | 0/15649 [00:00<?, ?it/s]

# %%
#Create the x_test and y_test data sets
x_test = []
y_test = df.loc[:,'cnt'].iloc[training_data_len:len(df)]

for i in tqdm(range(len(test) - time_steps)):
    x_test.append(test.drop(columns='cnt').iloc[i:i + time_steps].to_numpy())
    # y_test.append(test.loc[:,'cnt'].iloc[i + time_steps])

#Convert x_test and y_test to numpy arrays
x_test = np.array(x_test)
y_test = np.array(y_test)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   """
#   0%|          | 0/1741 [00:00<?, ?it/s]

# %%
# All 12 columns of the data
print('Train size:')
print(x_train.shape, y_train.shape)
print('Test size:')
print(x_test.shape, y_test.shape)
# Out:
# Train size:
# (15649, 24, 12) (15649,)
# Test size:
# (1741, 24, 12) (1741,)

# %%
# Import Keras

# %%
from keras.preprocessing import sequence
from keras.models import Sequential , load_model
from keras.layers import Dense, Dropout , LSTM , Bidirectional 
from keras_layer_normalization import LayerNormalization
from keras.initializers import  glorot_normal, RandomUniform
from keras import optimizers,regularizers
# Out:
# Using TensorFlow backend.

# %%
init = glorot_normal(seed=None) # 給 LSTM
init_d = RandomUniform(minval=-0.05, maxval=0.05) # 給 Dense layer
nadam = optimizers.Nadam(lr=0.002,clipvalue=0.5)

model = Sequential()
model.add(Bidirectional(LSTM(64, kernel_initializer=init,unit_forget_bias = True ,kernel_regularizer = regularizers.l2(0.01),return_sequences=True,
                             recurrent_regularizer = regularizers.l2(0.01),input_shape=(x_train.shape[1],x_train.shape[2])),merge_mode='concat'))
# model.add(Bidirectional(LSTM(50,input_shape=(x_train.shape[1],x_train.shape[2]),return_sequences=True,dropout=0.1, recurrent_dropout=0.1)))
model.add(LayerNormalization())
model.add(Bidirectional(LSTM(64, kernel_initializer=init,unit_forget_bias = True ,kernel_regularizer = regularizers.l2(0.01),
                             recurrent_regularizer = regularizers.l2(0.01))))
model.add(LayerNormalization())
# model.add(Bidirectional(LSTM(50)))
# model.add(LayerNormalization())
model.add(Dropout(0.3))
model.add(Dense(units=1, kernel_initializer=init_d))
model.compile(optimizer = nadam , loss="mse")
history = model.fit(x_train, y_train, epochs=130, batch_size=24, validation_split=0.1, shuffle=True)

#model summary
model.summary()
#Save Model
model.save('LSTM_model_5.h5')  # creates a HDF5 file 
print('Model Saved')
del model  # deletes the existing model
# Out:
# Train on 14084 samples, validate on 1565 samples
# Epoch 1/130
# 14084/14084 [==============================] - 36s 3ms/step - loss: 0.8381 - val_loss: 0.2856
# Epoch 2/130
# 14084/14084 [==============================] - 35s 2ms/step - loss: 0.2385 - val_loss: 0.2528
# Epoch 3/130
# 14084/14084 [==============================] - 34s 2ms/step - loss: 0.1963 - val_loss: 0.1807
# Epoch 4/130
# 14084/14084 [==============================] - 35s 2ms/step - loss: 0.1747 - val_loss: 0.1888
# Epoch 5/130
# 14084/14084 [==============================] - 35s 2ms/step - loss: 0.1602 - val_loss: 0.1719
# Epoch 6/130
# 14084/14084 [==============================] - 35s 3ms/step - loss: 0.1540 - val_loss: 0.1534
# 14084/14084 [==============================] - 35s 2ms/step - loss: 0.1025 - val_loss: 0.1116
# Epoch 65/130
# 14084/14084 [==============================] - 35s 3ms/step - loss: 0.1033 - val_loss: 0.1199
# Epoch 66/130
# 14084/14084 [==============================] - 35s 2ms/step - loss: 0.0966 - val_loss: 0.0933
# Epoch 67/130
# 14084/14084 [==============================] - 34s 2ms/step - loss: 0.1008 - val_loss: 0.1093
# Epoch 68/130
# 14084/14084 [==============================] - 34s 2ms/step - loss: 0.1018 - val_loss: 0.0990
# Epoch 69/130
# 14084/14084 [==============================] - 34s 2ms/step - loss: 0.1038 - val_loss: 0.1256
# Epoch 70/130
# 14084/14084 [==============================] - 35s 3ms/step - loss: 0.1014 - val_loss: 0.1493
# Epoch 71/130
# 14084/14084 [==============================] - 35s 3ms/step - loss: 0.1032 - val_loss: 0.1204
# Epoch 72/130
# 14084/14084 [==============================] - 35s 3ms/step - loss: 0.0996 - val_loss: 0.1061
# Epoch 73/130
# 14084/14084 [==============================] - 35s 2ms/step - loss: 0.0961 - val_loss: 0.1427
# Epoch 74/130
# 14084/14084 [==============================] - 36s 3ms/step - loss: 0.0928 - val_loss: 0.1141
# Epoch 75/130
# 14084/14084 [==============================] - 34s 2ms/step - loss: 0.0968 - val_loss: 0.1202
# Epoch 76/130
# 14084/14084 [==============================] - 34s 2ms/step - loss: 0.0953 - val_loss: 0.1284
# Epoch 77/130
# 14084/14084 [==============================] - 34s 2ms/step - loss: 0.0952 - val_loss: 0.1317
# Epoch 78/130
# 14084/14084 [==============================] - 34s 2ms/step - loss: 0.0945 - val_loss: 0.1108
# Epoch 79/130
# 14084/14084 [==============================] - 34s 2ms/step - loss: 0.0901 - val_loss: 0.0975
# Epoch 80/130
# 14084/14084 [==============================] - 36s 3ms/step - loss: 0.0899 - val_loss: 0.1172
# Epoch 81/130
# 14084/14084 [==============================] - 35s 2ms/step - loss: 0.0945 - val_loss: 0.1190
# Epoch 82/130
# 14084/14084 [==============================] - 35s 2ms/step - loss: 0.0930 - val_loss: 0.0888
# Epoch 83/130
# 14084/14084 [==============================] - 35s 2ms/step - loss: 0.0915 - val_loss: 0.1115
# Epoch 84/130
# 14084/14084 [==============================] - 35s 2ms/step - loss: 0.0907 - val_loss: 0.1034
# Epoch 85/130
# 14084/14084 [==============================] - 35s 2ms/step - loss: 0.0894 - val_loss: 0.1205
# Epoch 86/130
# 14084/14084 [==============================] - 35s 2ms/step - loss: 0.0903 - val_loss: 0.0938
# Epoch 87/130
# 14084/14084 [==============================] - 35s 2ms/step - loss: 0.0907 - val_loss: 0.0968
# Epoch 88/130
# 14084/14084 [==============================] - 35s 2ms/step - loss: 0.0922 - val_loss: 0.0795
# Epoch 89/130
# 14084/14084 [==============================] - 35s 2ms/step - loss: 0.0871 - val_loss: 0.0848
# Epoch 90/130
# 14084/14084 [==============================] - 34s 2ms/step - loss: 0.0876 - val_loss: 0.1492
# Epoch 91/130
# 14084/14084 [==============================] - 34s 2ms/step - loss: 0.0980 - val_loss: 0.1407
# Epoch 92/130
# 14084/14084 [==============================] - 35s 2ms/step - loss: 0.0932 - val_loss: 0.0830
# Epoch 93/130
# 14084/14084 [==============================] - 34s 2ms/step - loss: 0.0909 - val_loss: 0.2121
# Epoch 94/130
# 14084/14084 [==============================] - 35s 2ms/step - loss: 0.0941 - val_loss: 0.1001
# Epoch 95/130
# 14084/14084 [==============================] - 34s 2ms/step - loss: 0.0906 - val_loss: 0.0856
# Epoch 96/130
# 14084/14084 [==============================] - 35s 2ms/step - loss: 0.0880 - val_loss: 0.0896
# Epoch 97/130
# 14084/14084 [==============================] - 35s 2ms/step - loss: 0.0870 - val_loss: 0.1070
# Epoch 98/130
# 14084/14084 [==============================] - 35s 2ms/step - loss: 0.0888 - val_loss: 0.1155
# Epoch 99/130
# 14084/14084 [==============================] - 34s 2ms/step - loss: 0.0868 - val_loss: 0.0919
# Epoch 100/130
# 14084/14084 [==============================] - 35s 2ms/step - loss: 0.0933 - val_loss: 0.0940
# Epoch 101/130
# 14084/14084 [==============================] - 34s 2ms/step - loss: 0.0965 - val_loss: 0.1074
# Epoch 102/130
# 14084/14084 [==============================] - 35s 2ms/step - loss: 0.0928 - val_loss: 0.1014
# Epoch 103/130
# 14084/14084 [==============================] - 36s 3ms/step - loss: 0.0868 - val_loss: 0.1314
# Epoch 104/130
# 14084/14084 [==============================] - 35s 2ms/step - loss: 0.0847 - val_loss: 0.1020
# Epoch 105/130
# 14084/14084 [==============================] - 35s 3ms/step - loss: 0.0827 - val_loss: 0.1124
# Epoch 106/130
# 14084/14084 [==============================] - 35s 2ms/step - loss: 0.0883 - val_loss: 0.1141
# Epoch 107/130
# 14084/14084 [==============================] - 35s 3ms/step - loss: 0.0878 - val_loss: 0.1119
# Epoch 108/130
# 14084/14084 [==============================] - 35s 2ms/step - loss: 0.0864 - val_loss: 0.1441
# Epoch 109/130
# 14084/14084 [==============================] - 35s 2ms/step - loss: 0.0869 - val_loss: 0.1276
# Epoch 110/130
# 14084/14084 [==============================] - 35s 2ms/step - loss: 0.0886 - val_loss: 0.0984
# Epoch 111/130
# 14084/14084 [==============================] - 35s 2ms/step - loss: 0.0893 - val_loss: 0.0878
# Epoch 112/130
# 14084/14084 [==============================] - 35s 2ms/step - loss: 0.0864 - val_loss: 0.0920
# Epoch 113/130
# 14084/14084 [==============================] - 35s 2ms/step - loss: 0.0907 - val_loss: 0.1136
# Epoch 114/130
# 14084/14084 [==============================] - 35s 2ms/step - loss: 0.0842 - val_loss: 0.0778
# Epoch 115/130
# 14084/14084 [==============================] - 35s 3ms/step - loss: 0.0881 - val_loss: 0.0879
# Epoch 116/130
# 14084/14084 [==============================] - 35s 2ms/step - loss: 0.0834 - val_loss: 0.0829
# Epoch 117/130
# 14084/14084 [==============================] - 36s 3ms/step - loss: 0.0877 - val_loss: 0.1010
# Epoch 118/130
# 14084/14084 [==============================] - 35s 3ms/step - loss: 0.0883 - val_loss: 0.0804
# Epoch 119/130
# 14084/14084 [==============================] - 36s 3ms/step - loss: 0.0897 - val_loss: 0.0948
# Epoch 120/130
# 14084/14084 [==============================] - 36s 3ms/step - loss: 0.0901 - val_loss: 0.1113
# Epoch 121/130
# 14084/14084 [==============================] - 36s 3ms/step - loss: 0.0873 - val_loss: 0.1383
# Epoch 122/130
# 14084/14084 [==============================] - 35s 3ms/step - loss: 0.0887 - val_loss: 0.0971
# Epoch 123/130
# 14084/14084 [==============================] - 35s 3ms/step - loss: 0.0868 - val_loss: 0.1011
# Epoch 124/130
# 14084/14084 [==============================] - 35s 3ms/step - loss: 0.0861 - val_loss: 0.0954
# Epoch 125/130
# 14084/14084 [==============================] - 36s 3ms/step - loss: 0.0842 - val_loss: 0.0987
# Epoch 126/130
# 14084/14084 [==============================] - 35s 3ms/step - loss: 0.0853 - val_loss: 0.1027
# Epoch 127/130
# 14084/14084 [==============================] - 35s 2ms/step - loss: 0.0831 - val_loss: 0.0869
# Epoch 128/130
# 14084/14084 [==============================] - 35s 3ms/step - loss: 0.0877 - val_loss: 0.1076
# Epoch 129/130
# 14084/14084 [==============================] - 35s 3ms/step - loss: 0.0880 - val_loss: 0.1036
# Epoch 130/130
# 14084/14084 [==============================] - 36s 3ms/step - loss: 0.0852 - val_loss: 0.0992
# Model: "sequential_38"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_59 (Bidirectio (None, 24, 128)           39424
# _________________________________________________________________
# layer_normalization_48 (Laye (None, 24, 128)           256
# _________________________________________________________________
# bidirectional_60 (Bidirectio (None, 128)               98816
# _________________________________________________________________
# layer_normalization_49 (Laye (None, 128)               256
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_37 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 138,881
# Trainable params: 138,881
# Non-trainable params: 0
# _________________________________________________________________
# Model Saved

# %%
# Predict

# %%
import time
# layernormalization 屬於自訂義層,直接load model 會報錯
custom_ob = {'LayerNormalization': LayerNormalization}
model = load_model('LSTM_model_4.h5', custom_objects=custom_ob)
t1 = time.time()
y_pred = model.predict(x_test)
t2 = time.time()
print('Predict time: ',t2-t1)
y_pred = scaler.inverse_transform(y_pred)#Undo scaling
#y_pred
# Out:
# Predict time:  0.7599716186523438

# %%
from sklearn.metrics import mean_squared_error, r2_score
rmse_lstm = np.sqrt(mean_squared_error(y_test, y_pred))
print('RMSE: ',rmse_lstm)

r2 =  r2_score(y_test, y_pred)
print('R-square: ',r2)

n = len(y_test)
p = 12
Adj_r2 = 1-(1-r2)*(n-1)/(n-p-1)
print('Adj R-square: ',r2)
# Out:
# RMSE:  419.65933349677994
# R-square:  0.7960188475809017
# Adj R-square:  0.7960188475809017

# %%
plt.figure(figsize=(16, 8))
# plt.plot(y_test[1200:1500], label='true')
# plt.plot(y_pred[1200:1500], label='predicted')
plt.plot(y_test, label='true')
plt.plot(y_pred, label='predicted')
plt.legend()

# %%
plt.plot(history.history["loss"],label="loss")
plt.plot(history.history["val_loss"],label="val_loss")
plt.legend(loc="best")
plt.xlabel("No. Of Epochs")
plt.ylabel("mse score")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-1c42d638741e> in <module>
# ----> 1 plt.plot(history.history["loss"],label="loss")
#       2 plt.plot(history.history["val_loss"],label="val_loss")
#       3 plt.legend(loc="best")
#       4 plt.xlabel("No. Of Epochs")
#       5 plt.ylabel("mse score")
#
# NameError: name 'history' is not defined

# %%
plt.figure(figsize=(16, 8))
plt.plot(y_test[1200:1500], label='true')
plt.plot(y_pred[1200:1500], label='predicted')
plt.legend()
