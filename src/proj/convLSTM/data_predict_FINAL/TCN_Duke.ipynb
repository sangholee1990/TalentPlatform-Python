# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tcn import TCN # main library
import math
from sklearn.preprocessing import RobustScaler
#from keras.initializers import  glorot_normal, RandomUniform
#from keras import optimizers,regularizers

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import load_model 
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
df = pd.read_csv("station_bike _Duke.csv")
df["timestamp"] = pd.to_datetime(df["timestamp"])
df = df.set_index("timestamp")
#df.head()

df["hour"] = df.index.hour
df["day_of_month"] = df.index.day
df["day_of_week"]  = df.index.dayofweek
df["month"] = df.index.month

training_data_len = math.ceil(len(df) * 0.9) # taking 90% of data to train and 10% of data to test
testing_data_len = len(df) - training_data_len

time_steps = 24
train, test = df.iloc[0:training_data_len], df.iloc[(training_data_len-time_steps):len(df)]
print(df.shape, train.shape, test.shape)

train_trans = train[['t1','t2', 'hum', 'wind_speed']].to_numpy()
test_trans = test[['t1','t2', 'hum', 'wind_speed']].to_numpy()

scaler = RobustScaler() # Handles outliers
train.loc[:, ['t1','t2','hum', 'wind_speed']]=scaler.fit_transform(train_trans)
test.loc[:, ['t1','t2', 'hum', 'wind_speed']]=scaler.fit_transform(test_trans)

train['cnt'] = scaler.fit_transform(train[['cnt']])
test['cnt'] = scaler.fit_transform(test[['cnt']])

from tqdm import tqdm_notebook as tqdm

#Split the data into x_train and y_train data sets
x_train = []
y_train = []

for i in tqdm(range(len(train) - time_steps)):
    x_train.append(train.drop(columns='cnt').iloc[i:i + time_steps].to_numpy())
    y_train.append(train.loc[:,'cnt'].iloc[i + time_steps])

#Convert x_train and y_train to numpy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

#Create the x_test and y_test data sets
x_test = []
y_test = df.loc[:,'cnt'].iloc[training_data_len:len(df)]

for i in tqdm(range(len(test) - time_steps)):
    x_test.append(test.drop(columns='cnt').iloc[i:i + time_steps].to_numpy())
    # y_test.append(test.loc[:,'cnt'].iloc[i + time_steps])

#Convert x_test and y_test to numpy arrays
x_test = np.array(x_test)
y_test = np.array(y_test)

# All 12 columns of the data
print('Train size:')
print(x_train.shape, y_train.shape)
print('Test size:')
print(x_test.shape, y_test.shape)
# Out:
# (160, 13) (144, 13) (40, 13)
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:34: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/120 [00:00<?, ?it/s]
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:46: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/16 [00:00<?, ?it/s]
# Train size:
# (120, 24, 12) (120,)
# Test size:
# (16, 24, 12) (16,)

# %%
#init = glorot_normal(seed=None) # 給 LSTM
#init_d = RandomUniform(minval=-0.05, maxval=0.05) # 給 Dense layer
#nadam = optimizers.Nadam(lr=0.002,clipvalue=0.5)
from tensorflow.keras.initializers import RandomUniform
init_d = RandomUniform(minval=-0.05, maxval=0.05) # 給 Dense layer
model = Sequential()
model.add(TCN(input_shape=(x_train.shape[1],x_train.shape[2]),
        kernel_size=3,
        nb_filters=20,
        nb_stacks=1,
        dilations=(1, 2, 4, 8),
        kernel_initializer='glorot_uniform',
        use_skip_connections=True,
        use_batch_norm=False,
        use_weight_norm=False,
        use_layer_norm=True,
        dropout_rate = 0.05,
        return_sequences=True
        ))
model.add(Dropout(0.3))
model.add(TCN(
        kernel_size=3,
        nb_filters=20,
        nb_stacks=1,
        dilations=(1, 2, 4, 8),
        kernel_initializer='glorot_uniform',
        use_skip_connections=True,
        use_batch_norm=False,
        use_weight_norm=False,
        use_layer_norm=True,
        dropout_rate = 0.05,
        return_sequences=False
        ))  
model.add(Dropout(0.3))
model.add(Dense(1,kernel_initializer=init_d))  
model.summary()

print('Train...')
model.compile(optimizer = "nadam" , loss="mse")
history = model.fit(x_train, y_train, epochs=120, batch_size=12, validation_split=0.1, shuffle=True)
#Save Model
model.save('TCN_model_duke.h5')  # creates a HDF5 file 
del model

custom_ob = {'TCN': TCN}
# model = load_model('TCN_model_1.h5', custom_objects=custom_ob)
model = load_model('TCN_model_duke.h5', custom_objects=custom_ob)
print('Load Success')

import time
t1 = time.time()
y_pred = model.predict(x_test)
t2 = time.time()
print('Predict time: ',t2-t1)
y_pred = scaler.inverse_transform(y_pred)#Undo scaling

from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error
rmse_lstm = np.sqrt(mean_squared_error(y_test, y_pred))
print('RMSE: ',rmse_lstm)

mae = mean_absolute_error(y_test, y_pred)
print('MAE: ',mae)

r2 =  r2_score(y_test, y_pred)
print('R-square: ',r2)


n = len(y_test)
p = 12
Adj_r2 = 1-(1-r2)*(n-1)/(n-p-1)
print('Adj R-square: ',Adj_r2)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# tcn_4 (TCN)                  (None, 24, 20)            9860
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 24, 20)            0
# _________________________________________________________________
# tcn_5 (TCN)                  (None, 20)                10080
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 19,961
# Trainable params: 19,961
# Non-trainable params: 0
# _________________________________________________________________
# Train...
# Train on 108 samples, validate on 12 samples
# Epoch 1/120
# 108/108 [==============================] - 6s 59ms/sample - loss: 1.2480 - val_loss: 0.7070
# Epoch 2/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 1.0477 - val_loss: 0.6657
# Epoch 3/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 1.1042 - val_loss: 0.6496
# Epoch 4/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 1.1922 - val_loss: 0.6372
# Epoch 5/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 1.0612 - val_loss: 0.6225
# Epoch 6/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 1.0251 - val_loss: 0.5862
# Epoch 7/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 1.0260 - val_loss: 0.5287
# Epoch 8/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 1.0050 - val_loss: 0.4191
# Epoch 9/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.9373 - val_loss: 0.4276
# Epoch 10/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.8358 - val_loss: 0.3552
# Epoch 11/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.8244 - val_loss: 0.3234
# Epoch 12/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.7004 - val_loss: 0.2597
# Epoch 13/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.6802 - val_loss: 0.2643
# Epoch 14/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.5799 - val_loss: 0.2045
# Epoch 15/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.6507 - val_loss: 0.2255
# Epoch 16/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.5239 - val_loss: 0.1865
# Epoch 17/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4691 - val_loss: 0.2275
# Epoch 18/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4983 - val_loss: 0.2353
# Epoch 19/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.5863 - val_loss: 0.2584
# Epoch 20/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4635 - val_loss: 0.2824
# Epoch 21/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3337 - val_loss: 0.1830
# Epoch 22/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3894 - val_loss: 0.1663
# Epoch 23/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4680 - val_loss: 0.1305
# Epoch 24/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2972 - val_loss: 0.1674
# Epoch 25/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3781 - val_loss: 0.1623
# Epoch 26/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3585 - val_loss: 0.1934
# Epoch 27/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3309 - val_loss: 0.2118
# Epoch 28/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4271 - val_loss: 0.1668
# Epoch 29/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3374 - val_loss: 0.2625
# Epoch 30/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3255 - val_loss: 0.2716
# Epoch 31/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2699 - val_loss: 0.2571
# Epoch 32/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3283 - val_loss: 0.1847
# Epoch 33/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2645 - val_loss: 0.2206
# Epoch 34/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2621 - val_loss: 0.2137
# Epoch 35/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2649 - val_loss: 0.2039
# Epoch 36/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2364 - val_loss: 0.3032
# Epoch 37/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2438 - val_loss: 0.2710
# Epoch 38/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3171 - val_loss: 0.2781
# Epoch 39/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2896 - val_loss: 0.2644
# Epoch 40/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2421 - val_loss: 0.2890
# Epoch 41/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2224 - val_loss: 0.2626
# Epoch 42/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2068 - val_loss: 0.2743
# Epoch 43/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1968 - val_loss: 0.2534
# Epoch 44/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2853 - val_loss: 0.3049
# Epoch 45/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2264 - val_loss: 0.2661
# Epoch 46/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1557 - val_loss: 0.2768
# Epoch 47/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2798 - val_loss: 0.2141
# Epoch 48/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2038 - val_loss: 0.2577
# Epoch 49/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2370 - val_loss: 0.2357
# Epoch 50/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1441 - val_loss: 0.2506
# Epoch 51/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2516 - val_loss: 0.2341
# Epoch 52/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1767 - val_loss: 0.2803
# Epoch 53/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1936 - val_loss: 0.2248
# Epoch 54/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2132 - val_loss: 0.1746
# Epoch 55/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2439 - val_loss: 0.2009
# Epoch 56/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1637 - val_loss: 0.2363
# Epoch 57/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2266 - val_loss: 0.1942
# Epoch 58/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1283 - val_loss: 0.2269
# Epoch 59/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1793 - val_loss: 0.2071
# Epoch 60/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2053 - val_loss: 0.2845
# Epoch 61/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1833 - val_loss: 0.2291
# Epoch 62/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1809 - val_loss: 0.2206
# Epoch 63/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1582 - val_loss: 0.2035
# Epoch 64/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2138 - val_loss: 0.2036
# Epoch 65/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1980 - val_loss: 0.2224
# Epoch 66/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2368 - val_loss: 0.1891
# Epoch 67/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1903 - val_loss: 0.1754
# Epoch 68/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2738 - val_loss: 0.2265
# Epoch 69/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1823 - val_loss: 0.2248
# Epoch 70/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1744 - val_loss: 0.2492
# Epoch 71/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1916 - val_loss: 0.2305
# Epoch 72/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1829 - val_loss: 0.2918
# Epoch 73/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1648 - val_loss: 0.2326
# Epoch 74/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1423 - val_loss: 0.2100
# Epoch 75/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1902 - val_loss: 0.2558
# Epoch 76/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2334 - val_loss: 0.2054
# Epoch 77/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1713 - val_loss: 0.2104
# Epoch 78/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1253 - val_loss: 0.2293
# Epoch 79/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1845 - val_loss: 0.2089
# Epoch 80/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1370 - val_loss: 0.1797
# Epoch 81/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2782 - val_loss: 0.1850
# Epoch 82/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1879 - val_loss: 0.1752
# Epoch 83/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1092 - val_loss: 0.1902
# Epoch 84/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1021 - val_loss: 0.2497
# Epoch 85/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1364 - val_loss: 0.2789
# Epoch 86/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1777 - val_loss: 0.2109
# Epoch 87/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1667 - val_loss: 0.1932
# Epoch 88/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1803 - val_loss: 0.2398
# Epoch 89/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2118 - val_loss: 0.2203
# Epoch 90/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1752 - val_loss: 0.2211
# Epoch 91/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1581 - val_loss: 0.2375
# Epoch 92/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1752 - val_loss: 0.1885
# Epoch 93/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1601 - val_loss: 0.2140
# Epoch 94/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1407 - val_loss: 0.2093
# Epoch 95/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2012 - val_loss: 0.2467
# Epoch 96/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1604 - val_loss: 0.2280
# Epoch 97/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1778 - val_loss: 0.2118
# Epoch 98/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2139 - val_loss: 0.2581
# Epoch 99/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2184 - val_loss: 0.2715
# Epoch 100/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2035 - val_loss: 0.2721
# Epoch 101/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1742 - val_loss: 0.2351
# Epoch 102/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1691 - val_loss: 0.2294
# Epoch 103/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1719 - val_loss: 0.2010
# Epoch 104/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1674 - val_loss: 0.2086
# Epoch 105/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1636 - val_loss: 0.2031
# Epoch 106/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1493 - val_loss: 0.2055
# Epoch 107/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2550 - val_loss: 0.2334
# Epoch 108/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2346 - val_loss: 0.2113
# Epoch 109/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1339 - val_loss: 0.2261
# Epoch 110/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1466 - val_loss: 0.2486
# Epoch 111/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1589 - val_loss: 0.2787
# Epoch 112/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1186 - val_loss: 0.3175
# Epoch 113/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1536 - val_loss: 0.2727
# Epoch 114/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1657 - val_loss: 0.2335
# Epoch 115/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1761 - val_loss: 0.2583
# Epoch 116/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1883 - val_loss: 0.2404
# Epoch 117/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1889 - val_loss: 0.2397
# Epoch 118/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1017 - val_loss: 0.2508
# Epoch 119/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1280 - val_loss: 0.2906
# Epoch 120/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1046 - val_loss: 0.2631
# Load Success
# Predict time:  0.697364330291748
# RMSE:  13.175349476068467
# MAE:  9.89461663365364
# R-square:  -0.695174421401245
# Adj R-square:  -7.475872107006225
