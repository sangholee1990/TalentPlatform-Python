# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
import math
from sklearn.preprocessing import RobustScaler, MinMaxScaler
from tqdm import tqdm_notebook as tqdm
from tcn import TCN
import time
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error
from keras.preprocessing import sequence
from keras.models import Sequential , load_model , Model
from keras.layers import Dense, Dropout , LSTM , Bidirectional ,GRU ,Flatten,Add,BatchNormalization
from keras_layer_normalization import LayerNormalization
from keras.initializers import  glorot_normal, RandomUniform
from keras import optimizers,Input
from keras_self_attention import SeqSelfAttention
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv("Mode2_bike_region.csv")
df["timestamp"] = pd.to_datetime(df["timestamp"])
df = df.set_index("timestamp")
#df.head()

df["hour"] = df.index.hour
df["day_of_month"] = df.index.day
df["day_of_week"]  = df.index.dayofweek
df["month"] = df.index.month

training_data_len = math.ceil(len(df) * 0.9) # taking 90% of data to train and 10% of data to test
testing_data_len = len(df) - training_data_len

time_steps = 24
train, test = df.iloc[0:training_data_len], df.iloc[(training_data_len-time_steps):len(df)]
print(df.shape, train.shape, test.shape)
train_trans = train[['t1','t2', 'hum', 'wind_speed']].to_numpy()
test_trans = test[['t1','t2', 'hum', 'wind_speed']].to_numpy()

scaler = RobustScaler() # Handles outliers
#scaler = MinMaxScaler(feature_range=(0, 1)) # scale to (0,1)
train.loc[:, ['t1','t2','hum', 'wind_speed']]=scaler.fit_transform(train_trans)
test.loc[:, ['t1','t2', 'hum', 'wind_speed']]=scaler.fit_transform(test_trans)

train['cnt'] = scaler.fit_transform(train[['cnt']])
test['cnt'] = scaler.fit_transform(test[['cnt']])

#Split the data into x_train and y_train data sets
x_train = []
y_train = []

for i in tqdm(range(len(train) - time_steps)):
    x_train.append(train.drop(columns='cnt').iloc[i:i + time_steps].to_numpy())
    y_train.append(train.loc[:,'cnt'].iloc[i + time_steps])

#Convert x_train and y_train to numpy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

#Create the x_test and y_test data sets
x_test = []
y_test = df.loc[:,'cnt'].iloc[training_data_len:len(df)]

for i in tqdm(range(len(test) - time_steps)):
    x_test.append(test.drop(columns='cnt').iloc[i:i + time_steps].to_numpy())
    # y_test.append(test.loc[:,'cnt'].iloc[i + time_steps])

#Convert x_test and y_test to numpy arrays
x_test = np.array(x_test)
y_test = np.array(y_test)

# All 12 columns of the data
print('Train size:')
print(x_train.shape, y_train.shape)
print('Test size:')
print(x_test.shape, y_test.shape)
# Out:
# (735, 16) (662, 16) (97, 16)
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:32: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/638 [00:00<?, ?it/s]
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:44: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/73 [00:00<?, ?it/s]
# Train size:
# (638, 24, 15) (638,)
# Test size:
# (73, 24, 15) (73,)

# %%
from keras.layers import Concatenate
init = glorot_normal(seed=None) # 給 GRU
init_d = RandomUniform(minval=-0.05, maxval=0.05) # 給 Dense layer

def Encoder(layer):
    shortcut = layer
    layer = SeqSelfAttention(
                     attention_type=SeqSelfAttention.ATTENTION_TYPE_MUL,
                     kernel_regularizer=tf.keras.regularizers.l2(0.01),
                     bias_regularizer=tf.keras.regularizers.l2(0.01),
                     attention_regularizer_weight=0.0001)(layer)
    layer = Add()([layer,shortcut])
    layer = LayerNormalization()(layer)
    layer = Flatten()(layer)
    
    shortcut2 = layer
    layer = Dense(16,kernel_initializer=init_d)(layer)
    layer = Dropout(0.5)(layer)
    layer = Concatenate()([layer,shortcut2])
    output = Dense(1,kernel_initializer=init_d)(layer)
    return output

def Decoder(layer):
    shortcut = layer
    layer = SeqSelfAttention(
                     attention_type=SeqSelfAttention.ATTENTION_TYPE_MUL,
                     kernel_regularizer=tf.keras.regularizers.l2(0.01),
                     bias_regularizer=tf.keras.regularizers.l2(0.01),
                     attention_regularizer_weight=0.0001)(layer)
    layer = Add()([layer,shortcut])
    layer = LayerNormalization()(layer)
    layer = SeqSelfAttention(
                     attention_type=SeqSelfAttention.ATTENTION_TYPE_MUL,
                     kernel_regularizer=tf.keras.regularizers.l2(0.01),
                     bias_regularizer=tf.keras.regularizers.l2(0.01),
                     attention_regularizer_weight=0.0001)(layer)
    layer = LayerNormalization()(layer)
    
    layer = Flatten()(layer)
    shortcut2 = layer
    layer = Dense(16,kernel_initializer=init_d)(layer)
    layer = Dropout(0.3)(layer)
    layer = Concatenate()([layer,shortcut2])
    output = Dense(1,kernel_initializer=init_d)(layer)
    return output

def Bi_GRU(layer,unit):
    output = Bidirectional(GRU(unit, dropout=0.25, recurrent_dropout=0.25, return_sequences=True,
                            kernel_initializer=init))(layer)
    return output

#start = Input(shape = (x_train.shape[1],x_train.shape[2]))
start = Input(shape = (x_train.shape[1:]))
start2 = Input(shape = (x_train.shape[1:]))
x = Bi_GRU(start,32)
x = Encoder(x)

y = Bi_GRU(start2,16)
y = Decoder(y)

Merge = Add()([x,y])
Last = Dense(1)(Merge)
model = Model([start,start2] , Last)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 24, 15)       0
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 24, 32)       3072        input_2[0][0]
# __________________________________________________________________________________________________
# input_1 (InputLayer)            (None, 24, 15)       0
# __________________________________________________________________________________________________
# seq_self_attention_2 (SeqSelfAt (None, 24, 32)       1025        bidirectional_2[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 24, 64)       9216        input_1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 24, 32)       0           seq_self_attention_2[0][0]
#                                                                  bidirectional_2[0][0]
# __________________________________________________________________________________________________
# seq_self_attention_1 (SeqSelfAt (None, 24, 64)       4097        bidirectional_1[0][0]
# __________________________________________________________________________________________________
# layer_normalization_2 (LayerNor (None, 24, 32)       64          add_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 24, 64)       0           seq_self_attention_1[0][0]
#                                                                  bidirectional_1[0][0]
# __________________________________________________________________________________________________
# seq_self_attention_3 (SeqSelfAt (None, 24, 32)       1025        layer_normalization_2[0][0]
# __________________________________________________________________________________________________
# layer_normalization_1 (LayerNor (None, 24, 64)       128         add_1[0][0]
# __________________________________________________________________________________________________
# layer_normalization_3 (LayerNor (None, 24, 32)       64          seq_self_attention_3[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 1536)         0           layer_normalization_1[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 768)          0           layer_normalization_3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 16)           24592       flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 16)           12304       flatten_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16)           0           dense_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 1552)         0           dropout_1[0][0]
#                                                                  flatten_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 784)          0           dropout_2[0][0]
#                                                                  flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            1553        concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            785         concatenate_2[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 1)            0           dense_2[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            2           add_3[0][0]
# ==================================================================================================
# Total params: 57,927
# Trainable params: 57,927
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
opt = optimizers.Adam(lr=0.0009)
print('Train...')
model.compile(optimizer = opt , loss="mse")
#model.compile(optimizer = "adam" , loss="mse")
history = model.fit([x_train,x_train], y_train, epochs = 500, batch_size=24, validation_split=0.1, shuffle=True)
# history = model.fit(x_train, y_train, epochs = 500, batch_size=6, validation_split=0.1, shuffle=True)
model.summary()
#Save Model
model.save('GRU_Single_Attention_model_region.h5')  # creates a HDF5 file 
del model
# Out:
# Train...
# Train on 574 samples, validate on 64 samples
# Epoch 1/500
# 574/574 [==============================] - 4s 7ms/step - loss: 2.9092 - val_loss: 2.8115
# Epoch 2/500
# 574/574 [==============================] - 2s 3ms/step - loss: 2.2457 - val_loss: 1.8226
# Epoch 3/500
# 574/574 [==============================] - 2s 3ms/step - loss: 2.0144 - val_loss: 3.2627
# Epoch 4/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.9207 - val_loss: 5.1881
# Epoch 5/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.8568 - val_loss: 5.5737
# Epoch 6/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.8041 - val_loss: 5.9436
# Epoch 7/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.7835 - val_loss: 1.7387
# Epoch 8/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.7867 - val_loss: 8.0046
# Epoch 9/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.6547 - val_loss: 3.9722
# Epoch 10/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.6744 - val_loss: 5.1504
# Epoch 11/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.5618 - val_loss: 4.5295
# Epoch 12/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.5618 - val_loss: 4.6915
# Epoch 13/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.5209 - val_loss: 4.1521
# Epoch 14/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.4898 - val_loss: 4.1937
# Epoch 15/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.4906 - val_loss: 5.4542
# Epoch 16/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.4490 - val_loss: 8.1279
# Epoch 17/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.4735 - val_loss: 3.3106
# Epoch 18/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.3947 - val_loss: 5.8381
# Epoch 19/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.3576 - val_loss: 4.8425
# Epoch 20/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.3761 - val_loss: 5.8232
# Epoch 21/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.3963 - val_loss: 2.7446
# Epoch 22/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.2998 - val_loss: 3.4326
# Epoch 23/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.2994 - val_loss: 2.8889
# Epoch 24/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.2976 - val_loss: 4.3500
# Epoch 25/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.2611 - val_loss: 3.7191
# Epoch 26/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.2399 - val_loss: 7.8786
# Epoch 27/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.2472 - val_loss: 9.2727
# Epoch 28/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.2258 - val_loss: 6.8271
# Epoch 29/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.2243 - val_loss: 4.7695
# Epoch 30/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.1840 - val_loss: 6.1245
# Epoch 31/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.1516 - val_loss: 3.3884
# Epoch 32/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.1616 - val_loss: 4.5231
# Epoch 33/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.1223 - val_loss: 8.6899
# Epoch 34/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.1295 - val_loss: 6.1563
# Epoch 35/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.1155 - val_loss: 8.0258
# Epoch 36/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.1095 - val_loss: 9.0225
# Epoch 37/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.0968 - val_loss: 5.4852
# Epoch 38/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.1003 - val_loss: 6.3063
# Epoch 39/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.0678 - val_loss: 6.9003
# Epoch 40/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.0553 - val_loss: 6.4583
# Epoch 41/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.0529 - val_loss: 7.1551
# Epoch 42/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.0731 - val_loss: 5.6420
# Epoch 43/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.0530 - val_loss: 5.3623
# Epoch 44/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.0354 - val_loss: 6.1451
# Epoch 45/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.0103 - val_loss: 7.8352
# Epoch 46/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.0106 - val_loss: 4.2899
# Epoch 47/500
# 574/574 [==============================] - 2s 3ms/step - loss: 1.0309 - val_loss: 4.8448
# Epoch 48/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.9585 - val_loss: 6.4743
# Epoch 49/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.9594 - val_loss: 5.4926
# Epoch 50/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.9370 - val_loss: 5.6988
# Epoch 51/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.9792 - val_loss: 7.0957
# Epoch 52/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.9478 - val_loss: 8.7317
# Epoch 53/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.9467 - val_loss: 6.2077
# Epoch 54/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.9361 - val_loss: 4.4179
# Epoch 55/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.9506 - val_loss: 8.6164
# Epoch 56/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.8760 - val_loss: 8.6571
# Epoch 57/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.9076 - val_loss: 7.1785
# Epoch 58/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.9078 - val_loss: 6.5642
# Epoch 59/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.9219 - val_loss: 8.3367
# Epoch 60/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.9009 - val_loss: 7.2617
# Epoch 61/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.8926 - val_loss: 7.6515
# Epoch 62/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.8995 - val_loss: 8.4545
# Epoch 63/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.8837 - val_loss: 7.4879
# Epoch 64/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.8662 - val_loss: 6.1267
# Epoch 65/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.8793 - val_loss: 7.3721
# Epoch 66/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.8518 - val_loss: 7.8218
# Epoch 67/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.8392 - val_loss: 10.3841
# Epoch 68/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.8524 - val_loss: 10.3867
# Epoch 69/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.8065 - val_loss: 9.0825
# Epoch 70/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.8700 - val_loss: 9.2993
# Epoch 71/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.8555 - val_loss: 8.9103
# Epoch 72/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.8354 - val_loss: 11.4737
# Epoch 73/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.8053 - val_loss: 12.7099
# Epoch 74/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.7949 - val_loss: 11.6189
# Epoch 75/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.8335 - val_loss: 9.3547
# Epoch 76/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.8146 - val_loss: 6.9893
# Epoch 77/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.8210 - val_loss: 9.0071
# Epoch 78/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.7863 - val_loss: 8.1096
# Epoch 79/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.8146 - val_loss: 9.5105
# Epoch 80/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.7921 - val_loss: 11.9142
# Epoch 81/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.7769 - val_loss: 12.2483
# Epoch 82/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.7536 - val_loss: 13.9350
# Epoch 83/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.7991 - val_loss: 13.7553
# Epoch 84/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.7626 - val_loss: 12.2352
# Epoch 85/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.7477 - val_loss: 12.0148
# Epoch 86/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.7722 - val_loss: 13.3253
# Epoch 87/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.7391 - val_loss: 14.3298
# Epoch 88/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.7216 - val_loss: 10.8308
# Epoch 89/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.7375 - val_loss: 12.8330
# Epoch 90/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.7171 - val_loss: 12.2413
# Epoch 91/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.7440 - val_loss: 10.7399
# Epoch 92/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.7150 - val_loss: 10.3245
# Epoch 93/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.7495 - val_loss: 11.6815
# Epoch 94/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.7381 - val_loss: 10.8826
# Epoch 95/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.6924 - val_loss: 9.0962
# Epoch 96/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.6927 - val_loss: 8.8664
# Epoch 97/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.7180 - val_loss: 8.1700
# Epoch 98/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.7147 - val_loss: 9.0481
# Epoch 99/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.6644 - val_loss: 11.0232
# Epoch 100/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.7031 - val_loss: 10.5758
# Epoch 101/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.6771 - val_loss: 9.2220
# Epoch 102/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.6773 - val_loss: 10.3612
# Epoch 103/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.6629 - val_loss: 8.9109
# Epoch 104/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.6837 - val_loss: 6.2283
# Epoch 105/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.6561 - val_loss: 6.7137
# Epoch 106/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.6899 - val_loss: 6.5957
# Epoch 107/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.6648 - val_loss: 6.1171
# Epoch 108/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.6541 - val_loss: 6.8164
# Epoch 109/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.6562 - val_loss: 7.5509
# Epoch 110/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.6512 - val_loss: 7.8545
# Epoch 111/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.6424 - val_loss: 8.5349
# Epoch 112/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.6414 - val_loss: 9.0891
# Epoch 113/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.6366 - val_loss: 8.8538
# Epoch 114/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.6335 - val_loss: 9.6662
# Epoch 115/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.6139 - val_loss: 10.4814
# Epoch 116/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.6442 - val_loss: 11.3463
# Epoch 117/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.6348 - val_loss: 9.6321
# Epoch 118/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.6123 - val_loss: 10.9312
# Epoch 119/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.6175 - val_loss: 10.5624
# Epoch 120/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.6060 - val_loss: 9.8280
# Epoch 121/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.5902 - val_loss: 8.8782
# Epoch 122/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.6185 - val_loss: 10.8005
# Epoch 123/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.5720 - val_loss: 10.6991
# Epoch 124/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.5759 - val_loss: 10.0708
# Epoch 125/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.5982 - val_loss: 9.1586
# Epoch 126/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.5866 - val_loss: 8.1917
# Epoch 127/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.5817 - val_loss: 7.1179
# Epoch 128/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.5872 - val_loss: 6.9167
# Epoch 129/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.5979 - val_loss: 5.3463
# Epoch 130/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.5818 - val_loss: 5.4947
# Epoch 131/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.5710 - val_loss: 7.2276
# Epoch 132/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.5863 - val_loss: 6.1842
# Epoch 133/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.5782 - val_loss: 6.6437
# Epoch 134/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.5865 - val_loss: 5.8612
# Epoch 135/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.5770 - val_loss: 7.0950
# Epoch 136/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.5729 - val_loss: 7.3952
# Epoch 137/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.5766 - val_loss: 7.7691
# Epoch 138/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.5375 - val_loss: 7.0243
# Epoch 139/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.6000 - val_loss: 6.9506
# Epoch 140/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.5577 - val_loss: 8.0471
# Epoch 141/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.5314 - val_loss: 8.1545
# Epoch 142/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.5682 - val_loss: 7.9389
# Epoch 143/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.5595 - val_loss: 6.3396
# Epoch 144/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.5274 - val_loss: 5.0011
# Epoch 145/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.5518 - val_loss: 4.2919
# Epoch 146/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.5772 - val_loss: 3.6082
# Epoch 147/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.5348 - val_loss: 4.0235
# Epoch 148/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.5374 - val_loss: 4.5958
# Epoch 149/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.5217 - val_loss: 3.9171
# Epoch 150/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.5148 - val_loss: 3.8330
# Epoch 151/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.5207 - val_loss: 4.7509
# Epoch 152/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.5306 - val_loss: 3.8491
# Epoch 153/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.5277 - val_loss: 4.0340
# Epoch 154/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4997 - val_loss: 3.1039
# Epoch 155/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4901 - val_loss: 3.4799
# Epoch 156/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.5271 - val_loss: 3.0395
# Epoch 157/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.5010 - val_loss: 3.0326
# Epoch 158/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4905 - val_loss: 3.6658
# Epoch 159/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4771 - val_loss: 3.6053
# Epoch 160/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.5026 - val_loss: 4.2569
# Epoch 161/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4935 - val_loss: 2.9461
# Epoch 162/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4820 - val_loss: 3.5583
# Epoch 163/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.5092 - val_loss: 2.1784
# Epoch 164/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4803 - val_loss: 3.4343
# Epoch 165/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4829 - val_loss: 2.3060
# Epoch 166/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4343 - val_loss: 3.0371
# Epoch 167/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4762 - val_loss: 2.9544
# Epoch 168/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4773 - val_loss: 2.1296
# Epoch 169/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4537 - val_loss: 3.6413
# Epoch 170/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4544 - val_loss: 3.2779
# Epoch 171/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.5042 - val_loss: 3.1519
# Epoch 172/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4603 - val_loss: 3.3646
# Epoch 173/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4757 - val_loss: 2.3103
# Epoch 174/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4730 - val_loss: 2.5727
# Epoch 175/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4439 - val_loss: 2.2615
# Epoch 176/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4415 - val_loss: 2.5114
# Epoch 177/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4517 - val_loss: 2.6965
# Epoch 178/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4637 - val_loss: 2.3978
# Epoch 179/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4317 - val_loss: 2.2644
# Epoch 180/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4771 - val_loss: 3.6297
# Epoch 181/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4592 - val_loss: 2.8202
# Epoch 182/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4360 - val_loss: 2.8707
# Epoch 183/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4191 - val_loss: 2.2653
# Epoch 184/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4271 - val_loss: 2.5341
# Epoch 185/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4235 - val_loss: 2.2660
# Epoch 186/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4354 - val_loss: 2.8940
# Epoch 187/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4208 - val_loss: 3.3012
# Epoch 188/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4471 - val_loss: 4.2221
# Epoch 189/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4235 - val_loss: 3.7387
# Epoch 190/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4107 - val_loss: 3.6382
# Epoch 191/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4263 - val_loss: 2.6519
# Epoch 192/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4079 - val_loss: 2.1733
# Epoch 193/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4254 - val_loss: 1.7757
# Epoch 194/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4378 - val_loss: 1.8171
# Epoch 195/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4068 - val_loss: 2.4925
# Epoch 196/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4276 - val_loss: 3.2741
# Epoch 197/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4022 - val_loss: 2.7269
# Epoch 198/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4114 - val_loss: 2.0518
# Epoch 199/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4030 - val_loss: 2.5052
# Epoch 200/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3951 - val_loss: 2.2420
# Epoch 201/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3969 - val_loss: 2.5363
# Epoch 202/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3895 - val_loss: 2.3470
# Epoch 203/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3964 - val_loss: 2.8822
# Epoch 204/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3846 - val_loss: 2.6447
# Epoch 205/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4124 - val_loss: 2.5436
# Epoch 206/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3980 - val_loss: 2.6766
# Epoch 207/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4012 - val_loss: 1.7466
# Epoch 208/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4035 - val_loss: 2.0535
# Epoch 209/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3783 - val_loss: 2.4698
# Epoch 210/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3763 - val_loss: 2.3863
# Epoch 211/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.4142 - val_loss: 2.3319
# Epoch 212/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3875 - val_loss: 2.6749
# Epoch 213/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3731 - val_loss: 3.0164
# Epoch 214/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3946 - val_loss: 2.5794
# Epoch 215/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3910 - val_loss: 2.4766
# Epoch 216/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3695 - val_loss: 2.7777
# Epoch 217/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3627 - val_loss: 3.1897
# Epoch 218/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3786 - val_loss: 4.2566
# Epoch 219/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3694 - val_loss: 2.7628
# Epoch 220/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3564 - val_loss: 2.2563
# Epoch 221/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3897 - val_loss: 2.2500
# Epoch 222/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3528 - val_loss: 2.1135
# Epoch 223/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3494 - val_loss: 2.2603
# Epoch 224/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3637 - val_loss: 2.1969
# Epoch 225/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3483 - val_loss: 3.5900
# Epoch 226/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3700 - val_loss: 3.1945
# Epoch 227/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3655 - val_loss: 3.1593
# Epoch 228/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3306 - val_loss: 3.3490
# Epoch 229/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3549 - val_loss: 2.2987
# Epoch 230/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3477 - val_loss: 1.8582
# Epoch 231/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3553 - val_loss: 2.3378
# Epoch 232/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3297 - val_loss: 2.8348
# Epoch 233/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3378 - val_loss: 2.1132
# Epoch 234/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3486 - val_loss: 2.3553
# Epoch 235/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3248 - val_loss: 2.7278
# Epoch 236/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3221 - val_loss: 2.3081
# Epoch 237/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3515 - val_loss: 2.0921
# Epoch 238/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3514 - val_loss: 2.7923
# Epoch 239/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3191 - val_loss: 2.9292
# Epoch 240/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3529 - val_loss: 3.2300
# Epoch 241/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3518 - val_loss: 2.6702
# Epoch 242/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3469 - val_loss: 2.3041
# Epoch 243/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3338 - val_loss: 1.8388
# Epoch 244/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3338 - val_loss: 1.8441
# Epoch 245/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3195 - val_loss: 2.0149
# Epoch 246/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3369 - val_loss: 2.1088
# Epoch 247/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2951 - val_loss: 2.2478
# Epoch 248/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3318 - val_loss: 2.5389
# Epoch 249/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3430 - val_loss: 2.6869
# Epoch 250/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3320 - val_loss: 2.7601
# Epoch 251/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3088 - val_loss: 2.9089
# Epoch 252/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3104 - val_loss: 2.2480
# Epoch 253/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3550 - val_loss: 2.2634
# Epoch 254/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3125 - val_loss: 2.1658
# Epoch 255/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3205 - val_loss: 1.5152
# Epoch 256/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3172 - val_loss: 1.5126
# Epoch 257/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3120 - val_loss: 1.6912
# Epoch 258/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3297 - val_loss: 1.4703
# Epoch 259/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3139 - val_loss: 1.6173
# Epoch 260/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3016 - val_loss: 1.7376
# Epoch 261/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3012 - val_loss: 2.5698
# Epoch 262/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3001 - val_loss: 2.0497
# Epoch 263/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3219 - val_loss: 1.9635
# Epoch 264/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3069 - val_loss: 2.0505
# Epoch 265/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3262 - val_loss: 2.0848
# Epoch 266/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3279 - val_loss: 2.5112
# Epoch 267/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2872 - val_loss: 1.4704
# Epoch 268/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2997 - val_loss: 1.8063
# Epoch 269/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3074 - val_loss: 1.5949
# Epoch 270/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3153 - val_loss: 1.4945
# Epoch 271/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3008 - val_loss: 1.9028
# Epoch 272/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2714 - val_loss: 1.6746
# Epoch 273/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3156 - val_loss: 1.8414
# Epoch 274/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2931 - val_loss: 1.5995
# Epoch 275/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2773 - val_loss: 1.4769
# Epoch 276/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3037 - val_loss: 1.7502
# Epoch 277/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2601 - val_loss: 1.8388
# Epoch 278/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2705 - val_loss: 1.5380
# Epoch 279/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2879 - val_loss: 1.2124
# Epoch 280/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.3014 - val_loss: 1.2870
# Epoch 281/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2918 - val_loss: 1.8366
# Epoch 282/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2933 - val_loss: 1.5252
# Epoch 283/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2745 - val_loss: 2.1535
# Epoch 284/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2884 - val_loss: 1.3712
# Epoch 285/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2850 - val_loss: 1.8351
# Epoch 286/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2855 - val_loss: 2.6469
# Epoch 287/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2948 - val_loss: 1.6434
# Epoch 288/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2749 - val_loss: 1.8237
# Epoch 289/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2897 - val_loss: 2.0222
# Epoch 290/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2871 - val_loss: 1.5264
# Epoch 291/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2989 - val_loss: 1.8521
# Epoch 292/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2673 - val_loss: 2.2151
# Epoch 293/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2692 - val_loss: 1.9960
# Epoch 294/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2666 - val_loss: 1.6348
# Epoch 295/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2747 - val_loss: 1.1115
# Epoch 296/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2716 - val_loss: 1.2662
# Epoch 297/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2760 - val_loss: 2.1105
# Epoch 298/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2706 - val_loss: 1.9389
# Epoch 299/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2606 - val_loss: 1.8423
# Epoch 300/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2470 - val_loss: 1.0864
# Epoch 301/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2429 - val_loss: 1.1548
# Epoch 302/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2750 - val_loss: 1.0410
# Epoch 303/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2623 - val_loss: 1.5972
# Epoch 304/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2637 - val_loss: 1.7285
# Epoch 305/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2689 - val_loss: 2.1423
# Epoch 306/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2584 - val_loss: 2.1986
# Epoch 307/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2680 - val_loss: 1.3836
# Epoch 308/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2480 - val_loss: 1.6269
# Epoch 309/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2605 - val_loss: 1.9271
# Epoch 310/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2449 - val_loss: 1.9514
# Epoch 311/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2564 - val_loss: 2.2780
# Epoch 312/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2344 - val_loss: 1.9296
# Epoch 313/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2523 - val_loss: 1.9561
# Epoch 314/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2524 - val_loss: 2.0313
# Epoch 315/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2591 - val_loss: 1.8678
# Epoch 316/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2673 - val_loss: 1.7881
# Epoch 317/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2429 - val_loss: 1.3895
# Epoch 318/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2385 - val_loss: 1.9522
# Epoch 319/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2380 - val_loss: 1.5993
# Epoch 320/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2292 - val_loss: 1.3533
# Epoch 321/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2228 - val_loss: 1.7222
# Epoch 322/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2597 - val_loss: 2.3688
# Epoch 323/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2314 - val_loss: 1.6244
# Epoch 324/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2393 - val_loss: 1.8389
# Epoch 325/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2346 - val_loss: 1.7696
# Epoch 326/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2585 - val_loss: 1.9610
# Epoch 327/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2402 - val_loss: 2.0116
# Epoch 328/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2385 - val_loss: 2.0977
# Epoch 329/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2440 - val_loss: 1.4972
# Epoch 330/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2397 - val_loss: 1.9033
# Epoch 331/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2433 - val_loss: 1.7191
# Epoch 332/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2373 - val_loss: 1.7010
# Epoch 333/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2417 - val_loss: 2.4219
# Epoch 334/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2354 - val_loss: 1.9821
# Epoch 335/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2514 - val_loss: 2.0936
# Epoch 336/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2451 - val_loss: 2.1507
# Epoch 337/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2333 - val_loss: 2.6375
# Epoch 338/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2292 - val_loss: 2.1274
# Epoch 339/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2489 - val_loss: 2.3066
# Epoch 340/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2346 - val_loss: 1.9277
# Epoch 341/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2227 - val_loss: 2.6191
# Epoch 342/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2395 - val_loss: 2.1027
# Epoch 343/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2570 - val_loss: 2.0225
# Epoch 344/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2507 - val_loss: 2.3479
# Epoch 345/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2407 - val_loss: 2.5100
# Epoch 346/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2484 - val_loss: 2.3910
# Epoch 347/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2496 - val_loss: 2.2715
# Epoch 348/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2189 - val_loss: 1.4581
# Epoch 349/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2341 - val_loss: 1.5367
# Epoch 350/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2244 - val_loss: 1.7874
# Epoch 351/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2148 - val_loss: 1.9183
# Epoch 352/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2147 - val_loss: 2.1222
# Epoch 353/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2316 - val_loss: 2.3185
# Epoch 354/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2370 - val_loss: 1.5805
# Epoch 355/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2336 - val_loss: 2.4617
# Epoch 356/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2269 - val_loss: 1.5885
# Epoch 357/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2286 - val_loss: 2.3794
# Epoch 358/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2165 - val_loss: 1.9832
# Epoch 359/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2122 - val_loss: 1.9863
# Epoch 360/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2164 - val_loss: 1.8727
# Epoch 361/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2249 - val_loss: 1.5346
# Epoch 362/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2156 - val_loss: 1.6229
# Epoch 363/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2151 - val_loss: 1.8461
# Epoch 364/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1993 - val_loss: 1.7397
# Epoch 365/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2259 - val_loss: 1.7426
# Epoch 366/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1940 - val_loss: 1.9043
# Epoch 367/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2212 - val_loss: 1.6093
# Epoch 368/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2075 - val_loss: 2.4001
# Epoch 369/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2139 - val_loss: 2.2546
# Epoch 370/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2226 - val_loss: 1.8553
# Epoch 371/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2165 - val_loss: 1.6781
# Epoch 372/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2209 - val_loss: 2.3752
# Epoch 373/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2056 - val_loss: 1.9556
# Epoch 374/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2323 - val_loss: 1.7698
# Epoch 375/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2010 - val_loss: 2.3676
# Epoch 376/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2068 - val_loss: 1.9816
# Epoch 377/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2149 - val_loss: 1.7965
# Epoch 378/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2276 - val_loss: 1.5056
# Epoch 379/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2085 - val_loss: 1.5498
# Epoch 380/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2215 - val_loss: 1.6923
# Epoch 381/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2014 - val_loss: 2.1513
# Epoch 382/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2137 - val_loss: 1.5831
# Epoch 383/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2116 - val_loss: 1.4327
# Epoch 384/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2106 - val_loss: 1.4479
# Epoch 385/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2052 - val_loss: 1.8618
# Epoch 386/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2127 - val_loss: 1.4878
# Epoch 387/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2015 - val_loss: 1.5457
# Epoch 388/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2013 - val_loss: 1.5284
# Epoch 389/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1969 - val_loss: 1.1799
# Epoch 390/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2019 - val_loss: 1.6612
# Epoch 391/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1976 - val_loss: 1.2663
# Epoch 392/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2044 - val_loss: 1.6980
# Epoch 393/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1903 - val_loss: 1.7981
# Epoch 394/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1910 - val_loss: 1.1082
# Epoch 395/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2008 - val_loss: 1.2022
# Epoch 396/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1836 - val_loss: 1.6681
# Epoch 397/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1905 - val_loss: 2.0624
# Epoch 398/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2058 - val_loss: 1.1792
# Epoch 399/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2035 - val_loss: 1.3384
# Epoch 400/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1781 - val_loss: 1.6124
# Epoch 401/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1880 - val_loss: 1.3162
# Epoch 402/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1888 - val_loss: 1.2824
# Epoch 403/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1985 - val_loss: 1.2453
# Epoch 404/500
# 574/574 [==============================] - 2s 4ms/step - loss: 0.1882 - val_loss: 1.5327
# Epoch 405/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1941 - val_loss: 1.6190
# Epoch 406/500
# 574/574 [==============================] - 2s 4ms/step - loss: 0.1906 - val_loss: 1.4612
# Epoch 407/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1941 - val_loss: 1.6690
# Epoch 408/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2134 - val_loss: 1.2759
# Epoch 409/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1910 - val_loss: 1.4047
# Epoch 410/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1881 - val_loss: 1.5789
# Epoch 411/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1757 - val_loss: 1.2873
# Epoch 412/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1954 - val_loss: 1.5538
# Epoch 413/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1787 - val_loss: 1.4567
# Epoch 414/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1800 - val_loss: 1.7110
# Epoch 415/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1896 - val_loss: 1.7441
# Epoch 416/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1782 - val_loss: 1.6074
# Epoch 417/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1792 - val_loss: 1.4600
# Epoch 418/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1929 - val_loss: 1.4982
# Epoch 419/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1774 - val_loss: 1.4654
# Epoch 420/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1923 - val_loss: 1.5328
# Epoch 421/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1725 - val_loss: 1.3244
# Epoch 422/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1893 - val_loss: 1.2084
# Epoch 423/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1840 - val_loss: 1.4036
# Epoch 424/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2172 - val_loss: 1.2639
# Epoch 425/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1955 - val_loss: 0.8968
# Epoch 426/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1927 - val_loss: 1.0151
# Epoch 427/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1757 - val_loss: 1.2026
# Epoch 428/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.2048 - val_loss: 1.2672
# Epoch 429/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1737 - val_loss: 1.3167
# Epoch 430/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1637 - val_loss: 1.2724
# Epoch 431/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1750 - val_loss: 2.1367
# Epoch 432/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1866 - val_loss: 1.6656
# Epoch 433/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1629 - val_loss: 1.6886
# Epoch 434/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1975 - val_loss: 1.2415
# Epoch 435/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1809 - val_loss: 1.2664
# Epoch 436/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1820 - val_loss: 1.2316
# Epoch 437/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1781 - val_loss: 1.0525
# Epoch 438/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1731 - val_loss: 1.2445
# Epoch 439/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1696 - val_loss: 1.1592
# Epoch 440/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1756 - val_loss: 1.1120
# Epoch 441/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1826 - val_loss: 1.0852
# Epoch 442/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1782 - val_loss: 0.9654
# Epoch 443/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1734 - val_loss: 1.2275
# Epoch 444/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1833 - val_loss: 1.4477
# Epoch 445/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1743 - val_loss: 1.6001
# Epoch 446/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1795 - val_loss: 2.0190
# Epoch 447/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1837 - val_loss: 1.7517
# Epoch 448/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1669 - val_loss: 1.3250
# Epoch 449/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1688 - val_loss: 1.2108
# Epoch 450/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1586 - val_loss: 1.0844
# Epoch 451/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1548 - val_loss: 1.2458
# Epoch 452/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1605 - val_loss: 1.1775
# Epoch 453/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1818 - val_loss: 0.9670
# Epoch 454/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1652 - val_loss: 1.3290
# Epoch 455/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1439 - val_loss: 1.2988
# Epoch 456/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1551 - val_loss: 1.3705
# Epoch 457/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1622 - val_loss: 1.4348
# Epoch 458/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1627 - val_loss: 1.2702
# Epoch 459/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1742 - val_loss: 1.2356
# Epoch 460/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1633 - val_loss: 1.2305
# Epoch 461/500
# 574/574 [==============================] - 2s 4ms/step - loss: 0.1543 - val_loss: 1.3928
# Epoch 462/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1611 - val_loss: 1.3927
# Epoch 463/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1578 - val_loss: 1.4273
# Epoch 464/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1615 - val_loss: 1.2328
# Epoch 465/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1684 - val_loss: 1.4843
# Epoch 466/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1749 - val_loss: 1.3803
# Epoch 467/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1592 - val_loss: 1.1402
# Epoch 468/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1606 - val_loss: 1.5020
# Epoch 469/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1610 - val_loss: 1.7606
# Epoch 470/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1708 - val_loss: 1.2811
# Epoch 471/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1699 - val_loss: 1.5381
# Epoch 472/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1528 - val_loss: 1.3164
# Epoch 473/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1613 - val_loss: 1.5498
# Epoch 474/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1535 - val_loss: 1.3775
# Epoch 475/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1513 - val_loss: 1.4814
# Epoch 476/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1542 - val_loss: 1.4548
# Epoch 477/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1641 - val_loss: 1.4487
# Epoch 478/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1673 - val_loss: 1.3651
# Epoch 479/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1689 - val_loss: 1.2688
# Epoch 480/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1553 - val_loss: 1.3562
# Epoch 481/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1550 - val_loss: 1.6108
# Epoch 482/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1432 - val_loss: 1.4580
# Epoch 483/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1585 - val_loss: 1.4150
# Epoch 484/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1586 - val_loss: 1.5124
# Epoch 485/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1680 - val_loss: 1.3985
# Epoch 486/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1501 - val_loss: 1.3484
# Epoch 487/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1700 - val_loss: 1.4315
# Epoch 488/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1617 - val_loss: 1.3743
# Epoch 489/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1582 - val_loss: 1.3054
# Epoch 490/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1544 - val_loss: 1.4407
# Epoch 491/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1524 - val_loss: 1.2409
# Epoch 492/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1659 - val_loss: 1.5645
# Epoch 493/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1512 - val_loss: 1.5203
# Epoch 494/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1653 - val_loss: 1.2113
# Epoch 495/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1576 - val_loss: 1.6365
# Epoch 496/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1570 - val_loss: 1.5113
# Epoch 497/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1520 - val_loss: 0.9806
# Epoch 498/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1524 - val_loss: 1.4146
# Epoch 499/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1571 - val_loss: 1.1176
# Epoch 500/500
# 574/574 [==============================] - 2s 3ms/step - loss: 0.1579 - val_loss: 1.1644
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 24, 15)       0
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 24, 32)       3072        input_2[0][0]
# __________________________________________________________________________________________________
# input_1 (InputLayer)            (None, 24, 15)       0
# __________________________________________________________________________________________________
# seq_self_attention_2 (SeqSelfAt (None, 24, 32)       1025        bidirectional_2[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 24, 64)       9216        input_1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 24, 32)       0           seq_self_attention_2[0][0]
#                                                                  bidirectional_2[0][0]
# __________________________________________________________________________________________________
# seq_self_attention_1 (SeqSelfAt (None, 24, 64)       4097        bidirectional_1[0][0]
# __________________________________________________________________________________________________
# layer_normalization_2 (LayerNor (None, 24, 32)       64          add_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 24, 64)       0           seq_self_attention_1[0][0]
#                                                                  bidirectional_1[0][0]
# __________________________________________________________________________________________________
# seq_self_attention_3 (SeqSelfAt (None, 24, 32)       1025        layer_normalization_2[0][0]
# __________________________________________________________________________________________________
# layer_normalization_1 (LayerNor (None, 24, 64)       128         add_1[0][0]
# __________________________________________________________________________________________________
# layer_normalization_3 (LayerNor (None, 24, 32)       64          seq_self_attention_3[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 1536)         0           layer_normalization_1[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 768)          0           layer_normalization_3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 16)           24592       flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 16)           12304       flatten_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16)           0           dense_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 1552)         0           dropout_1[0][0]
#                                                                  flatten_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 784)          0           dropout_2[0][0]
#                                                                  flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            1553        concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            785         concatenate_2[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 1)            0           dense_2[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            2           add_3[0][0]
# ==================================================================================================
# Total params: 57,927
# Trainable params: 57,927
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
custom_ob = {'LayerNormalization': LayerNormalization , 'SeqSelfAttention':SeqSelfAttention}
model = load_model('GRU_Single_Attention_model_region.h5', custom_objects=custom_ob)
t1 = time.time()
y_pred2 = model.predict([x_test,x_test])
#y_pred2 = model.predict(x_test)
#y_pred = model.predict(x_train)
t2 = time.time()
print('Predict time: ',t2-t1)
y_pred = scaler.inverse_transform(y_pred2)#Undo scaling
rmse_lstm2 = np.sqrt(mean_squared_error(y_test, y_pred2))
#rmse_lstm = np.sqrt(mean_squared_error(y_train, y_pred))
#print('RMSE: ',rmse_lstm)
print('RMSE2: ',rmse_lstm2)
mae2 = mean_absolute_error(y_test, y_pred2)
#mae = mean_absolute_error(y_train, y_pred)
#print('MAE: ',mae)
print('MAE2: ',mae2)
r22 =  r2_score(y_test, y_pred2)
# r2 =  r2_score(y_train, y_pred)
# print('R-square: ',r2)
print('R-square2: ',r22)

# n = len(y_test)
# p = 12
# Adj_r2 = 1-(1-r2)*(n-1)/(n-p-1)
# Adj_r22 = 1-(1-r22)*(n-1)/(n-p-1)
# print('Adj R-square: ',Adj_r2)
# print('Adj R-square2: ',Adj_r22)

plt.plot(history.history["loss"],label="loss")
plt.plot(history.history["val_loss"],label="val_loss")
plt.legend(loc="best")
plt.xlabel("No. Of Epochs")
plt.ylabel("mse score")
# Out:
# Predict time:  0.5335631370544434
# RMSE2:  9.09503771831353
# MAE2:  6.271035315902674
# R-square2:  -0.5635781745522634
# Text(0, 0.5, 'mse score')
