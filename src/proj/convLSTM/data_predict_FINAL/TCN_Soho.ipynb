# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tcn import TCN # main library
import math
from sklearn.preprocessing import RobustScaler
#from keras.initializers import  glorot_normal, RandomUniform
#from keras import optimizers,regularizers

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import load_model 
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
df = pd.read_csv("station_bike _Soho.csv")
df["timestamp"] = pd.to_datetime(df["timestamp"])
df = df.set_index("timestamp")
#df.head()

df["hour"] = df.index.hour
df["day_of_month"] = df.index.day
df["day_of_week"]  = df.index.dayofweek
df["month"] = df.index.month

training_data_len = math.ceil(len(df) * 0.9) # taking 90% of data to train and 10% of data to test
testing_data_len = len(df) - training_data_len

time_steps = 24
train, test = df.iloc[0:training_data_len], df.iloc[(training_data_len-time_steps):len(df)]
print(df.shape, train.shape, test.shape)

train_trans = train[['t1','t2', 'hum', 'wind_speed']].to_numpy()
test_trans = test[['t1','t2', 'hum', 'wind_speed']].to_numpy()

scaler = RobustScaler() # Handles outliers
train.loc[:, ['t1','t2','hum', 'wind_speed']]=scaler.fit_transform(train_trans)
test.loc[:, ['t1','t2', 'hum', 'wind_speed']]=scaler.fit_transform(test_trans)

train['cnt'] = scaler.fit_transform(train[['cnt']])
test['cnt'] = scaler.fit_transform(test[['cnt']])

from tqdm import tqdm_notebook as tqdm

#Split the data into x_train and y_train data sets
x_train = []
y_train = []

for i in tqdm(range(len(train) - time_steps)):
    x_train.append(train.drop(columns='cnt').iloc[i:i + time_steps].to_numpy())
    y_train.append(train.loc[:,'cnt'].iloc[i + time_steps])

#Convert x_train and y_train to numpy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

#Create the x_test and y_test data sets
x_test = []
y_test = df.loc[:,'cnt'].iloc[training_data_len:len(df)]

for i in tqdm(range(len(test) - time_steps)):
    x_test.append(test.drop(columns='cnt').iloc[i:i + time_steps].to_numpy())
    # y_test.append(test.loc[:,'cnt'].iloc[i + time_steps])

#Convert x_test and y_test to numpy arrays
x_test = np.array(x_test)
y_test = np.array(y_test)

# All 12 columns of the data
print('Train size:')
print(x_train.shape, y_train.shape)
print('Test size:')
print(x_test.shape, y_test.shape)
# Out:
# (160, 13) (144, 13) (40, 13)
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:34: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/120 [00:00<?, ?it/s]
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:46: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/16 [00:00<?, ?it/s]
# Train size:
# (120, 24, 12) (120,)
# Test size:
# (16, 24, 12) (16,)

# %%
#init = glorot_normal(seed=None) # 給 LSTM
#init_d = RandomUniform(minval=-0.05, maxval=0.05) # 給 Dense layer
#nadam = optimizers.Nadam(lr=0.002,clipvalue=0.5)
from tensorflow.keras.initializers import RandomUniform
init_d = RandomUniform(minval=-0.05, maxval=0.05) # 給 Dense layer
model = Sequential()
model.add(TCN(input_shape=(x_train.shape[1],x_train.shape[2]),
        kernel_size=3,
        nb_filters=25,
        nb_stacks=1,
        dilations=(1, 2, 4, 8),
        kernel_initializer='glorot_uniform',
        use_skip_connections=True,
        use_batch_norm=False,
        use_weight_norm=False,
        use_layer_norm=True,
        dropout_rate = 0.05,
        return_sequences=True
        ))
model.add(Dropout(0.3))
model.add(TCN(
        kernel_size=3,
        nb_filters=25,
        nb_stacks=1,
        dilations=(1, 2, 4, 8),
        kernel_initializer='glorot_uniform',
        use_skip_connections=True,
        use_batch_norm=False,
        use_weight_norm=False,
        use_layer_norm=True,
        dropout_rate = 0.05,
        return_sequences=False
        ))  
model.add(Dropout(0.3))
model.add(Dense(1,kernel_initializer=init_d))  
model.summary()

print('Train...')
model.compile(optimizer = "nadam" , loss="mse")
history = model.fit(x_train, y_train, epochs=120, batch_size=12, validation_split=0.1, shuffle=True)
#Save Model
model.save('TCN_model_soho.h5')  # creates a HDF5 file 
del model

custom_ob = {'TCN': TCN}
# model = load_model('TCN_model_1.h5', custom_objects=custom_ob)
model = load_model('TCN_model_soho.h5', custom_objects=custom_ob)
print('Load Success')

import time
t1 = time.time()
y_pred = model.predict(x_test)
t2 = time.time()
print('Predict time: ',t2-t1)
y_pred = scaler.inverse_transform(y_pred)#Undo scaling

from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error
rmse_lstm = np.sqrt(mean_squared_error(y_test, y_pred))
print('RMSE: ',rmse_lstm)

mae = mean_absolute_error(y_test, y_pred)
print('MAE: ',mae)

r2 =  r2_score(y_test, y_pred)
print('R-square: ',r2)


n = len(y_test)
p = 12
Adj_r2 = 1-(1-r2)*(n-1)/(n-p-1)
print('Adj R-square: ',Adj_r2)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# tcn_4 (TCN)                  (None, 24, 25)            14950
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 24, 25)            0
# _________________________________________________________________
# tcn_5 (TCN)                  (None, 25)                15600
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 25)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 26
# =================================================================
# Total params: 30,576
# Trainable params: 30,576
# Non-trainable params: 0
# _________________________________________________________________
# Train...
# Train on 108 samples, validate on 12 samples
# Epoch 1/120
# 108/108 [==============================] - 5s 50ms/sample - loss: 0.5708 - val_loss: 0.5272
# Epoch 2/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.5463 - val_loss: 0.4726
# Epoch 3/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.4718 - val_loss: 0.3915
# Epoch 4/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.4328 - val_loss: 0.3181
# Epoch 5/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.4261 - val_loss: 0.2827
# Epoch 6/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3378 - val_loss: 0.2553
# Epoch 7/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3380 - val_loss: 0.2311
# Epoch 8/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2752 - val_loss: 0.2099
# Epoch 9/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3184 - val_loss: 0.2054
# Epoch 10/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3119 - val_loss: 0.2057
# Epoch 11/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2807 - val_loss: 0.1789
# Epoch 12/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2893 - val_loss: 0.1785
# Epoch 13/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2349 - val_loss: 0.1570
# Epoch 14/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2420 - val_loss: 0.1443
# Epoch 15/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2502 - val_loss: 0.1507
# Epoch 16/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2412 - val_loss: 0.1688
# Epoch 17/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2382 - val_loss: 0.1437
# Epoch 18/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2480 - val_loss: 0.1278
# Epoch 19/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2344 - val_loss: 0.1143
# Epoch 20/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2480 - val_loss: 0.1163
# Epoch 21/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2085 - val_loss: 0.1059
# Epoch 22/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1781 - val_loss: 0.0977
# Epoch 23/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2073 - val_loss: 0.1075
# Epoch 24/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1697 - val_loss: 0.1082
# Epoch 25/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1820 - val_loss: 0.0832
# Epoch 26/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1585 - val_loss: 0.1046
# Epoch 27/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1469 - val_loss: 0.0876
# Epoch 28/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1966 - val_loss: 0.0860
# Epoch 29/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1646 - val_loss: 0.0925
# Epoch 30/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1991 - val_loss: 0.1142
# Epoch 31/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1542 - val_loss: 0.0959
# Epoch 32/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1319 - val_loss: 0.1294
# Epoch 33/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1856 - val_loss: 0.1490
# Epoch 34/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1756 - val_loss: 0.0794
# Epoch 35/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1244 - val_loss: 0.0739
# Epoch 36/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1641 - val_loss: 0.0928
# Epoch 37/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1051 - val_loss: 0.1117
# Epoch 38/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1105 - val_loss: 0.0882
# Epoch 39/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1267 - val_loss: 0.1299
# Epoch 40/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1525 - val_loss: 0.0907
# Epoch 41/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1284 - val_loss: 0.1171
# Epoch 42/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1330 - val_loss: 0.0964
# Epoch 43/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1038 - val_loss: 0.0994
# Epoch 44/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0963 - val_loss: 0.0986
# Epoch 45/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1390 - val_loss: 0.1104
# Epoch 46/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0859 - val_loss: 0.1122
# Epoch 47/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1167 - val_loss: 0.1281
# Epoch 48/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1612 - val_loss: 0.0966
# Epoch 49/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1306 - val_loss: 0.1062
# Epoch 50/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1003 - val_loss: 0.1083
# Epoch 51/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1040 - val_loss: 0.1039
# Epoch 52/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1017 - val_loss: 0.0937
# Epoch 53/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1101 - val_loss: 0.1434
# Epoch 54/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0909 - val_loss: 0.1145
# Epoch 55/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0962 - val_loss: 0.1170
# Epoch 56/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0961 - val_loss: 0.0967
# Epoch 57/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0828 - val_loss: 0.1260
# Epoch 58/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0841 - val_loss: 0.1180
# Epoch 59/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0873 - val_loss: 0.1100
# Epoch 60/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1001 - val_loss: 0.1164
# Epoch 61/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0893 - val_loss: 0.1522
# Epoch 62/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1165 - val_loss: 0.1375
# Epoch 63/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0959 - val_loss: 0.1108
# Epoch 64/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0712 - val_loss: 0.1100
# Epoch 65/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1031 - val_loss: 0.1435
# Epoch 66/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1083 - val_loss: 0.1004
# Epoch 67/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0623 - val_loss: 0.0948
# Epoch 68/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0877 - val_loss: 0.1280
# Epoch 69/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0921 - val_loss: 0.1547
# Epoch 70/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0886 - val_loss: 0.0960
# Epoch 71/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0888 - val_loss: 0.1155
# Epoch 72/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0703 - val_loss: 0.1259
# Epoch 73/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0738 - val_loss: 0.1236
# Epoch 74/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0721 - val_loss: 0.1670
# Epoch 75/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0888 - val_loss: 0.1277
# Epoch 76/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0864 - val_loss: 0.1153
# Epoch 77/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0849 - val_loss: 0.1119
# Epoch 78/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1077 - val_loss: 0.1266
# Epoch 79/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0658 - val_loss: 0.1442
# Epoch 80/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0532 - val_loss: 0.1486
# Epoch 81/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1094 - val_loss: 0.1352
# Epoch 82/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0780 - val_loss: 0.1565
# Epoch 83/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0913 - val_loss: 0.0958
# Epoch 84/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1015 - val_loss: 0.1197
# Epoch 85/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0940 - val_loss: 0.1492
# Epoch 86/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0923 - val_loss: 0.1172
# Epoch 87/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0657 - val_loss: 0.1435
# Epoch 88/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0706 - val_loss: 0.1219
# Epoch 89/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0758 - val_loss: 0.1182
# Epoch 90/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0625 - val_loss: 0.1094
# Epoch 91/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0677 - val_loss: 0.1328
# Epoch 92/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0658 - val_loss: 0.0992
# Epoch 93/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0579 - val_loss: 0.0978
# Epoch 94/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0940 - val_loss: 0.1084
# Epoch 95/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0663 - val_loss: 0.0985
# Epoch 96/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0887 - val_loss: 0.1274
# Epoch 97/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0727 - val_loss: 0.1674
# Epoch 98/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0775 - val_loss: 0.1136
# Epoch 99/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0945 - val_loss: 0.1431
# Epoch 100/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0834 - val_loss: 0.1313
# Epoch 101/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0579 - val_loss: 0.1641
# Epoch 102/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0668 - val_loss: 0.1512
# Epoch 103/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0509 - val_loss: 0.1298
# Epoch 104/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0689 - val_loss: 0.1162
# Epoch 105/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0888 - val_loss: 0.1536
# Epoch 106/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0765 - val_loss: 0.1246
# Epoch 107/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0663 - val_loss: 0.1261
# Epoch 108/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0574 - val_loss: 0.1206
# Epoch 109/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0490 - val_loss: 0.1325
# Epoch 110/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0668 - val_loss: 0.1592
# Epoch 111/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.1067 - val_loss: 0.1173
# Epoch 112/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0666 - val_loss: 0.1395
# Epoch 113/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0653 - val_loss: 0.1200
# Epoch 114/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0666 - val_loss: 0.1148
# Epoch 115/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0539 - val_loss: 0.1252
# Epoch 116/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0587 - val_loss: 0.1118
# Epoch 117/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.0693 - val_loss: 0.1310
# Epoch 118/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0641 - val_loss: 0.1329
# Epoch 119/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0645 - val_loss: 0.1378
# Epoch 120/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.0498 - val_loss: 0.1348
# Load Success
# Predict time:  0.7509908676147461
# RMSE:  11.807829103591004
# MAE:  9.64025342464447
# R-square:  -0.5559178728744703
# Adj R-square:  -6.7795893643723515
