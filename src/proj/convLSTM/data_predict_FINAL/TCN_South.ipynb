# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tcn import TCN # main library
import math
from sklearn.preprocessing import RobustScaler
#from keras.initializers import  glorot_normal, RandomUniform
#from keras import optimizers,regularizers

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import load_model 
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
df = pd.read_csv("station_bike _South.csv")
df["timestamp"] = pd.to_datetime(df["timestamp"])
df = df.set_index("timestamp")
#df.head()

df["hour"] = df.index.hour
df["day_of_month"] = df.index.day
df["day_of_week"]  = df.index.dayofweek
df["month"] = df.index.month

training_data_len = math.ceil(len(df) * 0.9) # taking 90% of data to train and 10% of data to test
testing_data_len = len(df) - training_data_len

time_steps = 24
train, test = df.iloc[0:training_data_len], df.iloc[(training_data_len-time_steps):len(df)]
print(df.shape, train.shape, test.shape)

train_trans = train[['t1','t2', 'hum', 'wind_speed']].to_numpy()
test_trans = test[['t1','t2', 'hum', 'wind_speed']].to_numpy()

scaler = RobustScaler() # Handles outliers
train.loc[:, ['t1','t2','hum', 'wind_speed']]=scaler.fit_transform(train_trans)
test.loc[:, ['t1','t2', 'hum', 'wind_speed']]=scaler.fit_transform(test_trans)

train['cnt'] = scaler.fit_transform(train[['cnt']])
test['cnt'] = scaler.fit_transform(test[['cnt']])

from tqdm import tqdm_notebook as tqdm

#Split the data into x_train and y_train data sets
x_train = []
y_train = []

for i in tqdm(range(len(train) - time_steps)):
    x_train.append(train.drop(columns='cnt').iloc[i:i + time_steps].to_numpy())
    y_train.append(train.loc[:,'cnt'].iloc[i + time_steps])

#Convert x_train and y_train to numpy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

#Create the x_test and y_test data sets
x_test = []
y_test = df.loc[:,'cnt'].iloc[training_data_len:len(df)]

for i in tqdm(range(len(test) - time_steps)):
    x_test.append(test.drop(columns='cnt').iloc[i:i + time_steps].to_numpy())
    # y_test.append(test.loc[:,'cnt'].iloc[i + time_steps])

#Convert x_test and y_test to numpy arrays
x_test = np.array(x_test)
y_test = np.array(y_test)

# All 12 columns of the data
print('Train size:')
print(x_train.shape, y_train.shape)
print('Test size:')
print(x_test.shape, y_test.shape)
# Out:
# (160, 13) (144, 13) (40, 13)
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:34: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/120 [00:00<?, ?it/s]
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:46: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/16 [00:00<?, ?it/s]
# Train size:
# (120, 24, 12) (120,)
# Test size:
# (16, 24, 12) (16,)

# %%
#init = glorot_normal(seed=None) # 給 LSTM
#init_d = RandomUniform(minval=-0.05, maxval=0.05) # 給 Dense layer
#nadam = optimizers.Nadam(lr=0.002,clipvalue=0.5)
from tensorflow.keras.initializers import RandomUniform
init_d = RandomUniform(minval=-0.05, maxval=0.05) # 給 Dense layer
model = Sequential()
model.add(TCN(input_shape=(x_train.shape[1],x_train.shape[2]),
        kernel_size=3,
        nb_filters=20,
        nb_stacks=1,
        dilations=(1, 2, 4, 8),
        kernel_initializer='glorot_uniform',
        use_skip_connections=True,
        use_batch_norm=False,
        use_weight_norm=False,
        use_layer_norm=True,
        dropout_rate = 0.05,
        return_sequences=True
        ))
model.add(Dropout(0.3))
model.add(TCN(
        kernel_size=3,
        nb_filters=20,
        nb_stacks=1,
        dilations=(1, 2, 4, 8),
        kernel_initializer='glorot_uniform',
        use_skip_connections=True,
        use_batch_norm=False,
        use_weight_norm=False,
        use_layer_norm=True,
        dropout_rate = 0.05,
        return_sequences=False
        ))  
model.add(Dropout(0.3))
model.add(Dense(1,kernel_initializer=init_d))  
model.summary()

print('Train...')
model.compile(optimizer = "nadam" , loss="mse")
history = model.fit(x_train, y_train, epochs=120, batch_size=12, validation_split=0.1, shuffle=True)
#Save Model
model.save('TCN_model_south.h5')  # creates a HDF5 file 
del model

custom_ob = {'TCN': TCN}
# model = load_model('TCN_model_1.h5', custom_objects=custom_ob)
model = load_model('TCN_model_south.h5', custom_objects=custom_ob)
print('Load Success')

import time
t1 = time.time()
y_pred = model.predict(x_test)
t2 = time.time()
print('Predict time: ',t2-t1)
y_pred = scaler.inverse_transform(y_pred)#Undo scaling

from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error
rmse_lstm = np.sqrt(mean_squared_error(y_test, y_pred))
print('RMSE: ',rmse_lstm)

mae = mean_absolute_error(y_test, y_pred)
print('MAE: ',mae)

r2 =  r2_score(y_test, y_pred)
print('R-square: ',r2)


n = len(y_test)
p = 12
Adj_r2 = 1-(1-r2)*(n-1)/(n-p-1)
print('Adj R-square: ',Adj_r2)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# tcn_4 (TCN)                  (None, 24, 20)            9860
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 24, 20)            0
# _________________________________________________________________
# tcn_5 (TCN)                  (None, 20)                10080
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 19,961
# Trainable params: 19,961
# Non-trainable params: 0
# _________________________________________________________________
# Train...
# Train on 108 samples, validate on 12 samples
# Epoch 1/120
# 108/108 [==============================] - 6s 56ms/sample - loss: 1.2396 - val_loss: 0.8386
# Epoch 2/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 1.1039 - val_loss: 0.6223
# Epoch 3/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.9428 - val_loss: 0.5648
# Epoch 4/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.9157 - val_loss: 0.5524
# Epoch 5/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 1.0021 - val_loss: 0.5481
# Epoch 6/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.9769 - val_loss: 0.5520
# Epoch 7/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.9899 - val_loss: 0.5043
# Epoch 8/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.8832 - val_loss: 0.4866
# Epoch 9/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.8107 - val_loss: 0.3849
# Epoch 10/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.8323 - val_loss: 0.4037
# Epoch 11/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.8362 - val_loss: 0.3240
# Epoch 12/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.6628 - val_loss: 0.2827
# Epoch 13/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.7620 - val_loss: 0.2084
# Epoch 14/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.7079 - val_loss: 0.2932
# Epoch 15/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.6137 - val_loss: 0.2091
# Epoch 16/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.5669 - val_loss: 0.3349
# Epoch 17/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.4633 - val_loss: 0.2388
# Epoch 18/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.5885 - val_loss: 0.2199
# Epoch 19/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.4684 - val_loss: 0.2532
# Epoch 20/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.4851 - val_loss: 0.2732
# Epoch 21/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.5390 - val_loss: 0.2717
# Epoch 22/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.4854 - val_loss: 0.2247
# Epoch 23/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.4392 - val_loss: 0.2202
# Epoch 24/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.4048 - val_loss: 0.2465
# Epoch 25/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.4401 - val_loss: 0.2375
# Epoch 26/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.4309 - val_loss: 0.1786
# Epoch 27/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.4351 - val_loss: 0.1971
# Epoch 28/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.5020 - val_loss: 0.1972
# Epoch 29/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.4118 - val_loss: 0.2419
# Epoch 30/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4366 - val_loss: 0.2963
# Epoch 31/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.4674 - val_loss: 0.2425
# Epoch 32/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.4215 - val_loss: 0.3184
# Epoch 33/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3709 - val_loss: 0.2437
# Epoch 34/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.4017 - val_loss: 0.2495
# Epoch 35/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3601 - val_loss: 0.2101
# Epoch 36/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3987 - val_loss: 0.2551
# Epoch 37/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3744 - val_loss: 0.3056
# Epoch 38/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.5233 - val_loss: 0.2515
# Epoch 39/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.4265 - val_loss: 0.2749
# Epoch 40/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.4558 - val_loss: 0.2862
# Epoch 41/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3372 - val_loss: 0.2561
# Epoch 42/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3805 - val_loss: 0.4055
# Epoch 43/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3750 - val_loss: 0.3174
# Epoch 44/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3113 - val_loss: 0.2453
# Epoch 45/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3761 - val_loss: 0.2376
# Epoch 46/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3119 - val_loss: 0.2963
# Epoch 47/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3885 - val_loss: 0.2946
# Epoch 48/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2729 - val_loss: 0.3098
# Epoch 49/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.4322 - val_loss: 0.2689
# Epoch 50/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2655 - val_loss: 0.2774
# Epoch 51/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3351 - val_loss: 0.3302
# Epoch 52/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2323 - val_loss: 0.3054
# Epoch 53/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3206 - val_loss: 0.3120
# Epoch 54/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3210 - val_loss: 0.5025
# Epoch 55/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2925 - val_loss: 0.3086
# Epoch 56/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2903 - val_loss: 0.3297
# Epoch 57/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2249 - val_loss: 0.3738
# Epoch 58/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2717 - val_loss: 0.3637
# Epoch 59/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3186 - val_loss: 0.2847
# Epoch 60/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3446 - val_loss: 0.2202
# Epoch 61/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3108 - val_loss: 0.2668
# Epoch 62/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3161 - val_loss: 0.3098
# Epoch 63/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3370 - val_loss: 0.2775
# Epoch 64/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3751 - val_loss: 0.2775
# Epoch 65/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3092 - val_loss: 0.3132
# Epoch 66/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.3083 - val_loss: 0.2967
# Epoch 67/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2586 - val_loss: 0.3118
# Epoch 68/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2965 - val_loss: 0.3613
# Epoch 69/120
# 108/108 [==============================] - 0s 1ms/sample - loss: 0.2579 - val_loss: 0.4225
# Epoch 70/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4106 - val_loss: 0.3377
# Epoch 71/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2596 - val_loss: 0.4030
# Epoch 72/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2485 - val_loss: 0.4831
# Epoch 73/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2913 - val_loss: 0.3280
# Epoch 74/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2654 - val_loss: 0.2976
# Epoch 75/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3335 - val_loss: 0.3474
# Epoch 76/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2619 - val_loss: 0.3159
# Epoch 77/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2519 - val_loss: 0.2853
# Epoch 78/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3185 - val_loss: 0.3170
# Epoch 79/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.3240 - val_loss: 0.2849
# Epoch 80/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.4122 - val_loss: 0.2644
# Epoch 81/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2884 - val_loss: 0.3326
# Epoch 82/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2882 - val_loss: 0.2815
# Epoch 83/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2226 - val_loss: 0.3803
# Epoch 84/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2513 - val_loss: 0.3235
# Epoch 85/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2522 - val_loss: 0.3233
# Epoch 86/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2763 - val_loss: 0.2218
# Epoch 87/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2446 - val_loss: 0.2799
# Epoch 88/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2035 - val_loss: 0.3309
# Epoch 89/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2612 - val_loss: 0.3015
# Epoch 90/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2296 - val_loss: 0.3973
# Epoch 91/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1941 - val_loss: 0.3443
# Epoch 92/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2501 - val_loss: 0.4242
# Epoch 93/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1972 - val_loss: 0.3841
# Epoch 94/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2140 - val_loss: 0.4770
# Epoch 95/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1699 - val_loss: 0.3618
# Epoch 96/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1553 - val_loss: 0.3006
# Epoch 97/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2137 - val_loss: 0.3431
# Epoch 98/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1993 - val_loss: 0.3809
# Epoch 99/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2686 - val_loss: 0.3395
# Epoch 100/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2625 - val_loss: 0.2472
# Epoch 101/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2974 - val_loss: 0.4789
# Epoch 102/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2197 - val_loss: 0.4222
# Epoch 103/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2183 - val_loss: 0.3629
# Epoch 104/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1627 - val_loss: 0.4029
# Epoch 105/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2853 - val_loss: 0.3614
# Epoch 106/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2076 - val_loss: 0.2749
# Epoch 107/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2006 - val_loss: 0.2690
# Epoch 108/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2354 - val_loss: 0.3095
# Epoch 109/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2286 - val_loss: 0.2998
# Epoch 110/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2401 - val_loss: 0.3573
# Epoch 111/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2568 - val_loss: 0.3173
# Epoch 112/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2828 - val_loss: 0.3370
# Epoch 113/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2935 - val_loss: 0.2895
# Epoch 114/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2437 - val_loss: 0.2806
# Epoch 115/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1856 - val_loss: 0.2998
# Epoch 116/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2011 - val_loss: 0.3027
# Epoch 117/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1991 - val_loss: 0.2080
# Epoch 118/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2169 - val_loss: 0.2777
# Epoch 119/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.1847 - val_loss: 0.3321
# Epoch 120/120
# 108/108 [==============================] - 0s 2ms/sample - loss: 0.2647 - val_loss: 0.2839
# Load Success
# Predict time:  0.6948795318603516
# RMSE:  1.8381153607225664
# MAE:  1.4945239648222923
# R-square:  -0.9480608745653336
# Adj R-square:  -8.74030437282667
